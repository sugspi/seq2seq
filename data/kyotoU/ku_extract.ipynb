# %%
import numpy as np
import json
import pandas as pd
import os
import re
import ast
import xml.etree.ElementTree as ET
import ast

# %%
# input


#kana
lines = []
with open('data/ku_data.txt') as f:
    line = f.readline()
    while line:
        lst = line.split(" ")
        
        #lst[3]= lst[3].replace('\r','')
        #lst[3] = lst[3].replace('。','。\n')
        
        lst[4] = lst[4].replace('\n','')
        lst[4] = lst[4].replace('\r','')
        lst[4] = lst[4].replace('。','。\n')

        lines.append(lst[3]+"\n")
        lines.append(lst[4])        
        line = f.readline()
        
print(len(lines)/2)

txt = open('test.txt', 'w') # 書き込みモードで開く


count= 0;
for i in lines:
    count +=1
    print(i)
    txt.write(i) 
    #if(100<count):
    #    break
    
txt.close()
# Out:
# 2472.0
# もみじ狩りに行った。
#
# 狩りをした。
#
# ジョンは怠慢で、ビルは勤勉だ。
#
# 犬は怠慢で、人は勤勉だ。
#
# 羽田に行った。
#
# 千葉に行った。
#
# 英文法を勉強した。
#
# 中国語を勉強した。
#
# 角館はみちのくの小京都である。
#
# 角館は京都である。
#
# 漆器は高価だ。
#
# 張り物は高価だ。
#
# 春一番が吹いた。
#
# 火を吹いた。
#
# 酢が体にいいともてはやされている。
#
# 辛いものが体にいいともてはやされている。
#
# 雪だるまを作った。
#
# 水遊びをした。
#
# 雪崩が起きた。
#
# 山崩れが起きた。
#
# 太郎のおみやげは、ちんすこうだった。
#
# 太郎のおみやげは、置物だった。
#
# 大福を食べた。
#
# 洋菓子を食べた。
#
# 土筆が出た。
#
# お化けが出た。
#
# 梅干しはすっぱい。
#
# 干し物はすっぱい。
#
# 野生のサル生息の最北限は、下北半島である。
#
# 動物生息の最北限は青森である。
#
# あの人は呼吸器専門医だ。
#
# あの人は医者だ。
#
# アメリカンショートヘアーを飼っている。
#
# 猫を飼っている。
#
# カツオは海の生き物である。
#
# カツオは生き物である。
#
# キュウリの糠漬けを食べた。
#
# 漬け物を食べた。
#
# ケーキを食べた。
#
# スイーツを食べた。
#
# チョコレート工場の見学に行った。
#
# 工場見学に行った。
#
# ディズニーランドに行った。
#
# テーマパークに行った。
#
# トムヤムクンを食べた。
#
# タイ料理を食べた。
#
# フリッパーはイルカだ。
#
# フリッパーは哺乳類だ。
#
# ブラックバスやブルーギルがフナやタナゴを脅かしている。
#
# 外来種が固有種を脅かしている。
#
# ポルトガルワインを飲んだ。
#
# ワインを飲んだ。
#
# リャオヤンは中国遼寧省の都市である。
#
# リャオヤンは中国の都市である。
#
# 胃が痛い。
#
# 腹が痛い。
#
# 夏目漱石の『こころ』を読んだ。
#
# 小説を読んだ。
#
# 花子は洋菓子より和菓子をなお好む。
#
# 花子はお菓子が好きだ。
#
# 悔し涙を流した。
#
# 涙を流した。
#
# 葛飾区に住んでいます。
#
# 東京都に住んでいます。
#
# 競馬をした。
#
# 賭けをした。
#
# 軍記物を読んだ。
#
# 書物を読んだ。
#
# 昨晩のおかずは肉ジャガと青菜のお浸しだった。
#
# 昨晩のおかずは和食だった。
#
# 食後にケーキを食べた。
#
# 食後にスイーツを食べた。
#
# 生卵を食べた。
#
# 卵を食べた。
#
# 太郎は人間だ。
#
# 太郎は動物だ。
#
# 大福を食べた。
#
# 和菓子を食べた。
#
# 都民税を払った。
#
# 税金を払った。
#
# 肉まんを食べた。
#
# 中華まんを食べた。
#
# 彼は女児を殺害した。
#
# 彼は子どもを殺害した。
#
# 桜の季節になった。
#
# 花の季節になった。
#
# 太郎はイルカが好きだ。
#
# 太郎は哺乳類が好きだ。
#
# カツオは海の生き物である。
#
# 魚は海の生き物である。
#
# ぴょんぴょん飛び跳ねるのはウサギだけではない。
#
# ウサギ以外にも飛び跳ねる動物がいる。
#
# 違憲判決が下った。
#
# 判決が出なかった。
#
# 今年も白鳥が渡来した。
#
# 渡り鳥がやってきた。
#
# 冬季オリンピックがトリノで開催される。
#
# イタリアで冬季オリンピックが開かれる。
#
# ワーゲンに乗せてもらった。
#
# 私は外車に乗った。
#
# 首を寝違えた。
#
# 手首が痛い。
#
# レンタカーを借りた。
#
# 車で遊びに行った。
#
# 扁桃腺がやられた。
#
# のどが痛い。
#
# 国民年金保険料の納付率が問題になっている。
#
# 社会保険の納付は個人の自由である。
#
# ロンドン留学中に彼と出会い、結婚した。
#
# イギリスに留学した。
#
# ぬいぐるみと遊んだ。
#
# 犬のポチと遊んだ。
#
# ビールとおつまみを頼んだ。
#
# ビールとスパゲッティを頼んだ。
#
# フルーツ狩りをした。
#
# サツマイモ掘りをした。
#
# メーカーに勤めている。
#
# 会計事務所に勤めている。
#
# 夏野菜は体を冷やす効果がある。
#
# 白菜は体を冷やす効果がある。
#
# 観葉植物を育てている。
#
# チューリップを育てている。
#
# 関西に行った。
#
# 福島に行った。
#
# 靴を履いた。
#
# 靴下を履いた。
#
# 私は印象派の絵が好きだ。
#
# 私はキリコの絵が好きだ。
#
# 私は管楽器を持っている。
#
# 私はバイオリンを持っている。
#
# 酒を飲んだ。
#
# 緑茶を飲んだ。
#
# 女性だから妊娠する。
#
# 彼女は妊娠する。
#
# 焼き菓子を作った。
#
# ゼリーを作った。
#
# 雪国に行った。
#
# 沖縄に行った。
#
# 電子手帳が欲しい。
#
# 手帳が欲しい。
#
# 日本には四季がある。
#
# 日本には春と夏しかない。
#
# 乳製品は体にいい。
#
# ヨーグルトは体に悪い。
#
# 彼はある女性に出会った。
#
# 彼は母親に出会った。
#
# 彼はマリンスポーツが得意だ。
#
# 彼はバスケットが得意だ。
#
# 服飾品を買った。
#
# ジャケットを買った。
#
# 毎日、家事に追われている。
#
# 毎日、ピアノの練習に追われている。
#
# 彼は野菜が嫌いだ。
#
# 彼はトマトが嫌いだ。
#
# カツオは海のいきものである。
#
# マナガツオは海のいきものである。
#
# 夏野菜は体を冷やす効果がある。
#
# トマトは体を冷やす効果がある。
#
# 我々は、断固闘う。
#
# 私は、断固闘う。
#
# 四国八十八箇所めぐりをした。
#
# 霊山寺に行った。
#
# 鳥は羽を持つ。
#
# 雀は羽を持つ。
#
# 服飾品を買った。
#
# ベルトを買った。
#
# コンピューターをいじった。
#
# ハードディスクをいじった。
#
# 軍記物を読んだ。
#
# 平家物語を読んだ。
#
# 戸棚のお菓子が食べたい。
#
# おせんべいが食べたい。
#
# ボタンを糸で縫いつけた。
#
# ボタンをボタン糸で縫いつけた。
#
# 火事の原因を調査する。
#
# 出火の原因を調査する。
#
# 寒いので暖房器具が必要だ。
#
# 寒いのでストーブが必要だ。
#
# 主食を買った。
#
# 米を買った。
#
# 太郎は日本人だが、お風呂が嫌いだ。
#
# 太郎は銭湯が嫌いだ。
#
# 文房具を使った。
#
# 定規を使った。
#
# 根菜を使った。
#
# レンコンを食べた。
#
# あいさつの大切さを伝えたい。
#
# おはようは大切だ。
#
# 外来生物のアライグマが増えて、困っている。
#
# アライグマはかわいい。
#
# 漁業関係者は、エチゼンクラゲの大発生で魚が捕れず苦労している。
#
# 漁師は魚捕りがうまい。
#
# 私は、飛べない鳥が好きだ。
#
# 私は怪我をした鳥が好きだ。
#
# 私は暖かい色が好きだ。
#
# 私は青色が好きだ。
#
# 東京の人は冷たい。
#
# 東京の人は氷だ。
#
# 彼は甘いものが好きだ。
#
# 彼はゴーヤが好きだ。
#
# 彼は甘いものは何でも好きだ。
#
# 彼はうまい話が好きだ。
#
# 彼は大きい動物が好きだ。
#
# 彼はアイスクリームが好きだ。
#
# 彼は大きい動物が好きだ。
#
# 彼は蟻が好きだ。
#
# 彼は保守的だ。
#
# 彼は新しいことに挑戦するのが好きだ。
#
# 彼女は酸っぱいものが嫌いだ。
#
# 彼はアイスクリームが嫌いだ。
#
# 野性化したアライグマの被害に農家は困っている。
#
# アライグマは仕種がかわいらしい。
#
# イクラはロシア語である。
#
# イクラは外来語だ。
#
# トヨタが高級車「レクサス」店を開業した。
#
# レクサスは高級車だ。
#
# 切っても変色しない新種のリンゴが誕生した。
#
# 普通のリンゴは切ると変色していく。
#
# 彼は大きい動物は何でも好きだ。
#
# 彼は大蛇が好きだ。
#
# 運動会の練習をしている。
#
# 体を動かすのが好きだ。
#
# 彼はハト派だ。
#
# 彼はハトが好きだ。
#
# 彼は甘いものが好きだ。
#
# 彼はチョコレートが好きだ。
#
# 彼は大きい動物が好きだ。
#
# 彼は象が好きだ。
#
# 彼女は酸っぱいものが嫌いだ。
#
# 彼女は梅干が嫌いだ。
#
# 彼女は酸っぱいものは何でも嫌いだ。
#
# 彼女はレモンティーは飲まない。
#
# 私は、飛べない鳥が好きだ。
#
# 私はキウイが好きだ。
#
# 私は、飛べない鳥が好きだ。
#
# 私はペンギンが好きだ。
#
# 私は、飛べない鳥が好きだ。
#
# 私はヤンバルクイナが好きだ。
#
# 私は暖かい色が好きだ。
#
# 私は黄色が好きだ。
#
# 食物繊維を摂ると、腸が掃除される。
#
# セロリやゴボウを食べると、腸が掃除される。
#
# 彼はハト派だ。
#
# 彼は争いを好まない。
#
# 勉強すればいい大学に入れる。
#
# いい大学とそうでない大学がある。
#
# 街路樹のイチョウが色づいた。
#
# 街路樹のイチョウの葉が黄色くなった。
#
# 紅葉が色づいた。
#
# 紅葉の葉が赤くなった。
#
# 彼は大きい動物は何でも好きだ。
#
# 彼は象が好きだ。
#
# 彼女は酸っぱいものは何でも嫌いだ。
#
# 彼女は梅干が嫌いだ。
#
# 彼は甘いものは何でも好きだ。
#
# 彼はチョコレートが好きだ。
#
# お腹は時計回りにさするといい。
#
# お腹は反時計回りにさするといい。
#
# この道は私道だ。
#
# この道は国道だ。
#
# インドゾウとアフリカゾウのどこが違うか教えて下さい。
#
# インドゾウとアフリカゾウはそっくりだ。
#
# カリフォルニアはアメリカの西海岸にある。
#
# カリフォルニアはアメリカの東海岸にある。
#
# 現金は流動資産だ。
#
# 現金は固定資産だ。
#
# 太郎と花子は婚姻届を提出した。
#
# 太郎と花子は離婚届を提出した。
#
# 東洋には尺という単位があった。
#
# 西洋には尺という単位があった。
#
# 彼はハト派だ。
#
# 彼はタカ派だ。
#
# 彼女は母親似の目の大きな子だった。
#
# 彼女は父親にも似ている。
#
# 明日は日本の海上に低気圧が進んでくる。
#
# 明日は日本の海上に中気圧が進んでくる。
#
# 国民は教育を受ける義務がある。
#
# 国民は教育を受ける権利がある。
#
# 埼玉は東京の北に位置する。
#
# 東京は埼玉の南に位置する。
#
# 昔は天動説が信じられていた。
#
# 今は地動説が信じられている。
#
# 部下のミスをかぶって退職することになった。
#
# 自分は上司である。
#
# あの人は概念的なことばかり言う。
#
# あの人は客観的なことをあまり言わない。
#
# あの人は概念的なことばかり言う。
#
# あの人は具体的なことをあまり言わない。
#
# 竹取の翁はかぐや姫の養い親だ。
#
# かぐや姫は竹取の翁の養女だ。
#
# 集合時間10分前だ。
#
# 集合時間は10分後だ。
#
# 近くが見えて遠くが見えないのが近視である。
#
# 近くが見えなくて遠くが見えるのが遠視である。
#
# 日本の家庭から円卓が姿を消した。
#
# 日本の食卓は角形が主流になった。
#
# 女を殴る男は最低だ。
#
# 女は男を殴らない。
#
# 男性であるなら、女性を守らなければならない。
#
# 女性を守らなくてはならないのが、男性である。
#
# 埼玉は東京の北に位置する。
#
# 東京は埼玉の西に位置する。
#
# 埼玉は東京の北に位置する。
#
# 東京は埼玉の東に位置する。
#
# オタマジャクシはカエルの子である。
#
# カエルはオタマジャクシの親である。
#
# 花子は順子の姉だ。
#
# 順子は花子の妹だ。
#
# 紅組が白組に不戦勝した。
#
# 白組は紅組に不戦敗した。
#
# 太郎は次郎の兄だ。
#
# 次郎は太郎の弟だ。
#
# 彼は、僕より上手だ。
#
# 僕は彼より下手だ。
#
# 郵便局は銀行の左隣りにあります。
#
# 銀行は郵便局の右隣りにあります。
#
# 郵便局は銀行の先にあります。
#
# 銀行は郵便局の手前にあります。
#
# 日本は製品を輸出入している。
#
# 外国は製品を輸入する。
# 外国は製品を輸出する。
#
# あの店は創業300年の老舗だ。
#
# あの店は歴史が浅い。
#
# つくしが出た。
#
# 夏まっさかりだ。
#
# ショッピングに行こう。
#
# 家を買う。
#
# デッドボールだった。
#
# バスケットをしている。
#
# トンガは王国だ。
#
# トンガには王がいない。
#
# マニキュアを塗った。
#
# 顔の化粧をした。
#
# 花屋さんでは花を売っている。
#
# 八百屋さんでは八百を売っている。
#
# 花子の夢は宇宙飛行士になることです。
#
# 花子は眠っている。
#
# 絵画コンクールで佳作をとった。
#
# 一番いい賞をとった。
#
# 銀婚式を迎えた。
#
# 銀色の衣裳を着て式を行う。
#
# 銀婚式を迎えた。
#
# 結婚してまだ10年だ。
#
# 空に鰯雲がある。
#
# 秋は空に魚がいる。
#
# 甲子園は準決勝を迎えた。
#
# 8チームが残っている。
#
# 今年は戌年だ。
#
# 去年は未年だ。
#
# 桜の花が散ってしまった。
#
# 春が終わった。
#
# 子会社へ出向することになった。
#
# 会社は子どもが経営している。
#
# 私の夢は学校の先生になることです。
#
# 私は眠っていた。
#
# 私は正義感が強い。
#
# 私はウルトラマンだ。
#
# 若さだけを武器にして戦ってきた。
#
# 若さは人を殺す。
#
# 衆議院には解散がある。
#
# 内閣が総辞職する。
#
# 春分の日と秋分の日は昼と夜の時間が同じだ。
#
# 夏至は昼の時間が一番長い。
#
# 春分の日と秋分の日は昼と夜の時間が同じだ。
#
# 冬至は昼の時間が一番短い。
#
# 暑いから、帽子をかぶって行きなさい。
#
# 帽子は女性である。
#
# 床屋さんに行った。
#
# 車を洗った。
#
# 酢が体にいいともてはやされている。
#
# 酢はアルカリ性だ。
#
# 昔は天動説が信じられていた。
#
# 宇宙は私を中心にまわっている。
#
# 相撲を見た。
#
# 中国の国技を見た。
#
# 太郎の夢はお医者さんになることです。
#
# 太郎は眠っている。
#
# 端午の節句をした。
#
# 女児がいる。
#
# 二人は無理心中した。
#
# 二人は自殺した。
#
# 彼は甘党だ。
#
# 彼は政治家だ。
#
# 彼は倹約家だ。
#
# 彼は浪費する。
#
# 彼は殺人で現行犯逮捕された。
#
# 彼は人を殺したかもしれない。
#
# 彼は子煩悩だ。
#
# 彼は仏教徒だ。
#
# 布団を天日乾しした。
#
# 干物を作った。
#
# 聞き手の手は人を意味する。
#
# 利き手の手は人を意味する。
#
# オムレツを作った。
#
# フライパンを使った。
#
# サラダを食べた。
#
# 生野菜を食べた。
#
# 私の母語は日本語だ。
#
# 私は日本人だ。
#
# 太郎と花子は夫婦だ。
#
# 花子は太郎を愛している。
#
# 太郎と花子は夫婦だ。
#
# 太郎は花子を愛している。
#
# 聞き手の手は人を意味する。
#
# 話し手の手は人を意味する。
#
# あの人は呼吸器専門医だ。
#
# あの医者の専門は呼吸器だ。
#
# あの人は盲導犬を連れている。
#
# あの人は目の障害がある。
#
# あの木の下に立っている人は陽子です。
#
# あの木の下に立っている人は、女性です。
#
# うちの家系は姉妹ばかりだ。
#
# うちは女家系だ。
#
# このソフトはシェアウェアです。
#
# お金を払わなければ、このソフトは使えない。
#
# ごみを分別回収してのリサイクル活動が盛んだ。
#
# ごみは再生利用できる。
#
# ご来光を見に行った。
#
# 山に登った。
#
# つくしが出た。
#
# 春だ。
#
# エベレストは一番高い山である。
#
# どの山もエベレストより低い。
#
# エベレストは一番高い山である。
#
# エベレストより高い山はない。
#
# オール電化の家が増えてきた。
#
# ガスは使わない。
#
# オムレツを作った。
#
# 卵を使った。
#
# オリオン座は冬の星座である。
#
# 夏の夜空では見えない。
#
# キュウリの糠漬けを食べた。
#
# キュウリを糠に漬けた。
#
# キュウリの糠漬けを食べた。
#
# キュウリを食べた。
#
# サラダを食べた。
#
# 野菜を食べた。
#
# セミが鳴いている。
#
# 夏である。
#
# チャーハンを作った。
#
# 炊いた米を炒めた。
#
# チョコレート工場の見学に行った。
#
# 工場ではチョコレートを作っている。
#
# デッドボールだった。
#
# 当たったのはボールである。
#
# デッドボールだった。
#
# 当てたのはピッチャーである。
#
# デッドボールだった。
#
# 当てられたのはバッターである。
#
# デッドボールだった。
#
# 野球をしている。
#
# トムヤムクンを食べた。
#
# エビを食べた。
#
# トンガは王国だ。
#
# トンガには国王がいる。
#
# トンガは王国だ。
#
# トンガは国である。
#
# ハマチは成長するとブリと呼ばれる。
#
# ブリは出世魚である。
#
# ピラフを作った。
#
# 炒めた米を炊いた。
#
# 移動教室で日光に行った。
#
# 学校で日光に行った。
#
# 花子は臨月だ。
#
# 花子は妊娠している。
#
# 外来生物のアライグマが増えて、困っている。
#
# アライグマは元々日本にいなかった。
#
# 銀婚式を迎えた。
#
# 結婚して25年になる。
#
# 空に鰯雲がある。
#
# 秋である。
#
# 蛍が飛んでいる。
#
# きれいな水がある。
#
# 蛍が飛んでいる。
#
# カワニナがいる。
#
# 健作の配偶者は、そのときまだ二十歳だった。
#
# 健作は男性である。
#
# 国立科学博物館に行った。
#
# 博物館は国営である。
#
# 今年の初冠雪は、去年より10日早かった。
#
# 山で今年初めて雪が降った。
#
# 今年は厄年だから、災難に遭わないように注意する。
#
# 厄年とされる歳がある。
#
# 妻のつわりが軽くて助かっています。
#
# 妻は妊娠している。
#
# 埼玉は内陸に位置する。
#
# 埼玉は海に面していない。
#
# 朔太郎の遺言で、遺産は寄付された。
#
# 朔太郎は死んだ。
#
# 朔太郎の遺言で、遺産は寄付された。
#
# 朔太郎は死亡した。
#
# 枝豆を食べた。
#
# 大豆を食べた。
#
# 私は502号室に住んでいる。
#
# 私の家は集合住宅だ。
#
# 私はブラックでコーヒーを飲む。
#
# 砂糖とミルクが入っていない。
#
# 失恋には免疫がある。
#
# 失恋したことがある。
#
# 十の位が八、一の位が九だ。
#
# 八十九だ。
#
# 食物としての芋より、植物としての芋に興味がある。
#
# 芋は植物であり、そして食物である。
#
# 聖火がイタリアについた。
#
# オリンピックがイタリアで行われる。
#
# 千羽鶴を折った。
#
# 折り紙をした。
#
# 祖母は教師だった。
#
# 父の母か、母の母が教師だった。
#
# 総選挙がある。
#
# 衆議院が解散した。
#
# 代金はいつお支払いすればよろしいですか。
#
# 物品を購入した。
#
# 大学院の入学試験がある。
#
# 大学院へ行くには試験を受けなければならない。
#
# 大潮は、満月と新月の時に起こる。
#
# 大潮には、太陽と月の引力が関係している。
#
# 端午の節句をした。
#
# 男児がいる。
#
# 竹内結子は妊娠３カ月である。
#
# 竹内結子は妊娠している。
#
# 長野は内陸に位置する。
#
# 長野は海に面していない。
#
# 庭いじりをした。
#
# 庭がある。
#
# 日米首脳会談が京都で行われた。
#
# 日本の首相とアメリカ合衆国の大統領が京都で会談した。
#
# 年賀はがきを買った。
#
# 年末になった。
#
# 畑仕事をした。
#
# 畑がある。
#
# 彼はベジタリアンだ。
#
# 彼は植物性食品を食べる。
#
# 彼は甘党だ。
#
# 彼は甘いものが好きだ。
#
# 彼は倹約家だ。
#
# 彼はお金を節約する。
#
# 彼は子煩悩だ。
#
# 彼は我が子をとても可愛がっている。
#
# 彼は日本語の研究が仕事だ。
#
# 彼は日本語学の研究者だ。
#
# 彼女はバイリンガルだ。
#
# 彼女は2ヵ国語を話せる。
#
# 避難訓練があった。
#
# 災害時を想定している。
#
# 夫としての彼より、父親としての彼を愛している。
#
# 彼は夫であり、そして父親である。
#
# 夫は会社員です。
#
# 私は妻である。
#
# 父の母は、教師だった。
#
# 祖母は教師だった。
#
# 父は還暦を迎えた。
#
# 父は年男である。
#
# 本場のコアラを見て来た。
#
# オーストラリアに行った。
#
# 本場のパンダを見て来た。
#
# 中国に行った。
#
# 漫画が実写化される。
#
# 漫画は絵で描かれている。
#
# 娘は、さかあがりを練習している。
#
# 娘は鉄棒を練習している。
#
# 明日から二学期だ。
#
# 明日から学校が始まる。
#
# 明日は立秋だ。
#
# 暦上では秋になる。
#
# 要求を箇条書きにする。
#
# 要求は複数ある。
#
# あの人は呼吸器専門医だ。
#
# あの人は呼吸器が好きだ。
#
# 角館はみちのくの小京都である。
#
# 角館は京都に似ている。
#
# 今は梅雨だ。
#
# 明日も雨だろう。
#
# 今日は浴衣姿の人が多い。
#
# 花火大会がある。
#
# 私の母語は英語だ。
#
# 私は英国人だ。
#
# 私の夢は学校の先生になることです。
#
# 私は子どもが好きである。
#
# 私の夢は学校の先生になることです。
#
# 私は若い。
#
# 真樹は結婚した。
#
# 真樹は女性である。
#
# 真樹は結婚した。
#
# 真樹は男性である。
#
# 祖母は教師だった。
#
# 父の母は、教師だった。
#
# 普段はスカートははかない。
#
# 私は男性だ。
#
# 返却された本に書き込みがあったので消した。
#
# その本は図書館の本だ。
#
# 優しい息子がいて、私は幸せだわ。
#
# 私は男性である。
#
# つくしが出た。
#
# スギナが出てくる。
#
# インスタント食品で済ませる。
#
# 食事を簡単に済ませる。
#
# オール電化住宅が増えている。
#
# 住宅の全てのエネルギー源は電気である。
#
# コスモスが咲いた。
#
# 秋が近づいてきた。
#
# スイカのおいしい季節だ。
#
# 夏である。
#
# タロウは隠語でゴキブリのことだ。
#
# ゴキブリと言うのがはばかられるときがある。
#
# デッドボールだった。
#
# バッターは出塁する。
#
# ビキニを着るほどの気合いはない。
#
# 気合いには度合いがある。
#
# ポルトガルワインを飲んだ。
#
# ポルトガル産でないワインもある。
#
# ワンワンがいる。
#
# ワンワンは犬のことだ。
#
# 胃が痛い。
#
# 腹痛だ。
#
# 渦中の人にインタビューしている。
#
# 何か問題が起きている。
#
# 英外相がブラジル外相に謝罪した。
#
# 各国に外相がいる。
#
# 王妃に男の子が生まれた。
#
# 王子が生まれた。
#
# 花屋さんでは花を売っている。
#
# パン屋さんではパンを売っている。
#
# 花屋さんでは花を売っている。
#
# 八百屋さんでは野菜を売っている。
#
# 花子の夢は宇宙飛行士になることです。
#
# 花子は子どもだ。
#
# 各地で花火大会が開催されている。
#
# 夏である。
#
# 残暑見舞が届いた。
#
# 暦の上では秋である。
#
# 私の目標は花壇を花でいっぱいにすることです。
#
# 花壇は、まだ花でいっぱいではない。
#
# 首相官邸の主が倒れた。
#
# 総理大臣が倒れた。
#
# 秋は行楽シーズンだ。
#
# 秋はでかけるのにちょうど良い気候だ。
#
# 焼き芋を食べた。
#
# サツマイモを食べた。
#
# 太郎と花子は婚姻届を提出した。
#
# 太郎は花子を愛している。
#
# 太郎には子供が二人いる。
#
# 太郎には家庭がある。
#
# 太郎には子供が二人いる。
#
# 太郎は成人している。
#
# 太郎には子供が二人いる。
#
# 太郎は大人である。
#
# 太郎の夢はお医者さんになることです。
#
# 太郎はまだ若い。
#
# 太郎は、握力がクラスで一番だった。
#
# 太郎は、クラスの誰よりも握力が強い。
#
# 田村大尉は失踪した。
#
# 田村氏は軍人である。
#
# 田中元首相は会議中だ。
#
# 田中元氏は首相である。
#
# 田中元首相は会議中だ。
#
# 田中氏は以前総理大臣だった。
#
# 電車には、弱冷房車輛がある。
#
# 電車は冷房が効いている。
#
# 都民税を払った。
#
# 東京都に住んでいる。
#
# 道に迷ったので、地図を見た。
#
# 地図には道が書いてある。
#
# 白石さんに、「本学の知名度、好感度を高めた」と学長から感謝状が贈られた。
#
# 白石さんは、大学に勤めている。
#
# 彼はベジタリアンだ。
#
# 彼は肉は食べない。
#
# 彼は子煩悩だ。
#
# 彼は子どもが好きだ。
#
# 優しい息子がいて、私は幸せだわ。
#
# 私は女性である。
#
# 流氷が接岸した。
#
# 春が近づいてきた。
#
# 鈴木花子が婚約記者会見をした。
#
# 鈴木花子の婚約に興味のある人がたくさんいる。
#
# 鈴木花子が婚約記者会見をした。
#
# 鈴木花子は婚約した。
#
# 鈴木花子が婚約記者会見をした。
#
# 鈴木花子は有名人である。
#
# 泰子からお土産をもらったが、日本にはない珍しいものだった。
#
# 泰子は海外旅行に行っていた。
#
# 冬季オリンピックがトリノで開催される。
#
# 夏季オリンピックが開催されるのは2年後である。
#
# 英会話スクールが無料体験チケットを配布している。
#
# 無料でダンスが習える。
#
# 花子は娘に家事を手伝うように言った。
#
# 花子は子どもである。
#
# 事故で31人が死亡した。
#
# けが人も多数出た。
#
# タンスを捨てるにはお金がかかる。
#
# 粗大ごみを捨てるのは有料である。
#
# メルマガを読んだ。
#
# パソコンを持っている。
#
# 真樹は勇次と離婚した。
#
# 真樹は男性である。
#
# 真樹は勇次と離婚した。
#
# 真樹は女性である。
#
# テーブルマナーを知っておくべきだった。
#
# フルコースを食べている。
#
# インスタント食品で済ませる。
#
# 手間暇をかけた。
#
# 来年二十歳になる。
#
# 被選挙権が与えられる。
#
# 佐藤夫妻は25回目の結婚記念日を迎えた。
#
# 佐藤夫妻は銀婚式を迎えた。
#
# このソフトはシェアウェアです。
#
# このソフトは着心地がいい。
#
# ご来光を見に行った。
#
# 光がやって来た。
#
# もうすぐ三歳です。
#
# もうすぐ万歳です。
#
# アイスを食べた。
#
# 椅子を食べた。
#
# ウーロン茶を飲んだ。
#
# セイロン茶を飲んだ。
#
# ウーロン茶を飲んだ。
#
# 玉露茶を飲んだ。
#
# ウーロン茶を飲んだ。
#
# 紅茶を飲んだ。
#
# ウーロン茶を飲んだ。
#
# 緑茶を飲んだ。
#
# ウインドーショッピングに行こう。
#
# 窓を買いに行こう。
#
# ウナギが食べたい。
#
# サナギが食べたい。
#
# セミが鳴いている。
#
# ネコが鳴いている。
#
# トラックを走った。
#
# ダンプカーを走った。
#
# ポスト小泉はだれだろうか?
#
# 小泉の郵便係はだれだろうか?
# モノレールで駅前の開発が進んだ。
#
# モノで駅前の開発が進んだ。
#
# レシピを見ながらパエリアを作った。
#
# 処方箋を見ながらパエリアを作った。
#
# 運動会で一等賞をとった。
#
# 研究発表で一等賞をとった。
#
# 寒くても痩せ我慢をした。
#
# 私は痩せている。
#
# 眼下に絶景がひろがっていた。
#
# 眼下に壮絶な光景があった。
#
# 今年の収支決算は黒だった。
#
# 今年の収支決算は怪しい。
#
# 姉は今留守です。
#
# 姉は今います。
#
# 私の弟はコンピューターサイエンティストです。
#
# 私の弟は心理学者です。
#
# 私はいつも姉のお下がりばかりだ。
#
# 私はいつも姉にぶら下がっている。
#
# 私は涙顔になった。
#
# 私の顔は涙になった。
#
# 事件は迷宮入りだ。
#
# 事件は、解決した。
#
# 次郎はテストで100点をとった。
#
# 次郎はテストで赤点をとった。
#
# 首相は玉虫色の発言が多い。
#
# 首相の発言は光っている。
#
# 宿屋に泊まった。
#
# ホテルに泊まった。
#
# 食後にケーキを食べた。
#
# 食後に景気を食べた。
#
# 性愛の悦楽に溺れる。
#
# 海で溺れる。
#
# 太郎はナーバスだ。
#
# 太郎は無神経だ。
#
# 日本の通貨は、円である。
#
# 日本の通貨は丸い。
#
# 彼は、映画化された作品をいくつももつ、売れっ子の小説家だ。
#
# 彼は書家だ。
#
# 彼はリンゴが好きだ。
#
# 彼はミカンが好きだ。
#
# 彼はリンゴが好きだ。
#
# 彼は梨が好きだ。
#
# 彼は倹約家だ。
#
# 彼はけちだ。
#
# 百貨店に行った。
#
# スーパーに行った。
#
# 陽子は昇給した。
#
# 陽子は昇級した。
#
# お冷やをください。
#
# お水をください。
#
# 子どもの面倒をみる。
#
# 子どもの世話をする。
#
# 宿屋に泊まった。
#
# 旅館に泊まった。
#
# お相撲さんを見た。
#
# 力士を見た。
#
# お豆腐を食べた。
#
# 豆腐を食べた。
#
# この商品は20%引きだ。
#
# この商品は二割引きだ。
#
# この製品は廃番になる。
#
# この製品は製造されなくなる。
#
# この本はベストセラーだ。
#
# この本は売れ行きがよい。
#
# ご来光を見に行った。
#
# 日の出を見に行った。
#
# せっかくの苦労も水の泡になった。
#
# 苦労も無駄になった。
#
# むすびを食べた。
#
# おにぎりを食べた。
#
# もみじ狩りに行った。
#
# 紅葉を見に行った。
#
# アイスを食べた。
#
# アイスクリームを食べた。
#
# アキバがTDLを超える集客力だそうだ。
#
# 秋葉原が東京ディズニーランドを超える人出だそうだ。
#
# インフルエンザの予防接種をした。
#
# インフルエンザの注射をした。
#
# ウーロン茶を飲んだ。
#
# 烏龍茶を飲んだ。
#
# キャッチボールは和製英語だ。
#
# キャッチボールは日本で作った英語だ。
#
# クローン犬が誕生した。
#
# 同じ遺伝子を持った犬が誕生した。
#
# スペインでは干ばつに悩まされている。
#
# スペインでは水不足に悩まされている。
#
# セミが鳴いている。
#
# 蝉が鳴いている。
#
# ナイアガラ大瀑布を見に行った。
#
# ナイアガラの滝を見に行った。
#
# ニートが増えて困っている。
#
# 無職、無業者が増えて困っている。
#
# 丑三つ時になった。
#
# 午前二時過ぎになった。
#
# 歌を詠んだ。
#
# 和歌を詠んだ。
#
# 懐かしい顔がそろった。
#
# 懐かしい人がそろった。
#
# 海難審判法は1947年に制定された。
#
# 海難審判法は昭和22年に制定された。
#
# 各党のマニフェストが出された。
#
# 各党の選挙公約が出された。
#
# 今日はみどりの日だ。
#
# 今日は4月29日だ。
#
# 今年の収支決算は黒だった。
#
# 利益が出た。
#
# 最近、オタク系が注目されている。
#
# オタクと呼ばれる人達が注目されている。
#
# 最近、残業が多い。
#
# 時間外労働をしている。
#
# 最近は、晴雨兼用の傘がある。
#
# 晴れでも雨でも使える傘がある。
#
# 在日米軍の総司令部は東京の横田基地にある。
#
# 日本には米軍が駐留している。
#
# 産学共同で開発を行なう。
#
# 大学や研究期間と企業が一緒に開発を行なう。
#
# 姉は今留守です。
#
# 姉は今不在です。
#
# 私はいつも姉のお下がりばかりだ。
#
# いつも姉の着た洋服ばかり着ている。
#
# 私は妻の両親を新居に招いた。
#
# 私は義理の父母を新居に招いた。
#
# 床屋さんに行った。
#
# 理髪店に行った。
#
# 心の洗濯をした。
#
# 気分の転換を図った。
#
# 成人を迎えた。
#
# 二十歳になった。
#
# 台所で母が叫んでいる。
#
# キッチンで母が叫んでいる。
#
# 台風７号が発生し、日本に接近の恐れ。
#
# 台風７号は日本にくるかもしれない。
#
# 調理器具を集めるのが好きです。
#
# キッチンツールを集めるのが好きです。
#
# 彼には文才がある。
#
# 彼は文章を書くのが上手い。
#
# 彼はリンゴが好きだ。
#
# 彼は林檎が好きだ。
#
# 彼は会社に対して背任行為をした。
#
# 彼は任務にそむいた。
#
# 百貨店に行った。
#
# デパートに行った。
#
# 百貨店に行った。
#
# 小売り店に行った。
#
# 夫は獄中にいる。
#
# 夫は刑務所にいる。
#
# 名前順に並ぶ。
#
# アイウエオ順に並ぶ。
#
# 名前順に並ぶ。
#
# 五十音順に並ぶ。
#
# 両陛下は、ヨーロッパを訪問された。
#
# 天皇と皇后さまがヨーロッパを訪問された。
#
# にぎりを食べた。
#
# おにぎりを食べた。
#
# アイスを食べた
#
# 氷を食べた。
#
# 御利益がありますようにとお願いした。
#
# もうけがありますようにとお願いした。
#
# 今日は節分だ。
#
# 今日は2月3日だ。
#
# 彼は、映画化された作品をいくつももつ、売れっ子の小説家だ。
#
# 彼は実力派の小説家だ。
#
# あの人は概念的なことばかり言う。
#
# あの人は抽象的なことばかり言う。
#
# お加減はいかがですか。
#
# お身体の具合はいかがですか。
#
# ランチを食べに行った。
#
# 昼食を食べに行った。
#
# ワンワンがいる。
#
# 犬がいる。
#
# 宴会があるから、遅くなるよ。
#
# 飲み会があるから、遅くなるよ。
#
# 化粧室に行く。
#
# トイレに行く。
#
# 何度ノックをしても返事がない。
#
# 何度ノックをしても応答がない。
#
# 花子は臨月だ。
#
# 花子は出産間近だ。
#
# 私はシングルだ。
#
# 私は独身だ。
#
# 首相は玉虫色の発言が多い。
#
# 首相の発言はいかようにも解釈できる。
#
# 彼のお荷物にならないように、一生懸命働いた。
#
# 彼の負担にならないように、一生懸命働いた。
#
# 彼女はおめでただ。
#
# 彼女は妊娠した。
#
# 夫が風邪をひいた。
#
# 主人が風邪をひいた。
#
# NPOが増えている。
#
# ウイルスが増殖している。
#
# 鏡開きをした。
#
# ドレッサーを見た。
#
# 通勤電車で痴漢にあった。
#
# 通勤電車で愚か者にあった。
#
# 衆院選に出馬する。
#
# 衆議院議員選挙に立候補する。
#
# 梅酒を飲んだ。
#
# ウメ酒を呑んだ。
#
# 父は還暦を迎えた。
#
# 父は60歳になった。
#
# 薬を飲むと眠くなるのが欠点だ。
#
# 薬の副作用は眠くなることだ。
#
# 構内は禁煙です。
#
# 構内でたばこを吸ってはいけない。
#
# にぎりを食べた。
#
# にぎり寿司を食べた。
#
# 納品書を見ながら検品した。
#
# 納品伝票を見ながら納入品を検品した。
#
# せっかくの苦労も水の泡になった。
#
# 苦労が水泡になった。
#
# アワビの密漁団が逮捕された。
#
# アワビは山に生息している。
#
# 一郎の上司は寛大な人だ。
#
# 一郎は社長だ。
#
# 果物の王様はドリアンか、ランブータンか?
#
# ランブータンは野菜である。
#
# 私の従妹は長野にいる。
#
# 父にも母にも兄弟がいない。
#
# 私はトルストイの小説を読んだ。
#
# 私はフランス文学を読んだ。
#
# 時計の針が止まった。
#
# 時計はデジタル時計だ。
#
# 太郎の妹なのに花子は美人だ。
#
# 花子は一人っ子である。
#
# 東京は日本の首都である。
#
# 日本は都市である。
#
# 飛行機のチケットを買った。
#
# 私はスチュワーデスだ。
#
# うちの棟梁は厳しい。
#
# 私は大工だ。
#
# この店のショコラティエは有名だ。
#
# この店はチョコレートを売っている。
#
# エベレストの登頂に成功した。
#
# エベレストは山である。
#
# ジョンの妻は歌手だ。
#
# ジョンは既婚だ。
#
# ティラナはアルバニアの首都である。
#
# アルバニアは国である。
#
# ティラナはアルバニアの首都である。
#
# ティラナは都市である。
#
# 花子の甥はこの春大学に入学する。
#
# 花子には兄妹がいる。
#
# 花子の兄は医者だ。
#
# 花子には兄弟がいる。
#
# 花子は姉だ。
#
# 花子には兄妹がいる。
#
# 角館はみちのくの小京都である。
#
# 角館は東北にある。
#
# 月は地球の衛星である。
#
# 月は地球の周りにある。
#
# 今日の朝刊はどこにある?
#
# 今朝の新聞はどこにある?
# 生徒の指導は難しい。
#
# 私は教師だ。
#
# 東京は日本の首都である。
#
# 東京は都市である。
#
# 東京は日本の首都である。
#
# 日本は国である。
#
# 彼は、おかずを巡る喧嘩から妻を殺害した。
#
# 彼は夫婦喧嘩をした。
#
# この麺は米の粉でできている。
#
# この麺はビーフンである。
#
# 時計の針が止まった。
#
# 時計はアナログ時計だ。
#
# 彼女は歌の詞を専門に書いている。
#
# 彼女は作詞家だ。
#
# 隣の国はメキシコだ。
#
# この国はアメリカ合衆国だ。
#
# 夫が風邪をひいた。
#
# 私は妻である。
#
# 野性化したアライグマの被害に農家は困っている。
#
# アライグマが農作物を荒らしている。
#
# この小説の冒頭の雨の描写は、その後の展開を暗示している。
#
# この小説は『雪国』である。
#
# このポスターはデザインがいい。
#
# センスがない。
#
# 旺盛な食欲はとどまるところを知らなかった。
#
# 食欲は知ることができる。
#
# 化粧は女を化かす。
#
# 化粧は恐ろしい。
#
# 街路樹のイチョウが色づいた。
#
# 街路樹のイチョウには色が無かった。
#
# 紅葉が色づいた。
#
# 紅葉には色が無かった。
#
# 子育ての大変さを思い知らせたい。
#
# 子育てはできない。
#
# 太郎は花子に銃口を向けた。
#
# 太郎は花子が嫌いだ。
#
# 男は女性をひき逃げした疑いで逮捕された。
#
# 男が女性をひき逃げしたことは間違いない。
#
# 彼はなっていない。
#
# 彼には礼儀を教える必要はない。
#
# この花とあの花は似ている。
#
# この花とあの花は別の花だ。
#
# ものもらいのことを、めばちこと言うこともある。
#
# ものもらいとめばちこは同じものである。
#
# アトラスとマップの違いを説明する。
#
# アトラスとマップは似ている。
#
# コザクラインコはラブバードと言われる。
#
# コザクラインコはラブバードだ。
#
# ブラックバスやブルーギルがフナやタナゴを脅かしている。
#
# 外来種を減らさなければならない。
#
# メアリーはビルをナイフで傷つけた。
#
# ビルは生き延びた。
#
# 田中さんという人が来ました。
#
# 田中さんは知らない人だ。
#
# あまりに眠くて、仕事にならない。
#
# 本当は仕事がしたい。
#
# おたふく風邪の予防接種を受けた。
#
# おたふく風邪にかかると困る。
#
# さっきの交差点を左折した。
#
# さっきの交差点を右折しなかった。
#
# さっきの交差点を左折した。
#
# さっきの交差点を直進しなかった。
#
# だんだん日が短くなってきた。
#
# 夜が長くなる。
#
# イモリは両生類で、ヤモリは爬虫類だ。
#
# イモリとヤモリは姿が似ている。
#
# キノコには毒をもったものがある。
#
# キノコを採るときには注意するほうがいい。
#
# キャンペーン中なので、ポイントが二倍付く。
#
# キャンペーンでないときも、ポイントが貯まる。
#
# ショッピングに行こう。
#
# 物を買うつもりがある。
#
# タラバガニはカニに似ているが、海産のヤドカリの一種である。
#
# タラバガニはカニではない。
#
# ハマチは成長するとブリと呼ばれる。
#
# ハマチとブリは同じ魚である。
#
# マツバガニをズワイガニというところもある。
#
# マツバガニとズワイガニは同じカニである。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 運転免許を持っていても、車の運転ができない人がいる。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 車の運転ができる人だけが運転免許を持っているわけではない。
#
# 源氏物語は日本を代表する文学作品のひとつだ。
#
# 日本を代表する文学作品はたくさんある。
#
# 紅茶と緑茶は同じ茶葉から作られる。
#
# 紅茶と緑茶は製法が違う。
#
# 今夜はカレーにしてほしい。
#
# カレーが食べたい。
#
# 初もうでに行って商売繁盛を祈願した。
#
# 商売は繁盛した方がよい。
#
# 食物としての芋より、植物としての芋に興味がある。
#
# 食物としての芋には興味がない。
#
# 耐震基準を満たしていないマンションがあることが発覚した。
#
# 地震で倒壊する恐れがある。
#
# 著作権に詳しい弁護士に相談する。
#
# 著作権に詳しくない弁護士もいる。
#
# 長期の休暇には実家に帰省することが多い。
#
# 長期の休暇でも実家に帰省しないこともある。
#
# 鳥インフルエンザが発生した。
#
# 蔓延を防ぐ必要がある。
#
# 党首が全国を遊説する。
#
# 多くの国民に党の主張を聞いてもらう。
#
# 日本の大部分は温暖湿潤気候に分類される。
#
# 日本には、温暖湿潤気候に分類されないところがある。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本語を話しても、日本人でない場合がある。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本人だけが日本語を話すわけではない。
#
# 年下は恋愛の対象にならない。
#
# 同年齢以上しか恋愛の対象にならない。
#
# 年下は恋愛の対象にならない。
#
# 同年齢以上だけ恋愛の対象になる。
#
# 毎日のように缶コーヒーを飲んでいる。
#
# 缶コーヒーを飲まない日もある。
#
# 野生のサル生息の最北限は、下北半島である。
#
# サルはあまり寒いところには住めない。
#
# 養蚕業の衰退は著しい。
#
# かつて養蚕業は盛んだった。
#
# 朗報を待っている。
#
# 悪い知らせは期待していない。
#
# 老人ホームが次々に開所している。
#
# 需要がある。
#
# あいつとは波長が合わない。
#
# あいつが嫌いだ。
#
# あの人は、手広く商売をしている。
#
# あの人は商い上手だ。
#
# あの人は腕に包帯を巻いている。
#
# 病院で治療を受けている。
#
# お香を焚いたら、リラックスした。
#
# お香には癒し効果がある。
#
# インドゾウとアフリカゾウのどこが違うか教えて下さい。
#
# インドゾウとアフリカゾウは似ている。
#
# 亜硫酸の生成方法を教えられた。
#
# 教えられなくても知っていた。
#
# 何事もやり過ぎは良くない。
#
# さじ加減が必要だ。
#
# 寒くても痩せ我慢をした。
#
# 私にもプライドがある。
#
# 食玩が流行っている。
#
# 食品を買う人の目的はおまけである。
#
# 太郎は花子にに銃口を向けた。
#
# 花子は殺される。
#
# 二十四時間三交替勤務が辛くて、仕事をやめた。
#
# 仕事は嫌いだ。
#
# 年下は恋愛の対象にならない。
#
# 恋愛の対象を年齢で限定している。
#
# 発表の出番が近づき、ドキドキしてきた。
#
# 発表するのが嬉しい。
#
# 老人ホームが次々に開所している。
#
# 家庭事情がある。
#
# この幸福は永遠に続くものと思っていた。
#
# 幸福は永くは続かなかった。
#
# この成分が胃酸の働きを助ける。
#
# 胃酸はよく働いた方がいい。
#
# この部屋はクーラーが効いている。
#
# 外は暑い。
#
# アメリカで過去最大のハリケーンが発生した。
#
# 被害が出るだろう。
#
# インドア派なのでキャンプなんてもってのほかだ。
#
# インドア派は普通キャンプに行かない。
#
# ウインドーショッピングに行こう。
#
# 物を買うつもりはない。
#
# チョコレート工場の見学に行った。
#
# 工場はチョコレートの匂いがする。
#
# テレビで寒天ダイエットについて放映したら、寒天が売り切れた。
#
# テレビの影響は大きい。
#
# プロの音楽家になるつもりはない。
#
# 音楽は趣味として楽しみたい。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 運転免許を持っているひとのほとんどが、車の運転ができる。
#
# 援助交際を略して援交というそうだ。
#
# 「援助交際を略して援交という」とは知らなかった。
#
# 家族はもう寝ていると思っていた。
#
# 家族が起きていた。
#
# 家族はもう寝ていると思っていた。
#
# 家族はまだ寝ていなかった。
#
# 絵画コンクールで佳作をとった。
#
# 絵画コンクールで入賞しなかった。
#
# 蟻が行列を作っている。
#
# 引っ越しをしている。
#
# 健康のために運動は欠かさない。
#
# 運動を欠かすと健康に悪い。
#
# 今日は仕事が全然できなかった。
#
# 今日は仕事をやりたかった。
#
# 産学共同で開発を行なう。
#
# 成果が期待できる。
#
# 私はいつも姉のお下がりばかりだ。
#
# 新しい洋服がいい。
#
# 湿度がカビの増殖を助長する。
#
# カビの増殖は避けたい。
#
# 小泉首相はパフォーマンスが好きだ。
#
# 国民の注目をあびたい。
#
# 食物繊維を摂らないと、体に悪い。
#
# 食物繊維は大切だ。
#
# 食物繊維を摂らないと、体に悪い。
#
# 食物繊維を摂ったほうがいい。
#
# 心の奥底では、彼女を憎んでいた。
#
# 彼女を憎んでいる素振りは見せないようにしていた。
#
# 雪下ろしをする。
#
# 重労働だ。
#
# 選択を誤った。
#
# 後悔している。
#
# 太郎が花子を刺したのは、正当防衛だった。
#
# 太郎が花子を刺したのはやむを得なかった。
#
# 太郎が花子を刺したのは、正当防衛だった。
#
# 太郎が花子を刺したのは当然のことだ。
#
# 虫歯予防のために歯みがきは欠かさない。
#
# 歯みがきを欠かすと虫歯予防に悪い。
#
# 的確な判断で災害の被害を最小に抑えた。
#
# 判断を誤っていたら、被害はもっと拡大していた。
#
# 党首が全国を遊説する。
#
# 党首の力は大きい。
#
# 二十四時間三交替勤務が辛くて、仕事をやめた。
#
# 三交替勤務でなかったら、仕事を続けていた。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本語を話す人のほとんどは日本人である。
#
# 能や歌舞伎は日本の伝統文化である。
#
# 各国ごとに伝統文化がある。
#
# 彼は財産を守るために遺言書を書くことにした。
#
# 彼の財産は危険にさらされている。
#
# 彼女の髪形が変わって、別人のように見える。
#
# 彼女はイメージチェンジした。
#
# 彼女の話は作り話が多い。
#
# 彼女はよく嘘をつく。
#
# 彼女はしたたかだ。
#
# 彼女は何か考えて行動している。
#
# 飛行機が墜落した。
#
# 大惨事になった。
#
# 夫としての彼より、父親としての彼を愛している。
#
# 夫としての彼を愛していない。
#
# 腹筋運動を日課にしている。
#
# 腹筋運動は体にいい。
#
# 卵を割ったら黄身が二つ入っていた。
#
# 珍しい。
#
# 緑に囲まれたマンションに住めてうらやましい。
#
# そのマンションは環境が良い。
#
# 食物繊維を摂らないと、体に悪い。
#
# 食物繊維を摂ると体にいい。
#
# 甲子園は準決勝を迎えた。
#
# あと３試合で優勝が決まる。
#
# 千羽鶴を折った。
#
# 願いが込めてある。
#
# 水痘は、一般にはみずぼうそうと言われている。
#
# みずぼうそうは水痘のことである。
#
# 地震による死者が日に日に増えていっている。
#
# 明日はもっと増える。
#
# 予期していた事態が遂に起った。
#
# こういう事態になることはわかっていた。
#
# 会社に遅刻したが、上司に恩情をかけてもらった。
#
# 上司が遅刻を見逃してくれた。
#
# 受け付けは18時20分までです。
#
# 18時20分を過ぎたら受けつけられない。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# ブラジル人は逃げる必要を感じた。
#
# 笑点は放送が始まってから長い。
#
# 人々に人気がある。
#
# 占いは昔からずっと行われている。
#
# 人は占いを信じている。
#
# 松茸は人工栽培できない。
#
# なかなか手に入らない。
#
# 松茸は人工栽培できない。
#
# 松茸は高価だ。
#
# 今年はサンマが大量に捕れる。
#
# 漁師は漁を制限されて困る。
#
# 海の家ではラーメンがおいしい。
#
# 海の家ではラーメンを食べるのがいい。
#
# 五羽の仔ウサギが産まれて、三羽が死んでしまった。
#
# 二羽の仔ウサギが生きている。
#
# あの人は80歳を過ぎてもピンピンしている。
#
# あの人は背筋が伸びている。
#
# このごろトイレが近くなった。
#
# トイレが近いところにある。
#
# この仕事は精神的にはハードだ。
#
# この仕事は硬い。
#
# この部屋はむしむしする。
#
# この部屋は煙でいっぱいだ。
#
# さっきの交差点を左折した。
#
# さっきの交差点をまっすぐ進んだ。
#
# でんぷんがアルファ化した。
#
# でんぷんがシータ化した。
#
# でんぷんがアルファ化した。
#
# でんぷんがベータ化した。
#
# カレンダーをめくった。
#
# カレンダーを捨てた。
#
# カレンダーをめくった。
#
# メスシリンダーを洗った。
#
# クローン犬が誕生した。
#
# クローンという名の犬が生まれた。
#
# タバコをやめてから、食事がおいしい。
#
# タバコをやめたせいで、食事がおいしい。
#
# タバコを吸っている人が肺癌になる率は高い。
#
# タバコを吸う人は肺癌になりにくい。
#
# ハーブは薬にしたり、料理に使ったり、重宝する。
#
# ハーブは大切な宝だ。
#
# ビルが選ばれると皆が不幸になる。
#
# ビルが選ばれることを皆が望んでいる。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# ブラジル人は物を盗んだ。
#
# プロの音楽家になるつもりはない。
#
# 音楽には興味がない。
#
# 一刻を争っている。
#
# 競争をしている。
#
# 一日をいたずらに過ごした。
#
# いたずらをした。
#
# 一服する。
#
# 忙しくする。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 運転免許を持っている人は、必ず車の運転ができる。
#
# 家出する。
#
# 出家する。
#
# 家電のスイッチを入れたら、主電源が落ちた。
#
# 家電のスイッチを入れたら、主電源が落下した。
# ★
# 開花した。
#
# 花が枯れた。
#
# 外国では生水に気をつけなくてはいけない。
#
# 外国では生水は安全だ。
#
# 街で散財して帰ってきた。
#
# 街で財布を落とした。
#
# 紀宮様が皇室を離れた。
#
# 紀宮様が家出した。
#
# 牛乳と卵と砂糖でプリンを作った。
#
# プリンの原料は牛乳と卵と砂糖だ。
#
# 仰天した。
#
# 天を仰いだ。
#
# 今年の花粉飛散量はひどい。
#
# 今年の花粉飛散量はわからない。
#
# 今年の花粉飛散量はひどい。
#
# 今年の花粉飛散量はゼロだ。
#
# 視力が落ちた。
#
# 視力がつぶれた。
#
# 児童を引率する。
#
# 児童をつれまわしている。
#
# 次回はもうすこし頑張ってください。
#
# 次回はもうすこし我を張ってください。
#
# 衆院選に出馬する。
#
# 私は馬にのる。
#
# 出家する。
#
# 家出する。
#
# 出家する。
#
# 家出する。
#
# 小学校では皆勤賞だったが、中学校は休みまくりだった。
#
# 私は中学校に行かなかった。
#
# 消しゴムがなくなった。
#
# 消しゴムが死んだ。
#
# 新聞社は記者が嘘の記事を書いたことを謝罪した。
#
# 新聞社は記者に謝った。
#
# 太郎の態度はひどい。
#
# 太郎の態度は多い。
#
# 太郎は駅までの道を尋ねられた。
#
# 太郎は駅までの道を聞かれなかった。
#
# 痛恨の一撃を喰らった。
#
# 痛恨の一撃を食べた。
#
# 通勤ラッシュに頭を痛めている。
#
# 頭が痛い。
#
# 道にまよって交番で聞いた。
#
# 路頭に迷った。
#
# 道草を食って、家に帰った。
#
# 道草を食べて、家に帰った。
#
# 鍋は体が温まる。
#
# 鍋は温かい。
#
# 日本は予選を通過したので、ワールドカップに参加できる。
#
# 日本は通り過ぎた。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本語を話す人は日本人である。
#
# 彼は、おかずを巡る喧嘩から妻を殺害した。
#
# おかずはまわっていた。
#
# 彼は再婚した。
#
# 彼は再び後悔した。
#
# 彼は再婚した。
#
# 彼は菜根を食べた。
#
# 彼は退院した。
#
# 彼は仕事を辞めた。
#
# 彼女は御機嫌ななめだ。
#
# 彼女は斜めを向いている。
#
# 彼女は心も美しい。
#
# 彼女は心臓がきれいだ。
#
# 父は顔が広い。
#
# 父は大きい顔をしている。
#
# 仏さまにお線香を上げた。
#
# 仏さまにお線香を下げた。
#
# 仏さまにお線香を上げた。
#
# 仏さまにお線香を渡した。
#
# 北海道の寒さが身にしみた。
#
# 北海道の寒さがこびりついた。
#
# 本に書き込みがあったので消した。
#
# 本を殺した。
#
# 妙な噂をたてられて迷惑している。
#
# 噂が立っていて邪魔だ。
#
# 民家が全焼した。
#
# 全ての民家が燃えた。
#
# どうも具合が悪い。
#
# うまくいっていない。
#
# どうも具合が悪い。
#
# 壊れている。
#
# どうも具合が悪い。
#
# 体調が悪い。
#
# 外国では生水に気をつけなくてはいけない。
#
# 外国では生水は危険だ。
#
# 梅雨なのに雨が降らない。
#
# 空梅雨である。
#
# 両者の実力は伯仲している。
#
# 両者の実力はどっこいどっこいだ。
#
# 両者の実力は伯仲している。
#
# 両者の実力は五分五分だ。
#
# 両者の実力は伯仲している。
#
# 両者の実力は互角だ。
#
# 両者の実力は伯仲している。
#
# 両者の実力は拮抗している。
#
# 「笑点」は放送が始まってから長い。
#
# 「笑点」は長寿番組だ。
#
# おなかがすいた。
#
# おなかが減った。
#
# おなかがすいた。
#
# 空腹だ。
#
# このような書類を鉛筆で書いてくるなんて、信じられない。
#
# このような書類は鉛筆で書くものではない。
#
# この頃トイレが近くなった。
#
# この頃トイレにいく回数が増えた。
#
# この仕事は精神的にハードだ。
#
# この仕事は精神的にきつい。
#
# だんだんと日が短くなってきた。
#
# 冬が近づいてきた。
#
# でんぷんがアルファ化した。
#
# でんぷんが糊化した。
#
# ウイルスに感染した。
#
# ウイルスにやられた。
#
# オタマジャクシがカエルになる。
#
# オタマジャクシがカエルに変化する。
#
# シリアは地中海に面している。
#
# シリアは地中海に接している。
#
# タバコを吸っている人が肺癌になる率は高い。
#
# タバコを吸う人は肺癌になりやすい。
#
# テレビで寒天ダイエットについて放映したら、寒天が売り切れた。
#
# 寒天が完売した。
#
# パンを食べた。
#
# パンが、咀嚼されて、食道を通り、胃に入った。
#
# ビタミンの不足が体調不良を招く。
#
# ビタミンの不足が体調不良を起こす。
#
# ビューラーはまつげをカールさせるための道具だ。
#
# まつげをカールさせる道具をビューラーという。
#
# プロの音楽家になるつもりはない。
#
# 音楽を職業にするつもりはない。
#
# ミャンマーはかつてビルマと呼ばれていた。
#
# ミャンマーはかつてビルマだった。
#
# リャオヤンは中国遼寧省の都市である。
#
# 中国遼寧省にリャオヤンという都市がある。
#
# レバノン山脈とアンチレバノン山脈の間に肥沃なベッカー平原が開けている。
#
# ベッカー平原は、レバノン山脈とアンチレバノン山脈の間に位置する。
#
# 一刻を争っている。
#
# 急いでいる。
#
# 一刻を争っている。
#
# 状況が緊迫している。
#
# 一服する。
#
# 一休みする。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 車を運転できることと、運転免許を持っていることは同じではない。
#
# 何をやっても眠けがとれない。
#
# 何をしても眠い。
#
# 会社を解雇された。
#
# 会社を辞めさせられた。
#
# 皆で合唱した。
#
# みんなで歌を歌った。
#
# 開花した。
#
# 花が咲いた。
#
# 街が雪化粧した。
#
# 街に雪が積もった。
#
# 街で散財して帰ってきた。
#
# お金を使って帰ってきた。
#
# 漢字は表意文字であるが、ローマ字は違う。
#
# 漢字は表意文字であるが、ローマ字は表意文字ではない。
#
# 牛乳と卵と砂糖でプリンを作った。
#
# プリンの材料は牛乳と卵と砂糖だ。
#
# 牛乳と卵と砂糖でプリンを作った。
#
# プリンは、牛乳と卵と砂糖からできている。
#
# 恐竜は絶滅した。
#
# 恐竜はもういない。
#
# 誤解がとけて、楽になった。
#
# 誤解があったが、今は無い。
#
# 交渉が行き詰まった。
#
# 交渉が進まなくなった。
#
# 今日は、生憎の天気だ。
#
# 天気が悪い。
#
# 今年の花粉飛散量はひどい。
#
# 今年の花粉飛散量は多い。
#
# 今年はサンマが大量に捕れる。
#
# 今年はサンマが豊漁だ。
#
# 佐々木容疑者は他に２件の犯行を自供し始めた。
#
# 佐々木は２件の犯行について話しだした。
#
# 債務を果たした。
#
# 借金を返済した。
#
# 山の絵をスケッチした。
#
# 山の絵を描いた。
#
# 紙で鶴を折った。
#
# 折り紙をした。
#
# 実家は菓子の卸問屋を営んでいます。
#
# 実家は菓子の卸問屋だ。
#
# 種が発芽した。
#
# 種が芽を出した。
#
# 従業員を切った。
#
# 従業員を解雇した。
#
# 熟睡した。
#
# よく寝た。
#
# 出家する。
#
# 僧になる。
#
# 食事が多くて食べきれなかった。
#
# 食事を残した。
#
# 製靴工場から出火した。
#
# 製靴工場が火事になった。
#
# 選挙で自民党が圧勝した。
#
# 自民党が大差で勝った。
#
# 選択を誤った。
#
# 選択を間違えた。
#
# 霜柱がたった。
#
# 霜が降りた。
#
# 太郎は越境入学をすることにした。
#
# 太郎は指定された学校ではなくて別の学校に入学する。
#
# 知っている人とすれ違うときには、会釈をするものだ。
#
# 知っている人とすれ違うときには、軽く頭を下げるものだ。
#
# 地下鉄に乗って通勤している。
#
# 電車通勤をしている。
#
# 地球の温暖化が進んでいる。
#
# 地球は温暖化してきている。
#
# 電車が脱線した。
#
# 電車が線路から外れた。
#
# 電車に間に合わなかった。
#
# 電車に乗り遅れた。
#
# 東大の赤門は有名だ。
#
# 赤門は名が知られている。
#
# 道草を食って、家に帰った。
#
# 道草して、家に帰った。
#
# 日本は資源にとぼしい。
#
# 日本は資源が少ない。
#
# 日本は資源にとぼしい。
#
# 日本は資源が豊富にない。
#
# 日本チームは逆転勝ちした。
#
# 日本チームは勝った。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本語を話すことと日本人であることは同じではない。
#
# 麦茶を飲んだ。
#
# 麦茶がノドを通過して胃に入った。
#
# 彼に悩みを打ち明けたのは間違いだった。
#
# 彼に悩みを打ち明けたのは失敗だった。
#
# 彼は寡黙な人だと思われているようだが、そんなことは全然ない。
#
# 彼は寡黙な人ではない。
#
# 彼は講師から助教授になった。
#
# 彼は昇格した。
#
# 彼は再婚した。
#
# 彼は結婚した。
#
# 彼は財産を守るために遺言書を書くことにした。
#
# 彼は財産を守るために遺言書を書く予定だ。
#
# 彼は大往生を遂げた。
#
# 彼は死んだ。
#
# 彼は断トツの人気だ。
#
# 彼の人気は群をぬいている。
#
# 彼は二足のわらじをはいている。
#
# 彼は仕事を掛け持ちしている。
#
# 彼は二足のわらじをはいている。
#
# 彼は二種の仕事をしている。
#
# 彼女の夫はハンサムだ。
#
# 彼女の夫は顔だちがいい。
#
# 彼女はその白い鳥にユキと名付けた。
#
# 彼女は鳥に名前をつけた。
#
# 彼女は御機嫌ななめだ。
#
# 彼女は機嫌が悪い。
#
# 彼女は若くしてこの世を去った。
#
# 彼女は死んだ。
#
# 彼女は退職する。
#
# 彼女は仕事をやめる。
#
# 彼女は退職を決意した。
#
# 彼女は退職するつもりだ。
#
# 飛行機が墜落した。
#
# 飛行機が落ちた。
#
# 風呂から上がった。
#
# 風呂から出た。
#
# 仏さまにお線香を上げた。
#
# 仏壇に線香を焚いて捧げた。
#
# 文章を校正した。
#
# 文章を手直しした。
#
# 盆と正月に帰省する。
#
# 盆と正月に里帰りする。
#
# 毎晩ジョギングをしている。
#
# 毎晩走っている。
#
# 漫画が実写化される。
#
# 漫画を実際の映像にする。
#
# 民家が全焼した。
#
# 民家が燃えた。
#
# 幼虫がさなぎに変わる。
#
# 幼虫はさなぎになる。
#
# 用を足した。
#
# トイレに行った。
#
# 陽子は昇給した。
#
# 陽子の給料があがった。
#
# 卵は、白身の粘度の高さで鮮度がわかる。
#
# 新しい卵は白身の粘度が違う。
#
# 卵は、白身の粘度の高さで鮮度がわかる。
#
# 卵は古くなると白身の粘度が変化する。
#
# 朗報を待っている。
#
# 良い知らせを期待している。
#
# 六本木は国際色豊かだ。
#
# 六本木には色々な国の人がいる。
#
# 髮を切った。
#
# 髮を短くした。
#
# ビタミンの不足が体調不良を招く。
#
# 体調不良はビタミンの不足によるものだ。
#
# 可能ならば、明日来て下さい。
#
# よかったら、明日来て下さい。
#
# 外で食事をする。
#
# 屋外で食事をする。
#
# 外で食事をする。
#
# 別の場所で食事をする。
#
# 交渉が行き詰まった。
#
# 交渉がまとまらなくなった。
#
# 私はかつてでこちゃんと呼ばれていた。
#
# 私はかつてでこちゃんだった。
#
# 足腰が弱ってきた。
#
# 体力が落ちた。
#
# 彼とは相性が悪い。
#
# 彼と仲が悪い。
#
# 彼は肉料理が苦手だ。
#
# 彼は肉料理が好きだ。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女はひらがなとカタカナしか理解できない。
#
# あいつとは波長が合わない。
#
# 意志疎通がうまく行かない。
#
# あの会社は倒産寸前だ。
#
# あの会社は危ない。
#
# あの寿司屋は行列のできる寿司屋として近所で評判だ。
#
# その寿司屋は人気がある。
#
# あの人は、手広く商売をしている。
#
# いろいろな商いをしている。
#
# あの人は、手広く商売をしている。
#
# 商売範囲が広い。
#
# あの人はパチンコ中毒だ。
#
# あの人のパチンコ好きは病的だ。
#
# あの人はパチンコ中毒だ。
#
# あの人はパチンコがやめられない。
#
# あの人はパチンコ中毒だ。
#
# あの人はパチンコばかりやっている。
#
# この仕事をこなす。
#
# この仕事をうまく処理する。
#
# この仕事をこなす。
#
# この仕事をさばく。
#
# この仕事をこなす。
#
# この仕事を切り回す。
#
# やけ酒を飲んだ。
#
# 酒をあおった。
#
# カレンダーをめくった。
#
# カレンダーをはいだ。
#
# ゴリラは絶滅の危機に瀕している。
#
# ゴリラの数が減少している。
#
# ジョギングを始めて2ヶ月だ。
#
# 2ヶ月間、ジョギングを続けている。
#
# ストライプのシャツに水玉模様のネクタイをあわせるなんて、信じられない。
#
# ストライプのシャツに水玉模様のネクタイはあわない。
#
# タバコをやめてから、食事がおいしい。
#
# タバコをやめたおかげで、食事がおいしい。
#
# タバコを吸うと肺がんになるおそれがある。
#
# タバコは体に悪い。
#
# タバコを吸っている人が肺癌になる率は高い。
#
# タバコを吸っている人は肺癌になりやすい。
#
# ビタミンの不足が体調不良を招く。
#
# 体調不良の原因がビタミンの不足によることもある。
#
# 一息ついてから考えよう。
#
# 少し休憩してから考えよう。
#
# 一服する。
#
# お茶を飲む。
#
# 一服する。
#
# 煙草をすう。
#
# 雨の日が続いている。
#
# このところ晴れていない。
#
# 旺盛な食欲はとどまるところを知らなかった。
#
# 食欲は止まらなかった。
#
# 旺盛な食欲はとどまるところを知らなかった。
#
# 食欲は続いた。
#
# 何事もやり過ぎは良くない。
#
# 何事もほどほどがよい。
#
# 可能ならば、明日来て下さい。
#
# できたら、明日来て下さい。
#
# 可能ならば、明日来て下さい。
#
# できるだけ、明日来て下さい。
#
# 可能ならば、明日来て下さい。
#
# できれば、明日来て下さい。
#
# 花屋さんになりたい。
#
# 夢は花屋さんだ。
#
# 花子は複雑な閲歴をたどってきた人だ。
#
# 花子は複雑な経歴の持ち主だ。
#
# 花子は複雑な閲歴をたどってきた人だ。
#
# 花子は複雑な履歴の人だ。
#
# 外で食事をする。
#
# 外食する。
#
# 街で散財して帰ってきた。
#
# 街で買いものをしてきた。
#
# 感慨もひとしおでございます。
#
# とてもうれしい。
#
# 機械化が進んで人員の削減が進んだ。
#
# 機械化が進まなければ、人員を削減する必要はなかった。
#
# 疑惑の念も雲散霧消した。
#
# 疑いの心もすっかり消えた。
#
# 宮中に参内、拝謁の栄に浴した。
#
# 皇居に行って、天皇陛下に会った。
#
# 仰天した。
#
# とても驚いた。
#
# 血液が不足している。
#
# 血液が足りない。
#
# 健康に留意する。
#
# 健康に気をつける。
#
# 健康に留意する。
#
# 健康に注意する。
#
# 健康のために運動は欠かさない。
#
# 運動は健康にいい。
#
# 更衣室でお金がなくなった。
#
# お金を紛失した。
#
# 今日は残業した。
#
# 今日は遅くまで仕事をした。
#
# 佐藤党首は分刻みのスケジュールで行動している。
#
# 佐藤党首は忙しい。
#
# 昨夜は、久し振りに痛飲した。
#
# 昨夜は、久し振りに、おおいに酒を飲んだ。
#
# 殺人鬼を演じてから、動作がぎこちない。
#
# 殺人鬼を演じたせいで、動作がぎこちない。
#
# 視力が落ちた。
#
# 目が悪くなった。
#
# 寺田氏が知事に選ばれた。
#
# 寺田氏が知事に当選した。
#
# 車の往来が激しくて子どもをひとりで遊ばせられない。
#
# 交通量が多くて子どもをひとりで遊ばせられない。
#
# 首相は、自分の影響力の大きさを考えて行動しない。
#
# 首相は気ままに行動する。
#
# 消しゴムがなくなった。
#
# 消しゴムが紛失した。
#
# 消しゴムがなくなった。
#
# 消しゴムを使いきった。
#
# 場当たり的な行動が目立つ。
#
# 無計画で思慮のない行動が目立つ。
#
# 性愛の悦楽に溺れる。
#
# 性愛の悦楽にふける。
#
# 生け垣にすると、市から補助金がもらえるらしい。
#
# 生け垣にすると、市から補助金がもらえそうだ。
#
# 生け垣にすると、市から補助金がもらえるらしい。
#
# 生け垣にすると、市から補助金がもらえるかもしれない。
#
# 生け垣にすると、市から補助金がもらえるらしい。
#
# 生け垣にすると、市から補助金がもらえるそうだ。
#
# 洗濯をした。
#
# 洋服を洗った。
#
# 太郎は腕のある職人に成長した。
#
# 太郎は技術の高い職人だ。
#
# 虫歯予防のために歯みがきは欠かさない。
#
# 歯みがきは虫歯予防にいい。
#
# 日本の人口は一億を超えている。
#
# 日本の人口は一億以上だ。
#
# 彼とは相性が悪い。
#
# 彼とうまくいかない。
#
# 彼は、僕より上手だ。
#
# 彼は僕より悪どい。
#
# 彼は、僕より上手だ。
#
# 彼は僕より優れている。
#
# 彼はすぐ怒る。
#
# 彼は短気だ。
#
# 彼は大往生を遂げた。
#
# 彼は長生きした。
#
# 彼は肉料理が苦手だ。
#
# 彼は肉料理が嫌いだ。
#
# 彼女の髪形が変わって、別人のように見える。
#
# 彼女は別人になった。
#
# 彼女はしたたかだ。
#
# 彼女は手ごわい。
#
# 翻訳家になる夢をあきらめないでいた。
#
# ずっと翻訳家になりたいと思っている。
#
# 巨大ハリケーンが都市を飲み込んだ。
#
# ハリケーンが都市全体を襲った。
#
# 街が雪化粧した。
#
# 街が化粧をした。
#
# もみじが色付いてきた。
#
# 木々が紅葉してきた。
#
# 野生のサル生息の最北限は、下北半島である。
#
# サルは青森にいる。
#
# 英外相がブラジル外相に謝罪した。
#
# 英国がブラジルに謝った。
#
# 彼はピアノを弾くのが職業だ。
#
# 彼はピアニストだ。
#
# リボンと紙を解いた。
#
# プレゼントを開けた。
#
# 昨日は雨が降っていた。
#
# 昨日は光が降り注いでいた。
#
# 部長が大枚をはたいてくれた。
#
# 部長が多くのお金を払った。
#
# ＡチームがBチームより優位に立っている。
#
# Ａチームの方が勝算が高い。
#
# 文章を校正した。
#
# 誤字、脱字を直した。
#
# 占いは昔からずっと行われている。
#
# 占いはいつの時代にもあった。
#
# 心の洗濯をした。
#
# 心が洗われた。
#
# 姉より妹のほうが背が高い。
#
# 妹のほうが姉より身長がある。
#
# 切っても変色しない新種のリンゴが誕生した。
#
# 新しいリンゴが開発された。
#
# 紀宮様が皇室を離れた。
#
# 紀宮樣が結婚した。
#
# 子どもが母親とはぐれた。
#
# 迷児になった。
#
# 彼は財産を守るために遺言書を書くことにした。
#
# 彼は財産を守るために家族に遺言した。
#
# ロースよりヒレのほうが高い。
#
# ヒレ肉のほうが上等だ。
#
# 自動車がスリップしたのを見た。
#
# 自動車のタイヤが滑べったのを見た。
#
# 世界柔道が開幕した。
#
# 世界柔道選手権が始まった。
#
# 尿検査で「とう」が出た。
#
# 尿検査で基準値以上の糖が検出された。
#
# お昼だというのに、おなかがすかない。
#
# おなかがこんでいる。
#
# 寒天ダイエットについて報道した。
#
# 寒天が痩せた。
#
# 料理を堪能して大満足だ。
#
# 料理を味わった。
#
# ミュージシャンになる夢をあきらめきれない。
#
# 私はミュージシャンだ。
#
# 開花した。
#
# 桜だった。
#
# 開花した。
#
# 虫だった。
#
# 開花した。
#
# 蛹だった。
#
# 禁煙治療に保険が適用される。
#
# 喫煙が奨励されている。
#
# 今日は残業した。
#
# 今日は定時に退社した。
#
# 今夜も帰りは遅いのですか。
#
# 今夜は帰らない。
#
# 佐野さんが私を伊東さんに紹介してくれた。
#
# 私は伊東さんと顔見知りである。
#
# 私の夢はかわいいお嫁さんになることです。
#
# 私は眠っている。
#
# 私は男の子とよくまちがえられた。
#
# 私は男性である。
#
# 自分の意見をきちんと述べられるようにしつけられている。
#
# この犬は良くしつけられている。
#
# 若さだけを武器にして戦ってきた。
#
# 戦争があった。
#
# 世界柔道が開幕した。
#
# 緞帳は閉まっていた。
#
# 早稲田と明治が対戦した。
#
# 戦争がおこった。
#
# 太郎は次郎より背が高い。
#
# 太郎は次郎より年上だ。
#
# 堤防が決壊した。
#
# 堤防が強かった。
#
# 彼は大学を卒業した。
#
# 彼は大学院に入学していた。
#
# 便利になったと誰もが喜んだ。
#
# 便利ということほど、いいものはない。
#
# 野口さんが宇宙から無事帰還した。
#
# 野口さんは宇宙人に捕まっていた。
#
# 葉子は、華やかな女性になりたいと、日ごろから思っている。
#
# 葉子は男性である。
#
# 知事に寺田氏が再選した。
#
# 選挙があった。
#
# 知事に寺田氏が選ばれた。
#
# 選挙があった。
#
# 日本は国民主権国家として再出発した。
#
# 日本は国民主権国家ではなかった。
#
# 農民は雨が降ることを待ち望んでいる。
#
# 雨が降っていない。
#
# 彼は彼女に電話した。
#
# 彼は彼女の電話番号を知っていた。
#
# お菓子のパッケージの復刻版が人気を呼んでいる。
#
# パッケージは変化している。
#
# このラジオは部品の交換で修理できる。
#
# このラジオは故障している。
#
# そろそろ政界からの引退も考えている。
#
# 政界にいる。
#
# ぼけの防止のために料理を始めた。
#
# ぼけると困る。
#
# もみじが色付いてきた。
#
# 秋である。
#
# アワビの密漁団が逮捕された。
#
# 密漁は犯罪である。
#
# ウメがなったので、梅酒を作ろう。
#
# ウメの花が咲いた。
#
# オリーブオイルはオリーブの実から抽出される。
#
# オリーブの実には油分が含まれている。
#
# ミュージシャンになる夢をあきらめきれない。
#
# ミュージシャンになる夢をあきらめようとした。
#
# リビアへの制裁は停止された。
#
# リビアは制裁を受けていた。
#
# ルーマニアのチャウシェスク体制は崩壊した。
#
# ルーマニアにはチャウシェスク体制が存在していた。
#
# 哀しみを表情に出さないように苦労した。
#
# 哀しかった。
#
# 哀しみを表情に出さないように苦労した。
#
# 哀しそうな表情をしそうだった。
#
# 圧力鍋で米を炊くとおいしくできる。
#
# 圧力鍋でなくても米を炊ける。
#
# 宇宙人の存在を信じますか。
#
# 宇宙人の存在については賛否両論ある。
#
# 仮に私が男だったとして、そんなことをするだろうか。
#
# 私は女である。
#
# 仮に私が男だったとして、そんなことをするだろうか。
#
# 私は男ではない。
#
# 花子は出産した。
#
# 花子は妊娠していた。
#
# 芥川賞受賞祝賀パーティーに参加した。
#
# 芥川賞受賞者と関係がある。
#
# 開花した。
#
# 蕾だった。
#
# 街が雪化粧した。
#
# 雪が降った。
#
# 虐待と間違われるのが怖くて、子供を叱れない。
#
# 虐待はしていない。
#
# 魚が産卵した。
#
# 魚はメスである。
#
# 禁煙治療に保険が適用される。
#
# 禁煙治療には保険が適用されていなかった。
#
# 紅茶と緑茶は同じ茶葉から作られる。
#
# 紅茶と緑茶は違うものだ。
#
# 今夜はカレーにしてほしい。
#
# 夕食を作るのは自分ではない。
#
# 債務を果たした。
#
# 借金があった。
#
# 私は男の子とよくまちがえられた。
#
# 私は女性である。
#
# 次朗は放送委員会の委員長に選ばれた。
#
# 次朗は放送委員である。
#
# 辞書を引いて、意味がわかった。
#
# 辞書には、語釈が載っている。
#
# 聖火がイタリアについた。
#
# 聖火リレーをしていた。
#
# 祖父は今日、77歳になった。
#
# 今日は祖父の誕生日である。
#
# 続けてきた英会話が、旅行で役立った。
#
# 英会話を勉強していた。
#
# 損害賠償を請求することにした。
#
# 損害を受けた。
#
# 太郎と花子は仲直りした。
#
# 太郎と花子は喧嘩していた。
#
# 太郎は越境入学をすることにした。
#
# 指定された学校がある。
#
# 太郎は蚊に刺された。
#
# 蚊がいた。
#
# 太郎は奇妙な夢をみた。
#
# 太郎は寝ていた。
#
# 太郎は離婚した。
#
# 太郎は結婚していた。
#
# 知事に寺田氏が再選した。
#
# 寺田氏は知事だった。
#
# 地下鉄に乗って通勤している。
#
# 働いている。
#
# 長期の休暇には実家に帰省することが多い。
#
# 両親と一緒に暮らしていない。
#
# 鳥インフルエンザが発生した。
#
# 鳥がウイルスに感染した。
#
# 通勤電車に乗った。
#
# 働いている。
#
# 日本チームは逆転勝ちした。
#
# 日本チームは負けていた。
#
# 配偶者が妊娠した。
#
# 配偶者は女性である。
#
# 彼が再婚した。
#
# 彼は結婚していたことがある。
#
# 彼が再婚した。
#
# 彼は離婚したことがある。
#
# 彼は新会社を立ち上げた。
#
# 会社登記をした。
#
# 布団を天日乾しした。
#
# 晴れていた。
#
# 風呂から上がった。
#
# 風呂に入っていた。
#
# 放置自転車の問題に取り組み始めた。
#
# 放置自転車が問題になっていた。
#
# 夜になると電灯をつける。
#
# 夜は暗い。
#
# 野口さんが宇宙から無事帰還した。
#
# 野口さんは宇宙に行っていた。
#
# 約束を果たせなかった。
#
# 約束をした。
#
# 陽子は昇給した。
#
# 陽子は給与所得者である。
#
# 両陛下は、ヨーロッパを訪問された。
#
# 陛下は身分の高い方である。
#
# 老人ホームの地図記号を国土地理院が初めて公募した。
#
# 国土地理院が地図記号を決めていた。
#
# そろそろ政界からの引退も考えている。
#
# 政界は体力がものをいう世界だ。
#
# 亜硫酸の生成方法を教えてくれた。
#
# 亜硫酸の生成方法は、秘密に近い。
#
# 亜硫酸の生成方法を教えてくれた。
#
# 教えられなくても知っていた。
#
# 雨が降ってるから、車で行こう。
#
# 雨が降ってなかったら、車では行かない。
#
# 今年は厄年だから、災難に遭わないように注意する。
#
# 厄年には災いに遭いやすい。
#
# 私はお姉さんが欲しかった。
#
# 私にはお兄さんがいる。
#
# 首相は官邸に生えていたキノコが食べられるか調べようと思った。
#
# 首相はキノコが食べたかった。
#
# 生きた英語を身につけたい。
#
# 今は英語が話せない。
#
# 太郎は腕のある職人に成長した。
#
# 太郎には腕がなかった。
#
# 知事に寺田氏が選ばれた。
#
# 寺田氏は知事だった。
#
# 彼が再婚した。
#
# 彼は離婚した。
#
# 彼女の髪形が変わって、別人のように見える。
#
# 彼女は髮を切った。
#
# あいつは女性の扱いになれている感じがする。
#
# あいつは男性である。
#
# お正月は故郷で過ごすつもりだ。
#
# 現在は、実家に住んでいない。
#
# ここは西欧の文化に多大な影響を受けている。
#
# ここは西欧ではない。
#
# すき焼きには関西風と関東風がある。
#
# すき焼きの作り方が違う。
#
# アキバがを東京ディズニーランド超える集客力だそうだ。
#
# 東京ディズニーランドは集客力がある。
#
# タバコを吸うと肺がんになるおそれがある。
#
# タバコを吸う人がいる。
#
# トラが逃げた。
#
# トラは限られた場所にいる。
#
# ドライヤーで髪を乾かした。
#
# 髪が濡れていた。
#
# ビキニを着るほどの気合いはない。
#
# ビキニを着るには気合いがいる。
#
# 亜硫酸の生成方法を教えてくれた。
#
# 亜硫酸の生成方法を知らなかった。
#
# 亜硫酸の生成方法を教えてもらった。
#
# 亜硫酸の生成方法を知らなかった。
#
# 亜硫酸の生成方法を教えられた。
#
# 亜硫酸の生成方法を知らなかった。
#
# 亜硫酸の生成方法を教わった。
#
# 亜硫酸の生成方法を知らなかった。
#
# 偉人伝を子どもに読ませることは本当にいいことなのでしょうか。
#
# 偉人伝を子どもに読ませるといいとされている。
#
# 偉人伝を子どもに読ませることは本当にいいことなのでしょうか。
#
# 偉人伝を子どもに読ませる習慣がある。
#
# 慰められて少し気が楽になった。
#
# 慰められる前は、気が重かった。
#
# 乙女のはじらいが感じられない。
#
# 乙女にははじらいが感じられるものだ。
#
# 寒いのでストーブをつけた。
#
# ストーブをつけると暖かくなる。
#
# 危うくスリに遭うところだった。
#
# スリがいた。
#
# 蟻が行列を作っている。
#
# エサがある。
#
# 競馬をした。
#
# 馬券を買った。
#
# 研究の進捗状況について説明した。
#
# 研究をすべき状況にある。
#
# 四十日連続の真夏日を記録した。
#
# 四十日連続の真夏日は特筆すべきことである。
#
# 子どものころのことはいつから記憶に残っていますか。
#
# 子どものころのことは何かしらおぼえているものだ。
#
# 私の夢はかわいいお嫁さんになることです。
#
# 私は未婚である。
#
# 私はお姉さんが欲しかった。
#
# 私は長女である。
#
# 自転車のブレーキが効かなくて、こわい思いをした。
#
# スピードが出ていた。
#
# 辞書を引いて、意味がわかった。
#
# 辞書を引くと、言葉の意味がわかる。
#
# 車窓の景色が美しい。
#
# 電車に乗っている。
#
# 初もうでに行って商売繁盛を祈願した。
#
# 商売をしている。
#
# 女子トイレは3階にもありますよ。
#
# 女子トイレが混んでいる。
#
# 炊飯器を買い替えた。
#
# 炊飯器は古かった。
#
# 性愛の悦楽に溺れる。
#
# 性愛の悦楽に夢中になるのは好ましくない。
#
# 足のリハビリをしている。
#
# 足が自由に動かない。
#
# 耐震基準を満たしていないマンションがあることが発覚した。
#
# 基準を満たしていないマンションはないと思われていた。
#
# 二人の関係が噂になるのも時間の問題だ。
#
# 二人は関係がある。
#
# 彼の生涯は、波乱に満ちていた。
#
# 彼は死んだ。
#
# 彼は英語が堪能である。
#
# 彼の母語は英語ではない。
#
# 彼は保守的だ。
#
# 彼は伝統を重んじる。
#
# 標準的な体型に憧れる。
#
# 標準的な体型をしていない。
#
# 風で帽子がとんだ。
#
# 私は帽子をかぶっていた。
#
# 腹筋運動を日課にしている。
#
# おそらく、日課にしなければ腹筋運動はしない。
#
# 物音で目が覚めた。
#
# 寝ていた。
#
# 妙な噂をたてられて迷惑している。
#
# 噂は事実ではない。
#
# 野性化したアライグマの被害に農家は困っている。
#
# アライグマはペットとして飼われていた。
#
# 優雅な身のこなしは彼女の育ちのよさを感じさせた。
#
# 育ちがいいと身のこなしが優雅なものである。
#
# 友情をとるか愛情をとるか、選択が迫られている。
#
# 友情と愛情の両方は手に入れられない。
#
# 両親は年金暮らしだ。
#
# 父は退職した。
#
# 両親は年金暮らしだ。
#
# 母は退職した。
#
# 白バイに罰金を取られた。
#
# 白バイに捕まった。
#
# 結婚式に出席する。
#
# 私は結婚する。
#
# 佐々木容疑者は他に２件の犯行を自供し始めた。
#
# 佐々木は逮捕された。
#
# 配偶者が妊娠した。
#
# 私は男性である。
#
# アナウンスが流れたので、降車ボタンを押した。
#
# 乗り合いバスに乗っていた。
#
# 弁護士に依頼して、自己破産した。
#
# 自己破産するにも、法律的な知識が必要だ。
#
# 飯を食おう。
#
# 私は女性である。
#
# 飯を食おう。
#
# 私は男性である。
#
# だんだん日が短くなってきた。
#
# 冬に近づいてきた。
#
# また盗難が発生した。
#
# 盗難の被害にあった人がいる。
#
# 体重が六十キロ以上になったら、真剣にダイエットを考えよう。
#
# 痩せたい気持ちはある。
#
# まりもが浮いた。
#
# 光合成をして酸素を出している。
#
# 子どもにランドセルを買った。
#
# 子どもが小学校に入学する。
#
# 堤防が決壊した。
#
# 堤防が弱かった。
#
# この方法は効率が悪い。
#
# この方法は効率がいい。
#
# ジョギングを始めて2ヶ月だ。
#
# ジョギングを止めて2ヶ月になる。
#
# 違憲判決が下った。
#
# 違憲判決が上った。
#
# 一日をいたずらに過ごした。
#
# 一日を有意義に過ごした。
#
# 休日は家で過ごすことが多い。
#
# 休日は外出して過ごすことが多い。
#
# 私は太く短く生きたい。
#
# 私は細く長く生きたい。
#
# 男性は理性的だ。
#
# 男性は感情的だ。
#
# 糖尿病なので、食事には注意している。
#
# 糖尿病なので、食事は自由に食べて良い。
#
# 彼は英語が堪能である。
#
# 彼は英語が下手だ。
#
# 彼は断トツの人気だ。
#
# 彼は人気がない。
#
# 彼女は御機嫌ななめだ。
#
# 彼女は機嫌がいい。
#
# 面白いテレビだった。
#
# つまらないテレビはない。
#
# 紅白戦で紅組が勝った。
#
# 紅白戦で白組が負けた。
#
# 桜の花が散ってしまった。
#
# 桜の花は咲いていた。
#
# 私は物事をポジティブに考える。
#
# 私は物事をネガティブに捉えない。
#
# 昔ほど星が見えない。
#
# 昔はたくさん星が見えた。
#
# 選挙で自民党が圧勝した。
#
# 選挙で他党は惨敗した。
#
# 彼はドアを開けた。
#
# ドアは閉まっていた。
#
# 彼は大学を卒業した。
#
# 彼は大学に入学していた。
#
# 便利になったと誰もが喜んだ。
#
# それまで不便だった。
#
# 太郎は駅までの道を尋ねられた。
#
# 太郎は駅までの道を教えた。
#
# 彼は入院した。
#
# 彼は退院する。
#
# 安易に解熱剤を使うのは控えた方がいい。
#
# 解熱剤はよく考えてから使った方がいい。
#
# 英語とパソコンができないと、就職できない。
#
# 英語とパソコンができれば、就職しやすい。
#
# 英語とパソコンができないと、就職できない。
#
# 就職するには、英語とパソコンができると有利だ。
#
# 北日本と北陸地方は大荒れの天気である。
#
# 青森は天気がいい。
#
# 私は暖かい色が好きだ。
#
# 寒色は嫌いだ。
#
# タバコを吸っている人が肺癌になる率は高い。
#
# タバコを吸わない人は肺癌にならない。
#
# 夏野菜は体を冷やす効果がある。
#
# 体を暖める野菜もある。
#
# 女を殴る男は最低だ。
#
# 男に殴られる女は最高だ。
#
# 女性の管理職が増えた。
#
# 女性の管理職は少なかった。
#
# ジュースをこぼした。
#
# ジュースがコップの中にある。
#
# 紅組が白組に不戦勝した。
#
# 紅組は白組と試合をした。
#
# 手紙を書いた。
#
# 便箋は白紙だ。
#
# 大学に進学した。
#
# 大学に入学届けを出していない。
#
# 抽選会で、商品が当たった。
#
# 外れくじをひいた。
#
# キャンパスの美化にご協力ください。
#
# キャンパスを汚さないようにしてください。
#
# 電車が減速した。
#
# 電車は動いている。
#
# うさぎは耳が長い。
#
# うさぎには耳がある。
#
# さつきは緑に囲まれたマンションに住めてうらやましい。
#
# さつきは緑が多いマンションにいる。
#
# ジョンがボールを蹴った。
#
# ジョンがボールに触れた。
#
# ツバメが飛んでいる。
#
# ツバメが空中にいる。
#
# 花子は叫んだ。
#
# 花子は声を出した。
#
# 皆で合唱した。
#
# 声を合せた。
#
# 虐待と間違われるのが怖くて、子供を叱れない。
#
# 虐待と間違われると困る。
#
# 今日、運動会の延期が発表された。
#
# 今日は運動会はやらない。
#
# 三日間、旅行に行く。
#
# 三日間、自宅にいない。
#
# 掃除機の性能はフィルターに左右される。
#
# 掃除機にはフィルターがある。
#
# 掃除機の性能はフィルターに左右される。
#
# 掃除機には性能がある。
#
# 太郎は夕食を味わった。
#
# 太郎は夕食を食べた。
#
# 台風が関東地方に上陸した。
#
# 台風が関東地方にきた。
#
# 電車が減速した。
#
# 電車は動いていた。
#
# 納豆はビタミンが豊富だ。
#
# 納豆にはビタミンが含まれている。
#
# 彼女は部屋のインテリアにこだわる。
#
# 彼女は部屋のインテリアを気にする。
#
# 夫は単身赴任している。
#
# 夫と一緒に住んでいない。
#
# 隆がボールを投げた。
#
# 隆がボールに触れた。
#
# 六本木は国際色豊かだ。
#
# 六本木には外国人が多い。
#
# 和歌を詠んだ。
#
# 和歌を作った。
#
# チョコレートを食べた。
#
# チョコレートがなくなった。
#
# 脱出を試みた。
#
# 脱出できた。
#
# 脱出を試みた。
#
# 脱出できなかった。
#
# 通勤電車で痴漢にあった。
#
# 痴漢の顔を見た。
#
# 通勤電車で痴漢にあった。
#
# 痴漢行為を目撃した。
#
# もしよかったら、今週末映画を観にいきませんか。
#
# もしよかったら、今週末会ってくれませんか。
#
# ドライヤーで髪を乾かした。
#
# 髪が乾いた。
#
# メルマガを読んだ。
#
# パソコンの画面を見ている。
#
# 寒くても痩せ我慢をした。
#
# 暖房をつけなかった。
#
# 寒くても痩せ我慢をした。
#
# 着るものの調節をしなかった。
#
# 続けてきた英会話が、旅行で役立った。
#
# 旅行先で英語で会話が通じた。
#
# 二人は無理心中した。
#
# 二人は死んだ。
#
# 右手で円を書くのと同時に左手で三角を書く。
#
# 両手で違う動きをする。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# ブラジル人が逃げた。
#
# この店は昔ながらの製法を守っている。
#
# この店はどんどん新しい製法を取り入れている。
#
# ざわめきがぴたりと止んだ。
#
# ざわめきが一致した。
#
# また盗難が発生した。
#
# 盗難が発生したのは初めてだ。
#
# 花子はばっさりと髮を切った。
#
# 花子の髮は長い。
#
# 花子は何事にもきちんとしている。
#
# 花子は何事にもだらしがない。
#
# 危うくスリに遭うところだった。
#
# スリに遭った。
#
# 亀はゆっくり歩く。
#
# 亀はすばしっこい。
#
# 戸がぎしぎしときしむ。
#
# 戸の立て付けがよい。
#
# 今日はよく寝た。
#
# 今日は睡眠がとれなかった。
#
# 仕事がどっさりある。
#
# 軽くこなせる仕事量だ。
#
# 私にはさっぱり分からない問題だ。
#
# 私には問題が理解できた。
#
# 事もあろうにこんな事になるとは思わなかった。
#
# こんな事になるのは充分想像できた。
#
# 次郎はいつもそわそわしている。
#
# 次郎は落ち着きがある。
#
# 騒ぎは意外と大きくならなかった。
#
# 騒動は大きくなるばかりだった。
#
# 太郎はどっぷりと風呂に浸かった。
#
# 太郎は腰まで風呂に浸かった。
#
# 太郎は決して意見を曲げない。
#
# 太郎は譲歩した。
#
# 地球誕生の謎は未だに解明されていない。
#
# 地球誕生の謎は解明される事はない。
#
# 締め切りがいよいよ迫ってきた。
#
# 締め切りまで充分時間がある。
#
# 田中氏は、依然、総理大臣だ。
#
# 田中氏は首相だった。
#
# 彼の構想はまるで夢物語だ。
#
# 彼の構想は、現実的だ。
#
# 内容的には紅組が勝っていた。
#
# 紅組は負けた。
#
# また盗難が発生した。
#
# 今までに何度も盗難が起こっている。
#
# ポイントを貯めるためになるべくカードで払うことにした。
#
# カードで払わないこともある。
#
# ミャンマーはかつてビルマと呼ばれていた。
#
# ミャンマーは昔ビルマと呼ばれていた。
#
# 一日をいたずらに過ごした。
#
# 一日をなにもせず無駄に過ごした。
#
# 危うくスリに遭うところだった。
#
# スリに遭わなかった。
#
# 原則的には、所内は駐車禁止だ。
#
# 場合によっては、駐車を許可する。
#
# 最近よく学校に行く。
#
# 学校に行く事が増えた。
#
# 私はあえて会社を辞めた。
#
# 自分の意志で会社を辞めた。
#
# 私はかつてでこちゃんと呼ばれていた。
#
# 私は昔でこちゃんと呼ばれていた。
#
# 商談がやっとまとまった。
#
# 商談がまとまるのに時間がかかった。
#
# 田中選手一人で点数を稼いだ。
#
# チーム競技をしていた。
#
# 彼は寡黙な人だと思われているようだが、そんなことは全然ない。
#
# 彼はよくしゃべる。
#
# 彼は断トツの人気だ。
#
# 彼は一番人気がある。
#
# 彼女は再び東京に行った。
#
# 彼女は昔東京に行ったことがある。
#
# 本当に特異なケースだったのか。
#
# 特異なケースではないかもしれない。
#
# 野口さんが宇宙から無事帰還した。
#
# 宇宙からの帰還は危険を伴う。
#
# 量的には問題ない。
#
# 質に問題がある。
#
# 老人ホームが次々に開所している。
#
# 高齢者が増えている。
#
# のんびり歩くと、景色がよく見える。
#
# 早く歩くと、景色があまり見られない。
#
# 最近は、晴雨兼用の傘がある。
#
# 晴雨兼用の傘が使われるようになってきた。
#
# ついに宝くじに当選した。
#
# 宝くじの当選確率は低い。
#
# パソコンを強制終了した。
#
# 強制的でない終了の方法がある。
#
# 家屋の倒壊だけはまぬがれた。
#
# 家財道具は被害を受けた。
#
# 花子は洋菓子より和菓子をなお好む。
#
# 花子は和菓子の方が好きだ。
#
# 契約社員と正社員では、まず給料が違う。
#
# 契約社員と正社員では、ほかにもずいぶん違いがある。
#
# 健作の配偶者は、そのときまだ二十歳だった。
#
# 二十歳は若い。
#
# 今日はよく寝た。
#
# 熟睡した。
#
# 今日はよく寝た。
#
# 長時間寝た。
#
# 佐藤さんが会社を休むとは、よほどのことに違いない。
#
# 佐藤さんは、めったに会社を休まない。
#
# 女性が土俵にあがることは伝統的に禁じられている。
#
# 女性が土俵にあがることは長い間禁じられてきた。
#
# 長いこと泳いでいない。
#
# 最近は泳いでいない。
#
# 普段はスカートははかない。
#
# スカートをはくのは特別なときだ。
#
# 普段はスカートははかない。
#
# 普段はパンツスタイルだ。
#
# 厳密には、ルイボス茶は茶ではない。
#
# ルイボス茶は広い意味では茶である。
#
# あの人は80歳を過ぎてもピンピンしている。
#
# あの人は80歳を過ぎても元気で健康だ。
#
# この部屋はむしむしする。
#
# この部屋は湿度が高い。
#
# この部屋はむしむしする。
#
# 湿度が高い。
#
# もうすぐ三歳です。
#
# 今は二歳だ。
#
# 今年もあと2か月になった。
#
# 今は11月である。
#
# 今年もあと2か月になった。
#
# 今年も10か月が過ぎた。
#
# 凹面鏡は、反射望遠鏡などに利用されている。
#
# 反射望遠鏡に使われているのは、凸面鏡だ。
#
# 花子の色彩感覚は素晴らしい。
#
# 花子が素晴らしいのは、バランス感覚だ。
#
# 花子は韓国料理を習っている。
#
# 花子が習っているのは、台湾料理だ。
#
# 花子は指輪をなくした。
#
# 花子がなくしたのは鼻輪だった。
#
# 成功するには努力を怠らないことだ。
#
# 努力を怠たることこそ、成功のもとだ。
#
# 選挙で自民党が圧勝した。
#
# 選挙で圧勝したのは民主党だ。
#
# 太郎が次郎をナイフで刺した。
#
# 太郎がナイフで刺したのは三郎だった。
#
# 太郎は「どうにかなるさ」と言った。
#
# どうにかなると言ったのは僕だ。
#
# 彼女は白無垢よりドレスが着たい。
#
# 結婚式で彼女が着たいのは白無垢だった。
#
# 部下のミスをかぶって退職することになった。
#
# 私が退職することになったのは、部下の出来が良かったからだ。
#
# うさぎは耳が長い。
#
# 耳が長いのがうさぎだ。
#
# カツオは海の生き物である。
#
# 海の生き物としては、カツオが挙げられる。
#
# サツマイモの栽培には、火山灰台地が適している。
#
# サツマイモの栽培に適しているのは、火山灰台地である。
#
# 化粧は女を化かす。
#
# 女を化かすのが化粧だ。
#
# 夏野菜は体を冷やす効果がある。
#
# 夏野菜の効果は、体を冷やすことだ。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# 熊に乗った金太郎が担いでいるのはまさかりである。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# 熊に乗ってまさかりを担いでいるのは金太郎である。
#
# 具が大きいカレーが食べたい。
#
# 食べたいのは、具の大きいカレーだ。
#
# 更衣室でお金がなくなった。
#
# お金がなくなったのは、更衣室でだった。
#
# 国民は教育を受ける義務がある。
#
# 教育を受けるのが、国民の義務だ。
#
# 佐野さんが私を伊東さんに紹介してくれた。
#
# 私を伊東さんに紹介してくれたのは佐野さんだ。
#
# 太郎が次郎をナイフで刺した。
#
# 太郎がナイフで刺したのは、次郎だった。
#
# 男は女性をひき逃げした疑いで逮捕された。
#
# その男の容疑は女性ひき逃げだ。
#
# 彼は、おかずを巡る喧嘩から妻を殺害した。
#
# 殺害の原因は、おかずだった。
#
# 彼は必死に窓を叩いた。
#
# 彼が必死に叩いたのは、窓だった。
#
# 風で帽子がとんだ。
#
# 帽子が飛んだのは、風のせいだ。
#
# 老人ホームの地図記号を国土地理院が初めて公募した。
#
# 公募するのは、老人ホームの地図記号だ。
#
# 古代文明が栄えたのは、大きな川のそばだ。
#
# 大きな川のそばで、古代文明が栄えた。
#
# 電力の消費量が最も高くなるのは夏である。
#
# 夏には電力の消費量が最も高くなる。
#
# 贅沢にもその料理にはフォアグラが使われていた。
#
# フォアグラは贅沢だ。
#
# 彼は女児を殺害した。
#
# 彼が殺したのは男の子だ。
#
# イモリは両生類で、ヤモリは爬虫類だ。
#
# 水辺に棲んでいるのがイモリだ。
#
# この成分が胃酸の働きを助ける。
#
# 胃酸はこの成分がないと働けない。
#
# せんべいがしけっていて、残念だった。
#
# せんべいはがっかりした。
#
# カマキリは昆虫だ。
#
# 昆虫はカマキリだ。
#
# 花子は順子の姉だ。
#
# 順子は花子の姉だ。
#
# 花子は順子の妹だ。
#
# 順子は花子の妹だ。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# 熊はまさかりを担いで金太郎に乗られている。
#
# 健作の配偶者は、そのときまだ二十歳だった。
#
# 健作は配偶者より若かった。
#
# 国民は教育を受ける義務がある。
#
# 教育を受けるか否かは国民の自由だ。
#
# 災禍を被ったのは、この地区だけではない。
#
# この地区だけが災禍を被った。
#
# 私は浦島太郎が鶴を助けることを期待した。
#
# 浦島太郎は私が鶴を助けることを期待した。
#
# 私は妻の両親を新居に招いた。
#
# 妻の両親が私によって新居に招かれた。
#
# 選挙で自民党が圧勝した。
#
# 他党は潰された。
#
# 太郎は花子に本を貸した。
#
# 太郎は花子に本を貸した。
#
# 太郎は花子に恋している。
#
# 花子は太郎に恋している。
#
# 太郎は花子を愛している。
#
# 伊知朗は次郎に愛されている。
#
# 太郎は花子を愛している。
#
# 伊知朗は太郎に愛されている。
#
# 太郎は花子を愛している。
#
# 花子は太郎を愛している。
#
# 太郎は花子を驚かせた。
#
# 花子は太郎を驚かせた。
#
# 太郎は蚊に刺された。
#
# 蜂が太郎を刺した。
#
# 太郎は次郎の兄だ。
#
# 次郎は太郎の兄だ。
#
# 太郎は次郎の弟だ。
#
# 次郎は太郎の弟だ。
#
# 太郎は次郎より背が高い。
#
# 次郎は太郎よりも賢い。
#
# 太郎は次郎より背が高い。
#
# 次郎は太郎より足が大きい。
#
# 太郎は次郎より背が高い。
#
# 太郎は次郎より背が低い。
#
# 調査結果から事故原因を推論する。
#
# 事故原因から調査結果を推論する。
#
# 部下のミスをかぶって退職することになった。
#
# 部下が退職する。
#
# 野生のサルに畑を荒らされた。
#
# 野生のサルのせいで畑が荒れた。
#
# この本はベストセラーだ。
#
# この本は多くの人に読まれている。
#
# ぼけの防止のために料理を始めた。
#
# 料理は、ぼけの予防になる。
#
# アメリカで過去最大のハリケーンが発生した。
#
# 発生したハリケーンは今までで一番大きい。
#
# カマキリは昆虫だ。
#
# 昆虫の中にはカマキリもいる。
#
# サウジアラビアより日本の方が安全だ。
#
# 日本よりサウジアラビアの方が危険だ。
#
# トムはボブを連れて遊園地に行った。
#
# ボブはトムに連れられて遊園地に行った。
#
# ラブバードを見ていると、心がなごむ。
#
# ラブバードは心をなごませる。
#
# 英外相がブラジル外相に謝罪した。
#
# ブラジル外相が英外相に謝られた。
#
# 化粧は女を化かす。
#
# 女は化粧で化ける。
#
# 花子は陽子の親友だ。
#
# 陽子は花子の親友だ。
#
# 貨幣は造幣局で作られる。
#
# 造幣局が貨幣を作る。
#
# 海難審判法は1947年に制定された。
#
# 1947年に海難審判法を制定した。
#
# 漁業関係者は、エチゼンクラゲの大発生で魚がとれず苦労している。
#
# クラゲの大発生は、漁業関係者に損害を与えている。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# まさかりは熊に乗った金太郎に担がれている。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# 熊はまさかりを担いだ金太郎に乗られている。
#
# 交通事故死者よりも自殺者の方が多い。
#
# 自殺者の方が交通事故死者よりも多い。
#
# 交通事故死者よりも自殺者の方が多い。
#
# 自殺者よりも交通事故死者の方が少ない。
#
# 今年の梅雨明けは平年より三日早かった。
#
# 平年の梅雨明けは今年より三日遅い。
#
# 佐野さんが私を伊東さんに紹介してくれた。
#
# 伊東さんは佐野さんに私を紹介された。
#
# 佐野さんが私を伊東さんに紹介してくれた。
#
# 私は伊東さんから佐野さんに紹介された。
#
# 姉より妹のほうが背が高い。
#
# 姉のほうが妹より背が低い。
#
# 女性でないのなら男性である。
#
# 男性でないのなら女性である。
#
# 消しゴムがなくなった。
#
# 私は消しゴムをなくした。
#
# 情報が流出して困るのは、我々ではなく彼らの方だ。
#
# 我々よりも彼らが困るのは、情報が流出したときだ。
#
# 情報が流出して困るのは、我々ではなく彼らの方だ。
#
# 情報が流出すると、我々ではなく、彼らの方が困る。
#
# 掃除機の性能はフィルターに左右される。
#
# 掃除機の性能はフィルターが左右する。
#
# 総武線沿線より中央線沿線の方が家賃が高い。
#
# 中央線沿線より総武線沿線の方が家賃が安い。
#
# 太郎が花子を刺したのは、正当防衛だった。
#
# 花子は太郎に刺された。
#
# 太郎が次郎をナイフで刺した。
#
# 次郎が太郎にナイフで刺された。
#
# 太郎のおみやげは、ちんすこうだった。
#
# ちんすこうが太郎のおみやげだった。
#
# 太郎は花子に似ている。
#
# 花子は太郎に似ている。
#
# 太郎は花子を愛している。
#
# 花子は太郎に愛されている。
#
# 太郎は次郎の従兄弟だ。
#
# 次郎は太郎の従兄弟だ。
#
# 太郎は次郎より背が高い。
#
# 次郎は太郎より背が低い。
#
# 太郎は次郎より劣っている。
#
# 次郎は太郎より優れている。
#
# 泰子からお土産をもらったが、日本にはない珍しいものだった。
#
# 泰子がお土産をくれた。
#
# 大伴金村は物部尾輿に弾劾され、失脚した。
#
# 物部尾輿は大伴金村を弾劾し、失脚させた。
#
# 的確な判断で災害の被害を最小に抑えた。
#
# 的確な判断が災害の被害を最小に抑えた。
#
# 盗難が発生した。
#
# 物が盗まれた。
#
# 日本チームは逆転勝ちしたが、4失点した。
#
# 相手チームは4点取った。
#
# 白石さんに「本学の知名度、好感度を高めた」と学長から感謝状が贈られた。
#
# 学長が白石さんに感謝状を贈った。
#
# 妙な噂をたてられて迷惑している。
#
# 妙な噂がたっている。
#
# 野性化したアライグマの被害に農家は困っている。
#
# 農家はアライグマの被害を受けている。
#
# 野生のサルに畑を荒らされた。
#
# 野生のサルが畑を荒らした。
#
# うどんの材料は小麦粉と塩水だ。
#
# 小麦粉と塩水を混ぜればうどんになる。
#
# 銀行員は高給取りだ。
#
# 高給取りは銀行員だ。
#
# 太郎に貸した本がなくなった。
#
# 貸した本を太郎がなくしてしまった。
#
# 梅干しはすっぱい。
#
# すっぱいのは梅干しだ。
#
# 彼女は母親似の目の大きな子だった。
#
# 母親は目が大きい。
#
# 為政者の都合で何人もの生命が奪われた。
#
# 為政者が何人もの生命を奪った。
#
# 銀行員は高給取りだ。
#
# 高給取りといえば銀行員だ。
#
# 太郎は、握力がクラスで一番だった。
#
# 握力ではクラスの誰も太郎にかなわない。
#
# 梅干しはすっぱい。
#
# すっぱいものといえば梅干しだ。
#
# 母はすぐ怒る。
#
# 私はいつも怒られている。
#
# 太郎のおみやげは、ちんすこうだった。
#
# 私はちんすこうをもらわなかった。
#
# 紙を捨てた。
#
# 紙は拾われた。
#
# 彼女は道で元カレにあった。
#
# 彼は道で元カノにあった。
#
# 彼女は道で弟にあった。
#
# 彼は道で姉にあった。
#
# 巨大ハリケーンが都市を飲み込んだ。
#
# 都市はハリケーンに食べられた。
#
# 果物が白い器にのせてあるのが、おしゃれだ。
#
# 白い器に果物をのせているのが、おしゃれだ。
#
# ストッキングが伝線したので、マニキュアを塗った。
#
# マニキュアがストッキングを伝染させる。
#
# 小池氏が選ばれたのは不幸だ。
#
# 選ばれた小池氏は不幸だ。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# 彼はブラジルに滞在していた。
#
# 菓子を食べすぎると、体に良くない。
#
# 体によくないのは、菓子を食べないことだ。
#
# 虐待と間違われるのが怖くて、子供を叱れない。
#
# 子どもが怖くて叱れない。
#
# 牛肉の塊を買って来て、煮豚を作った。
#
# 牛肉で煮豚が作れる。
#
# 金太郎はまさかりを担いで熊に乗っている。
#
# 金太郎が熊に乗るにはまさかりが必要だ。
#
# 台風７号が発生し、日本に接近の恐れ。
#
# 台風は日本に接近した。
#
# 糖尿病なので、食事には注意している。
#
# 食事は糖尿病に悪い。
#
# 彼は寡黙な人だと思われているようだが、そんなことは全然ない。
#
# 彼はおしゃべりで有名だ。
#
# 眠いので、布団に入った。
#
# 布団に入るときは眠いものだ。
#
# 眠いので、布団に入った。
#
# 布団に入るには眠くなくてはいけない。
#
# 眠いのでガムをかんだ。
#
# ガムをかむには眠くなくてはならない。
#
# 優しい息子をもって、私は幸せです。
#
# 優しい息子をもっていない人は幸せではない。
#
# 幼稚園の先生になりたいと、子どものころは思っていた。
#
# 幼稚な先生になるのが夢だった。
#
# そこの角を右折すると、銀行がある。
#
# 銀行に行くには、そこの角を右折すればいい。
#
# 寒いのでコートを着た。
#
# コートを着ているということは寒いということだ。
#
# 寒いのでコートを着た。
#
# コートを着ると寒さがしのげる。
#
# 日本は予選を通過したのでワールドカップに行ける。
#
# ワールドカップに行くためには予選を通過しなければならない。
#
# 日本は予選を通過したのでワールドカップに行ける。
#
# 日本は予選を通過しないとワールドカップに行けない。
#
# 眠いのでガムをかんだ。
#
# ガムをかむと眠けが和らぐ。
#
# 明日雨が降ったらビデオを見ます。
#
# 明日雨が降らなかったらビデオを見ない。
#
# 明日雨が降ったら遠足は中止です。
#
# 明日雨が降らなかったら遠足がある。
#
# 明日雨が降ったら遠足は中止です。
#
# 明日遠足をする予定がある。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# ブラジル人は不法滞在していた。
#
# ブラジル人が逃走したのは不法滞在していたからだった。
#
# 不法滞在していたのでブラジル人は逃げた。
#
# ポイントを貯めるためになるべくカードで払うことにした。
#
# カードで払うとポイントが貯まる。
#
# ポイントを貯めるためになるべくカードで払うことにした。
#
# カードで払わないとポイントは貯まらない。
#
# 今年も白鳥が渡来したが、去年より遅かった。
#
# 去年のほうが、白鳥の渡来が早かった。
#
# 松茸は人工栽培できないので、外国から輸入している。
#
# 日本は松茸を輸入している。
#
# 体重が六十キロ以上になったら、真剣にダイエットを考えよう。
#
# まだ真剣にダイエットを考えていない。
#
# 体重が六十キロ以上になったら、真剣にダイエットを考えよう。
#
# 体重はまだ六十キロを超えていない。
#
# 大量のホルムアルデヒドが見つかったので、火星に生命が存在する可能性がある。
#
# ホルムアルデヒドは生命の存在に関係する。
#
# 豚肉の塊を買って来て、煮豚を作った。
#
# 煮豚は豚肉で作る。
#
# 彼は功績が認められて表彰された。
#
# 彼が表彰されたのは、功績が認められたからだ。
#
# キャベツを買って来て、ヤキソバを作った。
#
# ヤキソバはキャベツで作る。
#
# 電車に乗るので切符を買った。
#
# 切符を買わないと電車に乗れない。
#
# 年が明けるまで、来年度の異動先はわからない。
#
# 来年は異動する。
#
# 眠いのでガムをかんだ。
#
# ガムをかむのは、眠いときだ。
#
# もし行けなくなったら、電話を下さい。
#
# 行けるのなら電話はしなくていい。
#
# 易者が言うには、私は短命に終わるらしい。
#
# 易者は私に「あなたは短命に終わるでしょう」と言った。
#
# 高血圧なので、塩分の摂り過ぎには注意している。
#
# 塩分の摂り過ぎに注意しないと、高血圧に悪い。
#
# 高血圧なので、塩分の摂り過ぎには注意している。
#
# 塩分を摂り過ぎると、高血圧に悪い。
#
# 今日は土用丑の日だから、鰻を食べる。
#
# 土用丑の日には鰻を食べる。
#
# 辞書を引いて、意味がわかった。
#
# 言葉の意味が分からないときは、辞書を引けばよい。
#
# 小池氏が選ばれたのは不幸だ。
#
# 小池氏が選ばれて不幸だ。
#
# 組合活動に力をいれたら、会社に煙たがられた。
#
# 会社に煙たがられたのは、組合活動に力をいれたからだ。
#
# 糖尿病なので、食事には注意している。
#
# 食事に注意しないと、糖尿病に悪い。
#
# 背を伸ばしたいなら、よく寝ることだ。
#
# よく寝れば、背が伸びる。
#
# 売れ残ると困るので、店のお惣菜は夕方になると安くなる。
#
# 夕方店に行ったほうが食品が安く手に入る。
#
# 彼は、映画化された作品をいくつももつ、売れっ子の小説家だ。
#
# 彼の書いた小説が何本も映画化されている。
#
# 勉強すればいい大学に入れる。
#
# 勉強しないといい大学に入れない。
#
# 母が言うには、私は猫背らしい。
#
# 母は私に「あなたは猫背だ」と言った。
#
# 今年の初冠雪は、平年より10日遅く、去年より10日早かった。
#
# この山の初冠雪は去年のほうが遅かった。
#
# 高血圧なので、塩分の摂り過ぎには注意している。
#
# 塩分を摂ると高血圧になる。
#
# オール電化の家が増えてきた。
#
# この家は電気で動く。
#
# 花子は次郎の懐の深さを感じた。
#
# 花子は懐が深い。
#
# 自然の厳しさを思い知った。
#
# 自然は甘い。
#
# 太郎は胸の厚みがある。
#
# 太郎は面の皮が厚い。
#
# 地球も木星も太陽系の惑星だ。
#
# 太陽は惑星だ。
#
# 彼の指示の的確さは尊敬に値する。
#
# 彼の指示はいい加減だ。
#
# 病気のときは、健康のありがたみが身にしみる。
#
# 病気はありがたい。
#
# 面白いテレビだった。
#
# テレビがおかしい。
#
# あいさつの大切さを伝えたい。
#
# あいさつは大切だ。
#
# この画家の色彩感覚の素晴らしさには目を見張る。
#
# この画家の色彩感覚は素晴らしい。
#
# アトラスとマップの違いを説明する。
#
# アトラスとマップは違う。
#
# 漁業関係者は、エチゼンクラゲの大発生で魚がとれず苦労している。
#
# エチゼンクラゲが大発生した。
#
# 健太朗は、威圧的な態度で、気の弱さを隠していた。
#
# 健太朗は威圧的な態度をとる。
#
# 健太朗は、威圧的な態度で、気の弱さを隠していた。
#
# 健太朗は気が弱い。
#
# 子育ての大変さを思い知らせたい。
#
# 子育ては大変だ。
#
# 自然の厳しさを思い知った。
#
# 自然は厳しい。
#
# 北海道の寒さが身にしみた。
#
# 北海道は寒い。
#
# 優雅な身のこなしは彼女の育ちのよさを感じさせた。
#
# 彼女は育ちが悪い。
#
# 令子の冷たさといったらないよ。
#
# 令子は心が冷たい。
#
# 本当に特異なケースだったのか。
#
# 私は特異なケースだと信じている。
#
# お待ちのお客様がいらっしゃいますので。
#
# そろそろ席を開けて欲しい。
#
# あのビンは醤油ですか。
#
# 醤油のビンを取ってほしい。
#
# この部屋はクーラーがききすぎていませんか。
#
# クーラーをきってほしい。
#
# プーケットでもどこでもバカンスを楽しんできて下さい。
#
# 留守番の人のことも気にかけて下さい。
#
# 今何時かわかりますか
#
# 時間を知りたい。
#
# 今何時かわかりますか
#
# 相手の遅刻を怒っている。
#
# 昔は、電車で化粧をする人はいなかった。
#
# 電車で化粧をするのは許しがたい。
#
# 疲れていませんか。
#
# 休憩しましょう。
#
# 夕食を食べに行きませんか。
#
# お腹がすいた。
#
# ここはどこですか。
#
# 道に迷っています。
#
# ずっと前から言おうと思っていた。
#
# 今言おうとしている。
#
# どうしても行きたいというのなら行けばいい。
#
# 行かない方がいいと思っている。
#
# どうしても行きたいというのなら行けばいい。
#
# 行って欲しくない。
#
# ピーマンの浅漬けを食べたことがありますか。
#
# ピーマンの浅漬けはめずらしい。
#
# 紅茶とコーヒー、どちらにしますか。
#
# 紅茶でもコーヒーでも淹れる準備がある。
#
# 女子トイレは3階にもありますよ。
#
# 3階のトイレは空いている。
#
# 偉人伝を子どもに読ませることは本当にいいことなのでしょうか。
#
# 偉人伝を子どもに読ませることは、あまりいいことだとは思えない。
#
# おなかがすいた。
#
# 妊娠しているに違いない。
#
# ついに宝くじに当選した。
#
# 有権者から選ばれた。
#
# ゴリラは絶滅の危機に瀕している。
#
# みんなゴリラが嫌いだからだ。
#
# テレビで寒天ダイエットについて放映したら、寒天が売り切れた。
#
# 寒天がダイエットするのは簡単だ。
#
# パンにカビが生えていた。
#
# よく発酵していた。
#
# ブラックバスやブルーギルがフナやタナゴを脅かしている。
#
# ブラックバスは気が弱い。
#
# 肩たたきにあった。
#
# 肩こりだった。
#
# 交通事故死者よりも自殺者の方が多い。
#
# 交通事故死よりも自殺を選ぶ人が多い。
#
# 今日は仕事が全然できなかった。
#
# 失業したからだ。
#
# 最近、残業が多い。
#
# 私は仕事が大好きだ。
#
# 最近の子どもは、蚊帳を知らない。
#
# 蚊がいなくなった。
#
# 私はあえて会社を辞めた。
#
# 首になった。
#
# 首相がめまぐるしく交代した。
#
# 首相になると交代したくなる。
#
# 女性の管理職が増えた。
#
# 女性は管理される立場にある。
#
# 商談がやっとまとまった。
#
# じゃんけんで決着をつけた。
#
# 昔ほど星が見えない。
#
# 星がかくれんぼをしている。
#
# 昔ほど星が見えない。
#
# 星が光るのをやめた。
#
# 中央線は人身事故が多い。
#
# 中央線の運転手は運転が下手だ。
#
# 都議会議員選挙の投票率が問題になっている。
#
# 立候補者が少ない。
#
# 土曜日の朝は、電車が空いている。
#
# 事故が多発するからだ。
#
# 彼には頭が上がらない。
#
# 私は頭が重い。
#
# 彼女の話は作り話が多い。
#
# 彼女は作家である。
#
# 養蚕業の衰退は著しい。
#
# 蚕が絶滅の危機にあるからだ。
#
# パンにカビが生えていた。
#
# パンは古かった。
#
# ブラックバスやブルーギルがフナやタナゴを脅かしている。
#
# 外来種が増えた。
#
# 靴擦れができた。
#
# 新しい靴を履いた。
#
# 靴擦れができた。
#
# 長い距離を歩いた。
#
# 六法全書を読破した。
#
# 法律に興味があった。
#
# お店でもらった風船が飛んでしまった。
#
# ヘリウムは酸素より軽い。
#
# ひげを剃った。
#
# ひげが伸びていた。
#
# まりもが浮いた。
#
# 酸素がまりもの表面についた。
#
# もうすぐ三歳です。
#
# もうすぐ誕生日だ。
#
# インフルエンザの予防接種をした。
#
# インフルエンザウイルスに感染すると体調を崩す。
#
# スペインでは干ばつに悩まされている。
#
# スペインではずっと雨が降っていない。
#
# レールにつなぎ目がある。
#
# 金属が膨脹したり縮んだりするからだ。
#
# レールにつなぎ目がある。
#
# 電車がガタンゴトンと揺れる。
#
# 欧州の通貨が単一通貨になった。
#
# 国ごとに通貨が違っていた。
#
# 家電のスイッチを入れたら、主電源が落ちた。
#
# 家電を一度に使いすぎた。
#
# 悔し涙を流した。
#
# 悔しかった。
#
# 株で2000万円儲けた。
#
# 株を売った。
#
# 癌検診でひっかかった。
#
# 癌の疑いがある。
#
# 頑張りによっては、昇給してやってもいい。
#
# 私は昇給を決定する権限を持っている。
#
# 救急車のサイレンが聞こえる。
#
# 誰かが救急車を呼んだ。
#
# 交番で被害届を書いた。
#
# 被害にあった。
#
# 首都高速道路公団が首都高速道路株式会社に変わった。
#
# 公団が民営化した。
#
# 樹氷ができた。
#
# 気温が低い。
#
# 樹氷ができた。
#
# 細かい水滴が冷やされた。
#
# 暑いから、帽子をかぶって行きなさい。
#
# 暑いときは帽子をかぶるといい。
#
# 女性の管理職が増えた。
#
# 管理職は男性が多い。
#
# 水族館に行ったら、オジサンという名前の魚がいたんですよ!
#
# オジサンという名前の魚がいると知って驚いた。
#
# 雪下ろしをする。
#
# 雪の重みで家が潰れる。
#
# 川霧が立っている。
#
# 大気より水温のほうが高い。
#
# 霜柱がたった。
#
# 気温が低くなった。
#
# 霜柱がたった。
#
# 水が氷になった。
#
# 足のリハビリをしている。
#
# 足が自由に動かない。
#
# 太郎の人生の目標は幸せになることだそうだ。
#
# 太郎の人生の目標を知らなかった。
#
# 太郎の郵便番号を調べた。
#
# 太郎の郵便番号が分らなかった。
#
# 太郎の郵便番号を調べた。
#
# 郵便物を太郎に送りたい。
#
# 爪を切った。
#
# 爪が伸びていた。
#
# 日本は少子高齢化の道を進んでいる。
#
# 日本は合計特殊出生率が減少し続けている。
#
# 彼は、ヒートアイランド学会の会長に就任した。
#
# 彼はヒートアイランド学界の権威だ。
#
# 彼は、ヒートアイランド学会の会長に就任した。
#
# 彼はヒートアンランド研究の第一人者だ。
#
# 彼は功績が認められて表彰された。
#
# 彼は功労者である。
#
# 平日の朝の駅は混んでいる。
#
# 通勤に電車を使う人が多い。
#
# 片眼の達磨に眼を入れた。
#
# 念願がかなった。
#
# 補聴器をつけた。
#
# 耳の聞こえが悪かった。
#
# 満潮と台風の接近が重なるので、厳重な警戒が必要だ。
#
# 満潮と台風が重なると、危険である。
#
# 明日、彼女は会社に面接に行く。
#
# 彼女は就職活動をしている。
#
# 老人ホームが次々に開所している。
#
# 介護産業が増えて来た。
#
# 老人ホームの地図記号を国土地理院が初めて公募した。
#
# 今の地図には老人ホームは載っていない。
#
# あの寿司屋は行列のできる寿司屋として近所で評判だ。
#
# その寿司屋の寿司はうまい。
#
# あの寿司屋は行列のできる寿司屋として近所で評判だ。
#
# その寿司屋の寿司は安い。
#
# あの寿司屋は行列のできる寿司屋として近所で評判だ。
#
# その寿司屋は店員の感じがいい。
#
# お菓子のパッケージの復刻版が人気を呼んでいる。
#
# 復刻版には価値がある。
#
# お昼だというのに、おなかがすかない。
#
# どこか体の具合がわるいのかもしれない。
#
# この製品は廃番になる。
#
# 人気がなかった。
#
# この病院はいつも混んでいる。
#
# この病院は人気がある。
#
# ウサギの育児放棄について相談したい。
#
# ウサギが育児放棄をした。
#
# ウサギの育児放棄について相談したい。
#
# ウサギが子どもを産んだ。
#
# ウサギの育児放棄について相談したい。
#
# ウサギといえば育児放棄である。
#
# ウサギの育児放棄について相談したい。
#
# ウサギの繁殖を考えている。
#
# パソコンを強制終了した。
#
# パソコンを止めるよう圧力を受けた。
#
# 安易に解熱剤を使うのは控えた方がいい。
#
# 解熱剤は効きすぎる。
#
# 何度ノックをしても返事がない。
#
# 周りがうるさくて聞こえないのだろう。
#
# 何度ノックをしても返事がない。
#
# 誰もいないのだろう。
#
# 何度ノックをしても返事がない。
#
# 眠っているのだろう。
#
# 家族はもう寝ていると思った。
#
# 家の電気が消えていた。
#
# 家族はもう寝ていると思った。
#
# 帰宅時間が遅かった。
#
# 開店セールに間に合いたくて駅から走った。
#
# 家を出たのが予定より遅かった。
#
# 開店セールに間に合いたくて駅から走った。
#
# 開店セールには、走るだけの価値があるに違いないと思ってた。
#
# 開店セールに間に合いたくて駅から走った。
#
# 電車が遅れた。
#
# 甘いものが食べたくなった。
#
# イライラしている。
#
# 甘いものが食べたくなった。
#
# 疲れている。
#
# 救急車のサイレンが聞こえる。
#
# 事故があって怪我人が出た。
#
# 靴擦れができた。
#
# 靴が合っていなかった。
#
# 個人情報保護法がつくられた。
#
# 個人情報がいい加減に扱われていた。
#
# 今朝は朝食をとらなかった。
#
# 今朝は食欲がなかった。
#
# 今朝は朝食をとらなかった。
#
# 今朝は寝坊した。
#
# 今朝は朝食をとらなかった。
#
# 今朝は忙しかった。
#
# 今朝は朝食をとらなかった。
#
# 昨夜は酒を飲みすぎた。
#
# 四十日連続の真夏日を記録した。
#
# 異常気象である。
#
# 子どもにアザができると、虐待かと怪しまれるのではないかとドキドキする。
#
# 私は子どもを虐待していない。
#
# 子どもにアザができると、虐待かと怪しまれるのではないかとドキドキする。
#
# 私は子どもを虐待している。
#
# 子どもの手足があたたかい。
#
# 子どもは眠いにちがいない。
#
# 自動車がスリップしたのを見た。
#
# 雨が降り始めたところだった。
#
# 秋は行楽シーズンだ。
#
# 食物の実りの時期だ。
#
# 衆議院選挙を前に、新党が誕生した。
#
# 候補者同志の仲間割れがあった。
#
# 人生を楽しもうと決めた。
#
# 人生を深刻に考える傾向があった。
#
# 舌打ちするクセがある。
#
# 育ちが悪い。
#
# 足腰が弱ってきた。
#
# 運動不足だった。
#
# 太郎に貸した本がなくなった。
#
# 誰かが太郎に貸した本を盗った。
#
# 太郎の人生の目標は幸せになることだそうだ。
#
# 太郎に人生の目標を聞いた。
#
# 太郎の人生の目標は幸せになることだそうだ。
#
# 誰かから太郎の人生の目標を聞いた。
#
# 男性人口が減少した。
#
# 男性の寿命は短い。
#
# 昼食はおにぎり一個だけだった。
#
# 体調がすぐれなかった。
#
# 日本文学史の概説書を読んだ。
#
# 日本文学史に興味があった。
#
# 尿検査で「とう」が出た。
#
# 糖尿病の可能性がある。
#
# 彼には頭が上がらない。
#
# 私より彼のほうが優れている。
#
# 彼は、自分の家が炎上するのを、ただ眺めていた。
#
# 火事を前にして、なすすべが無かった。
#
# 彼は、自分の家が炎上するのを、ただ眺めていた。
#
# 火事を前にして、茫然とした。
#
# 彼は会社に対して背任行為をした。
#
# 彼は会社に恨みを持っていた。
#
# 彼は彼女に電話した。
#
# 彼は彼女に用があった。
#
# 彼女は再び東京に行った。
#
# 彼女は都会が恋しくなった。
#
# 鼻水がとまらない。
#
# アレルギー体質である。
#
# 鼻水がとまらない。
#
# 風邪をひいている。
#
# 病院に行った。
#
# 見舞いに行った。
#
# 病院に行った。
#
# 子どもが風邪をひいた。
#
# 病院に行った。
#
# 私は医師だ。
#
# 病院に行った。
#
# 私は看護師だ。
#
# 病院に行った。
#
# 私は妊娠している。
#
# 病院に行った。
#
# 私は病院に勤めている。
#
# 病院に行った。
#
# 体調が悪かった。
#
# 娘は、ピアノの練習をしている。
#
# 娘はピアノが弾けない。
#
# 30才になってしまった。
#
# 30才になりたくなかった。
#
# あの人は腕に包帯を巻いている。
#
# 怪我をした。
#
# お年寄りを狙った詐欺事件が増えている。
#
# お年寄りはだまされやすい。
#
# その虫は、図鑑で調べたら、カネタタキだとわかった。
#
# 図鑑で調べると、なんの虫かがわかる。
#
# もう少し段階を追って説明してください。
#
# 説明が悪くて理解できなかった。
#
# やけ酒を飲んだ。
#
# イヤなことがあった。
#
# インフルエンザの検査は陰性だった。
#
# インフルエンザの疑いがあった。
#
# カレンダーをめくった。
#
# 1か月が過ぎた。
#
# グリコ・森永事件は時効を迎えた。
#
# 事件の手がかりが掴めなかった。
#
# ドイツに出張した。
#
# 会社の取引先がドイツにある。
#
# パスポートを取りに行った。
#
# 海外に行く。
#
# パスポートを取りに行った。
#
# 有効期限が切れていた。
#
# 英会話スクールが無料体験チケットを配布している。
#
# 英会話スクールは生徒を募集している。
#
# 援助交際を略して援交というそうだ。
#
# どこからか「援助交際を略して援交という」という情報を入手した。
#
# 縁石に乗りあげてしまった。
#
# 縁石に乗りあげたくなかった。
#
# 科学の進歩によって、近視は手術で治る時代になった。
#
# 昔は、近視は手術では治らなかった。
#
# 火の気がないところから、火の手があがった。
#
# 放火の疑いがある。
#
# 各地で花火大会が開催されている。
#
# 日本人は花火が好きである。
#
# 株で2000万円儲けた。
#
# 株価が上がった。
#
# 吸収力に自信のある紙オムツが発売になった。
#
# 紙オムツには吸収力が必要である。
#
# 去年のズボンがはけなくなった。
#
# 去年より太った。
#
# 携帯電話が通じない。
#
# 電源が入っていない。
#
# 携帯電話が通じない。
#
# 電池が切れた。
#
# 携帯電話が通じない。
#
# 電波が届かない。
#
# 結婚式に出席する。
#
# 招待状が来た。
#
# 更衣室でお金がなくなった。
#
# 誰かがお金を盗んだ。
#
# 紅組が白組に不戦勝した。
#
# 白組は試合を棄権した。
#
# 今週末も天気が悪いそうだ。
#
# 「今週末も天候はよくないでしょう」と言っていたのを聞いた。
#
# 今日勝てば、阪神の優勝が決まる。
#
# 阪神の優勝が間近だ。
#
# 最近、残業が多い。
#
# 仕事が多くて溜まっている。
#
# 四十日連続の真夏日を記録した。
#
# 暑い日が毎日続いている。
#
# 私は冷え性だ。
#
# 血行が悪い。
#
# 自転車のブレーキが効かなくて、こわい思いをした。
#
# 自転車のブレーキがこわれた。
#
# 自動車がスリップしたのを見た。
#
# タイヤが摩耗していた。
#
# 車の運転には自信がもてない。
#
# 自動車の運転免許を持っている。
#
# 車の運転には自信がもてない。
#
# 車の運転をしたことがある。
#
# 種が発芽した。
#
# 水をやっていた。
#
# 秋は行楽シーズンだ。
#
# 木々が紅葉して美しい時期だ。
#
# 床屋さんに行った。
#
# 髪が伸びていた。
#
# 人生の厳しさを思い知った。
#
# 何か辛いことがあった。
#
# 水道料がいつもより高い。
#
# どこかで漏水している。
#
# 水道料がいつもより高い。
#
# 水を使いすぎた。
#
# 昔ほど星が見えない。
#
# 空気がきれいではなくなった。
#
# 昔ほど星が見えない。
#
# 地上が明るくなった。
#
# 扇風機をつけた。
#
# ...
#
# キャベツでヤキソバ作った。
#
# 汚れがよく落ちるという洗濯洗剤を買って来た。
#
# 周囲の人が、汚れがよく落ちると言っている洗濯洗剤を買って来た。
#
# 汚れがよく落ちるという洗濯洗剤を買って来た。
#
# 宣伝で、汚れがよく落ちると言っている洗濯洗剤を買って来た。
#
# 昨晩のおかずは肉ジャガと青菜のお浸しだった。
#
# 昨晩の主食はパンだった。
#
# 娘は塗り絵が好きだ。
#
# 娘は塗り絵をながめるのが好きだ。
#
# この商品は20%引きだ。
#
# この商品は定価の20%引きだ。
#
# ウナギが食べたい。
#
# ウナギの蒲焼が食べたい。
#
# ストッキングが伝線したので、マニキュアを塗った。
#
# マニキュアをストッキングに塗った。
#
# マニキュアを塗った。
#
# マニキュアを爪に塗った。
#
# モノレールで駅前の開発が進んだ。
#
# モノレールの開通で駅前の開発が進んだ。
#
# 印刷機の調子が悪くて、うまくいかない。
#
# 印刷機の調子が悪くて、印刷がうまくいかない。
#
# 英会話スクールが無料体験チケットを配布している。
#
# 無料でレッスンを体験できる。
#
# 宴会があるから、遅くなるよ。
#
# 宴会があるから、帰りが遅くなるよ。
#
# 横断歩道は左右を確認して渡りましょう。
#
# 横断歩道では左右の安全を確認して渡りましょう。
#
# 横断歩道は手をあげて
#
# 横断歩道は手をあげて渡りましょう。
#
# 横断歩道は手をあげて
#
# 子どもは、横断歩道は手をあげて渡りましょう。
#
# 花子は娘に家事を手伝うように言った。
#
# 娘は花子の娘である。
#
# 警戒心を抱かれないように、笑顔でいるように努めたが、失敗した。
#
# 笑顔でいたが、警戒心を抱かれた。
#
# 警戒心を抱かれないように、笑顔でいるように努めたが、失敗した。
#
# 笑顔でいることができなくて、警戒心を抱かれた。
#
# 五羽の仔ウサギが産まれて、三羽が死んでしまった。
#
# 五羽の仔ウサギが産まれて、三羽の仔ウサギが死んでしまった。
#
# 御利益がありますようにとお願いした。
#
# 御利益がありますようにと神仏にお願いした。
#
# 国民年金保険料の納付率が問題になっている。
#
# 国民年金保険料の納付率の低さが問題になっている。
#
# 昨晩のおかずは肉ジャガと青菜のお浸しだった。
#
# 昨晩はごはんを食べた。
#
# 自分の意見をきちんと述べられるようにしつけられている。
#
# 自分の意見をきちんと述べられるように、家庭でしつけられている。
#
# 写真館で証明写真を撮影した。
#
# 私はカメラマンに撮影された。
#
# 写真館で証明写真を撮影した。
#
# 私は証明写真を撮った。
#
# 写真館で証明写真を撮影した。
#
# 写真館のカメラマンが、写真館のスタジオで、私を撮影した。
#
# 秋葉原から浅草橋までなら歩いて行けるよ。
#
# 秋葉原駅周辺から浅草橋駅周辺までなら歩いて行ける。
#
# 床屋さんに行った。
#
# 床屋さんに髪を切りに行った。
#
# 証拠物件を押収した。
#
# 裁判所又は捜査機関が証拠物件を押収した。
#
# 寝る前に絵本を読むのが習慣になっている。
#
# 寝る前に、親が子どもに絵本を読んでやるのが習慣になっている。
#
# 総武線沿線より中央線沿線の方が家賃が高い。
#
# 総武線沿線にある家より中央線沿線にある家の方が家賃が高い。
#
# 太郎が花子を刺したのは、正当防衛だった。
#
# 太郎が花子を包丁で刺した。
#
# 太郎と花子は婚姻届を提出した。
#
# 太郎と花子は役所に婚姻届を提出した。
#
# 太郎のおみやげは、ちんすこうだった。
#
# 太郎はお土産にちんすこうを買って来た。
#
# 都議会議員選挙の投票率が問題になっている。
#
# 都議会議員選挙の投票率の低さが問題になっている。
#
# 年下は恋愛の対象にならない。
#
# 年下の異性は恋愛の対象にならない。
#
# 娘は塗り絵が好きだ。
#
# 娘は塗り絵を塗るのが好きだ。
#
# 携帯にメールが入った。
#
# 携帯電話に手紙が入った。
#
# 携帯にメールが入った。
#
# 携帯電話にメールが入った。
#
# 控訴を棄却する。
#
# 裁判所が控訴を却下する。
#
# 証拠物件を押収した。
#
# 裁判所又は捜査機関が証拠物件をしまった。
#
# 違憲判決が下った。
#
# 裁判所の判事が、違憲であると判決を下した。
#
# ウイルスに感染した。
#
# パソコンにコンピューターウイルスが入った。
#
# ウイルスに感染した。
#
# 体内にウイルスが入った。
#
# 宴会があるから、遅くなるよ。
#
# 宴会があると、帰りは早い。
#
# 寝る前に絵本を読むのが習慣になっている。
#
# 寝る前に、子どもに歌を歌ってあげる。
#
# あの店は、開店一周年だ。
#
# 店の回転は早い。
#
# ごみを分別回収してのリサイクル活動が盛んだ。
#
# ごみは全てリサイクルできる。
#
# そんなことはサルでもできる。
#
# そんなことはアリにもできる。
#
# ぼけの防止のために料理を始めた。
#
# 料理をするとぼけない。
#
# 一般に小型の哺乳類は冬眠する。
#
# 冬は眠い。
#
# 紅白戦で紅組が勝った。
#
# 女性の方が優れている。
#
# 松茸は人工栽培できないので、外国から輸入している。
#
# 日本人は松茸が好きだ。
#
# 他人の評価ばかり気にしてはいられない。
#
# 人はみんな自分勝手に生きている。
#
# 昼食はおにぎり一個だけだった。
#
# いつもは昼食は食べない。
#
# ボタンインコもラブバードと言われる。
#
# ボタンインコ以外にもラブバードと言われる鳥がいる。
#
# 今朝は朝食をとらなかった。
#
# いつも朝食をとる。
#
# 今朝も朝食をとらなかった。
#
# いつも朝食をとらない。
#
# そんなことはサルでもできる。
#
# そんなことはだれでもできる。
#
# オリオン座は冬の星座である。
#
# 季節毎に見える星座が違う。
#
# キノコには毒をもったものがある。
#
# キノコには毒のないものもある。
#
# トンガは王国だ。
#
# 王国でない国もある。
#
# 兄弟でも似ていないことはある。
#
# 兄弟は似ているのが普通だ。
#
# 国語は得意だったが、和歌だけはちんぷんかんぷんだった。
#
# 和歌は国語に含まれる。
#
# 今年も白鳥が渡来したが、去年より遅かった。
#
# 毎年、白鳥が渡来している。
#
# 使っていたプラスチックの蓋が割れた。
#
# プラスチックは劣化する。
#
# 子どもが加害者になる事件が増えている。
#
# 子どもの犯罪が増えている。
#
# 子どもが被害者になる事件も増えている。
#
# 子どもが事件に巻きこまれている。
#
# 大潮は、満月と新月の時に起こる。
#
# 小潮は半月のときに起こる。
#
# 茶道にも華道にも作法がある。
#
# 一般に〜道と言われるものには作法がある。
#
# 鳥が卵を産んだ。
#
# 雛は卵から生まれる。
#
# 仏さまにお線香を上げた。
#
# 神仏には線香を捧げる。
#
# 明日から二学期だ。
#
# 今日で夏休みは終わりだ。
#
# 理科は得意だったが、物理だけはわけがわからなかった。
#
# 物理は理科に含まれる。
#
# お菓子のパッケージの復刻版が人気を呼んでいる。
#
# 復刻版は人気が出る。
#
# 松茸は人工栽培できない。
#
# 他のキノコは人工栽培できる。
#
# 図書館へよく行く田中さんは非常に物知りだ。
#
# 図書館へ行くと物知りになれる。
#
# 太郎は蚊に刺された。
#
# 虫は人を刺す。
#
# 昼食はおにぎり一個だけだった。
#
# もっと食べられた。
#
# 道にまよって交番で聞いた。
#
# 困ったときは交番に行けばよい。
#
# ダイエット中なのにアイスクリームを食べてしまった。
#
# ダイエット中はアイスクリームを食べないほうがいい。
#
# 花子は、サンタクロースの存在を信じている。
#
# サンタクロースの存在を信じていない人もいる。
#
# 今年の流行色はターコイズブルーだ。
#
# 年ごとに、流行の色がある。
#
# 使っていたプラスチックの蓋が割れた。
#
# すべてのものは劣化していく。
#
# 私はいつも姉のお下がりばかりだ。
#
# 妹はお下がりを着ることが多い。
#
# 秋葉原から浅草橋までなら歩いて行けるよ。
#
# 秋葉原から浅草橋は、交通機関を使うのが普通だ。
#
# 他人の評価ばかり気にしてはいられない。
#
# 多少は他人の評価も気にしている。
#
# 天気予報は予報でしかない。
#
# 天気予報はあたらない。
#
# 日本にも餓死する人はいる。
#
# 日本では、餓死するのはめずらしい。
#
# 平日の朝の駅は混んでいる。
#
# 土・日の朝の駅は空いている。
#
# ブラックバスやブルーギルがフナやタナゴを脅かしている。
#
# 外来種のほうが固有種より強い。
#
# もみじが色付いてきた。
#
# 秋になると木々は紅葉する。
#
# おたふく風邪の予防接種を受けた。
#
# おたふく風邪は女性である。
#
# キノコには毒をもったものがある。
#
# キノコをとるには免許がいる。
#
# サツマイモの栽培には、火山灰台地が適している。
#
# サツマイモの栽培には、水がたくさん必要だ。
#
# チューリップの球根を植える。
#
# チューリップの葉は捨てる。
#
# テレビはニュースしか見ない。
#
# テレビはニュース番組だけ見ない。
#
# 一日をいたずらに過ごした。
#
# 私はいたずらっ子だ。
#
# 下りのエスカレーターは、点検中だ。
#
# 上りのエスカレーターは使えない。
#
# 果物が白い器にのせてあるのが、おしゃれだ。
#
# 果物は白い器にのせるにかぎる。
#
# 今週末も天気が悪いそうだ。
#
# 先週末は脳天気だった。
#
# 今夜も帰りは遅いのですか。
#
# 昨夜は帰りが早かった。
#
# 姉より妹のほうが背が高い。
#
# 姉は猫背である。
#
# 叔父は大学教授をしています。
#
# 父は大学教授をしています。
#
# 小泉首相はパフォーマンスが好きだ。
#
# 首相は道化者だ。
#
# 人身事故で電車が遅れた。
#
# 電車は遅い。
#
# 昔は天動説が信じられていた。
#
# 今は鼓動説が信じられている。
#
# 太郎は駅までの道を尋ねられた。
#
# 太郎は道先案内人である。
#
# 茶道にも華道にも作法がある。
#
# 茶道と華道の作法は同じである。
#
# 中身はちっとも変わってないな。
#
# 白身は変わった。
#
# 電車には、弱冷房車輛がある。
#
# 冷房を入れると車輌が壊れる。
#
# 党首が全国を遊説する。
#
# 党首以外は遊説しない。
#
# 日曜日まで学校に行った。
#
# 平日は教会に行った。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女はひらがな書きの文が読めない。
#
# 風で帽子がとんだ。
#
# 帽子は空を飛ぶ。
#
# 腹筋運動を日課にしている。
#
# 課題は腹筋運動だ。
#
# 母はすぐ怒る。
#
# 母は笑ったことがない。
#
# 昨日は雨が降っていた。
#
# 今日は雨は降っていない。
#
# 昨日も雨が降っていた。
#
# 今日も雨が降っている。
#
# 水曜日だけは大学に行かない。
#
# 水曜日以外は大学に行く。
#
# 東洋には尺という単位があった。
#
# 西洋には尺という単位がなかった。
#
# 日曜日まで学校に行った。
#
# 平日は学校に行った。
#
# このソフトはシェアウェアです。
#
# フリーウェアのソフトもある。
#
# このデッドボールは当てた方も痛い。
#
# 当てられた方は痛い。
#
# この仕事は精神的にはハードだ。
#
# この仕事は肉体的にはハードではない。
#
# グルタミン酸はうまみ成分のひとつだ。
#
# グルタミン酸以外にもうまみ成分がある。
#
# 遠距離通話なら、携帯電話で掛けた方がいい。
#
# 近距離通話なら、固定電話で掛けた方がいい。
#
# 過度の期待は、かえって害になる。
#
# 適度の期待は、有益である。
#
# 現金は流動資産だ。
#
# 家は固定資産だ。
#
# 黒橋研究室の受付けは隣の入口です。
#
# 隣も黒橋研究室だ。
#
# 今週末も天気が悪いそうだ。
#
# 先週末は天気が悪かった。
#
# 今日は浴衣姿の人が多い。
#
# 普段、浴衣姿で歩いている人は少ない。
#
# 最近は、晴雨兼用の傘がある。
#
# 雨だけしか使えない傘もある。
#
# 災禍を被ったのは、この地区だけではない。
#
# 他の地区も災禍を被った。
#
# 衆議院には解散がある。
#
# 参議院には解散はない。
#
# 女性が土俵にあがることは伝統的に禁じられている。
#
# 男性は土俵にあがることができる。
#
# 消しゴムがなくなった。
#
# 消しゴムは消耗品である。
#
# 中身はちっとも変わってないな。
#
# 外見は変わった。
#
# 土曜日の朝は、電車が空いている。
#
# 平日の電車は満員だ。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女は漢字の読み書きができない。
#
# 非常事態との認識もある。
#
# 非常事態ではないとの認識もある。
#
# 夢の中では彼女は淑女だった。
#
# 現実の彼女は淑女ではない。
#
# 誘拐されるのは子どもだけではない。
#
# 大人も誘拐される。
#
# 幼稚園の先生になりたいと、子どものころは思っていた。
#
# 今はもう子どもではない。
#
# ハンサムでない人とは付き合わない。
#
# ハンサムな人となら付き合う。
#
# 乙女のはじらいが感じられない。
#
# 私は乙女という年ではない。
#
# 海の家ではラーメンがおいしい。
#
# 海の家ではおにぎりもおいしい。
#
# 今夜も帰りは遅いのですか。
#
# いつも帰りが遅い。
#
# 今夜も帰りは遅いのですか。
#
# このところ帰りが遅い。
#
# 田中選手一人で点数を稼いだ。
#
# 田中選手以外は点数を入れなかった。
#
# 日本は安全だと言われてきた。
#
# 海外は安全ではないと言われてきた。
#
# 日本人は愛情を表現するのが下手だと言われてきた。
#
# 日本人も最近は愛情表現が上手になってきた。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女はアルファベットの読み書きができない。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女は数字の読み書きができない。
#
# 病気のときは、健康のありがたみが身にしみる。
#
# 健康なときは、健康のありがたみに気づかない。
#
# 病気のときは、健康のありがたみが身にしみる。
#
# 普段は、健康のありがたみに気づかない。
#
# 野生のサル生息の最北限は、下北半島である。
#
# 北海道にサルはいない。
#
# 誘拐されるのは子どもだけではない。
#
# ペットも誘拐される。
#
# 幼稚園の先生になりたいと、子どものころは思っていた。
#
# 今はもう、幼稚園の先生になりたいとは思っていない。
#
# 幼稚園の先生になりたいと、子どものころは思っていた。
#
# 今は幼稚園の先生をしていない。
#
# 幼稚園の先生になりたいと、子どものころは思っていた。
#
# 幼稚園の先生になってみると、それほど自分にあっていると思えない。
#
# 陽子は昇給した。
#
# 昇給しなかった人もいる。
#
# この方法は効率が悪い。
#
# もっと効率のいい方法があるに違いない。
#
# トヨタが高級車「レクサス」店を開業した。
#
# トヨタは自動車メーカーである。
#
# 韻文では韻律が大事だ。
#
# 散文では韻律は問題にしない。
#
# 凹面鏡は、反射望遠鏡などに利用されている。
#
# 凹面鏡は、反射望遠鏡以外にも利用されている。
#
# 下りのエスカレーターは、点検中だ。
#
# 上りのエスカレーターは、点検中ではない。
#
# 禁煙席は満席です。
#
# 喫煙席は空いています。
#
# 今夜も帰りは遅いのですか。
#
# 昨夜は帰りが遅かった。
#
# 最近の子どもは、蚊帳を知らない。
#
# 最近の子ども以外は、蚊帳を知っている。
#
# 私の弟はコンピューターサイエンティストです。
#
# 私はコンピューターサイエンティストではない。
#
# 次回はもうすこし頑張ってください。
#
# 今回はいまひとつだった。
#
# 若さだけを武器にして戦ってきた。
#
# 若さ以外に武器を持っていなかった。
#
# 昔、話していた言葉と現代の言葉は違う。
#
# 言葉は変化する。
#
# 昔は、電車で化粧をする人はいなかった。
#
# 最近は、電車で化粧をする人がいる。
#
# 中央線は人身事故が多い。
#
# 山手線は中央線ほど人身事故が多くない。
#
# 東京の人は冷たい。
#
# 東京以外の人は冷たくない。
#
# 日本の通貨は、円である。
#
# 米国の通貨は、円ではない。
#
# 日本は安全だと言われてきた。
#
# 最近は日本も安全とは言えなくなってきた。
#
# 日本人は愛情を表現するのが下手だと言われている。
#
# 日本人以外に、愛情表現が上手だと言われている人たちがいる。
#
# 日本人は愛情を表現するのが下手だと言われてきた。
#
# 日本人以外に、愛情表現が上手だと言われている人たちがいる。
#
# 彼女は心も美しい。
#
# 彼女は容姿が美しい。
#
# 保育園では、昼寝をする。
#
# 幼稚園では昼寝をしない。
#
# 一般に小型の哺乳類は冬眠する。
#
# リスは冬眠する。
#
# 韻文では韻律が大事だ。
#
# 漢詩は韻律を問題にしない。
#
# 一般に小型の哺乳類は冬眠する。
#
# ヤマネは冬眠する。
#
# 一般に小型の哺乳類は冬眠する。
#
# リスは冬眠する。
#
# 女性が土俵にあがることは伝統的に禁じられている。
#
# 女性は相撲をしてはいけない。
#
# お菓子のパッケージの復刻版が人気を呼んでいる。
#
# お菓子が人を呼んでいる。
#
# ウメがなったので、梅酒を作ろう。
#
# ウメがなったので、梅酒を作った。
#
# キャベツを買って来て、ヤキソバを作った。
#
# 芽キャベツを買って来た。
#
# グルタミン酸はうまみ成分のひとつだ。
#
# グルタミン酸は辛味成分だ。
#
# ゴキブリが飛んで、腰をぬかした。
#
# ゴキブリが腰をぬかした。
#
# 一般に小型の哺乳類は冬眠する。
#
# 大型の哺乳類は冬眠する。
#
# 横断歩道は左右を確認して渡りましょう。
#
# 横断歩道では前後の確認をする。
#
# 火を通したタマネギは甘い。
#
# タマネギは甘い。
#
# 海の家ではラーメンがおいしい。
#
# 海の家ではローメンがおいしい。
#
# 教授会で君はクビだと言われた。
#
# 君は首が長いと言われた。
#
# 健太朗は、威圧的な態度で、気の弱さを隠していた。
#
# 健太郎は気の弱さを隠していた。
#
# 誤解がとけて、楽になった。
#
# 誤解が楽になった。
#
# 高血圧なので、塩分の摂り過ぎには注意している。
#
# 高血圧には塩分が良い。
#
# 今日は土用丑の日だから、鰻を食べる。
#
# 今日は土用寅の日だ。
#
# 今日勝てば、阪神の優勝が決まる。
#
# 阪神が優勝した。
#
# 私は保育園に苦情を言った。
#
# 私は御礼を言った。
#
# 首相は、自分の影響力の大きさを考えて行動しない。
#
# 首相は行動しない。
#
# 寝ているときだけジョンはかわいい。
#
# ジョンはかわいい。
#
# 心の優しい男の人は素敵だ。
#
# 男の人は素敵だ。
#
# 水族館に行ったら、オジサンという名前の魚がいたんですよ!
#
# オバサンという名前の魚がいる。
#
# 昔は、電車で化粧をする人はいなかった。
#
# 電車で食事をする人がいなかった。
#
# 太郎に貸した本がなくなった。
#
# 太郎に本を借りた。
#
# 台風７号が発生し、日本に接近の恐れ。
#
# 台風8号が発生した。
#
# 大量のホルムアルデヒドが見つかったので、火星に生命が存在する可能性がある。
#
# 火星には生きものが存在する。
#
# 地震が起きたら津波に注意することだ。
#
# 地震が起こった。
#
# 土地を掘ったら、土器片が見つかった。
#
# 土偶が見つかった。
#
# 東大の赤門は有名だ。
#
# 東大の青門は有名だ。
#
# 日本は予選を通過したら、ワールドカップに参加できる。
#
# 日本は予選を通過した。
#
# 背の高い男の人は魅力的だ。
#
# 男の人は魅力的だ。
#
# 彼は財産を守るために遺言書を書くことにした。
#
# 彼は財産を守るために遺言書を書いた。
#
# 彼は二足のわらじをはいている。
#
# 彼はわらじをはいている。
#
# 彼女は、ひらがなとカタカナしか読み書きできない。
#
# 彼女は読み書きができない。
#
# 母が言うには、私は猫背らしい。
#
# 私は熊猫背らしい。
#
# 夢の中では彼女は淑女だった。
#
# 彼女は夢見る淑女だ。
#
# 遊んでいるときだけ彼は元気だ。
#
# 彼は元気だ。
#
# お香を焚いたら、リラックスした。
#
# お香を焚いた。
#
# お店でもらった風船が飛んでしまった。
#
# 風船をお店でもらった。
#
# この店のお菓子は全て手作りでおいしい。
#
# この店のお菓子は全て手作りだ。
#
# アナウンスが流れたので、降車ボタンを押した。
#
# アナウンスが流れた。
#
# ゴキブリが飛んで、腰を抜かした。
#
# ゴキブリが飛んだ。
#
# セールが始まるので、開店前から店先に並んだ。
#
# 開店前から店先に並んだ。
#
# ゾウの鼻はなぜ長いのでしょうか。
#
# ゾウの鼻は長い。
#
# 科学の進歩によって、近視は手術で治る時代になった。
#
# 科学は進歩した。
#
# 科学の進歩によって、近視は手術で治る時代になった。
#
# 近視は手術で治る時代になった。
#
# 花火大会があるので、浴衣姿の人が目立つ。
#
# 花火大会がある。
#
# 寒くても痩せ我慢をした。
#
# 寒かった。
#
# 紅組が白組に不戦勝した。
#
# 紅組は不戦勝した。
#
# 今日はおいしいお酒が飲めたので、気分がいい。
#
# 今日はおいしいお酒が飲めた。
#
# 昨日は雨が降ったせいで外出できなかった。
#
# 昨日は雨が降った。
#
# 初もうでに行って商売繁盛を祈願した。
#
# 初もうでに行った。
#
# 上野の国立科学博物館に行った。
#
# 上野に行った。
#
# 心の優しい太郎は嫌味を言わない。
#
# 太郎は嫌味を言わない。
#
# 酢が体にいいともてはやされている。
#
# 酢がもてはやされている。
#
# 水族館に行ったら、オジサンという名前の魚がいたんですよ!
#
# オジサンという名前の魚がいる。
#
# 切っても変色しない新種のリンゴが誕生した。
#
# 新種のリンゴは切っても変色しない。
#
# 窓を閉めないで寝た。
#
# 窓を閉めなかった。
#
# 太郎の人生の目標は幸せになることだそうだ。
#
# 太郎の人生の目標は幸せになることだ。
#
# 台風７号が発生し、日本に接近の恐れ。
#
# 台風が発生した。
#
# 大量のホルムアルデヒドが見つかったので、火星に生命が存在する可能性がある。
#
# 火星でホルムアルデヒドが見つかった。
#
# 転勤が決まったので、引っ越しをすることになった。
#
# 転勤が決まった。
#
# 土地を掘ったら、土器片が見つかった。
#
# 土地を掘った。
#
# 道に迷ったので、地図を見た。
#
# 道に迷った。
#
# 鍋は体が温まる。
#
# 鍋は温まる。
#
# 二十四時間三交替勤務が辛くて、仕事をやめた。
#
# 仕事をやめた。
#
# 二十四時間三交替勤務が辛くて、仕事をやめた。
#
# 二十四時間三交替勤務が辛かった。
#
# 日本は予選を通過したので、ワールドカップに参加できる。
#
# 日本は予選を通過した。
#
# 入学試験の出来が悪くて、不合格だった。
#
# 入学試験の出来が悪かった。
#
# 彼はテレビを見ながら朝食をとった。
#
# 彼はテレビを見た。
#
# 彼は財産を守るために遺言書を書くことにした。
#
# 彼は財産を守りたい。
#
# 彼は忙しくてレポートの締め切りに間に合わなかった。
#
# 彼は忙しかった。
#
# 彼女の髪形が変わって、別人のように見える。
#
# 彼女の髪形が変わった。
#
# 氷がとけて、水になった。
#
# 氷がとけた。
#
# 氷がとけて、水になった。
#
# 氷が水になった。
#
# 返却された本に書き込みがあったので消した。
#
# 本が返却された。
#
# 明日は日曜日なので、今日は夜更しができる。
#
# 明日は日曜日だ。
#
# 優しい息子をもって、私は幸せです。
#
# 私には息子がいる。
#
# 優しい息子をもって、私は幸せです。
#
# 息子は優しい。
#
# 著作権に詳しい弁護士に相談する。
#
# 弁護士は著作権に詳しい。
#
# 女を殴る男は最低だ。
#
# 男は女を殴る。
#
# ニャーニャーとうるさくて眠れない。
#
# ハエがうるさい。
#
# ボタンインコもラブバードと言われる。
#
# ボタンインコは愛鳥だ。
#
# 理科は得意だったが、物理だけはわけがわからなかった。
#
# 物理ができない理由が分からなかった。
#
# 相性が悪いので彼とはグループを別けて欲しい。
#
# 彼とは相性がいい。
#
# 花子は洋菓子より和菓子をなお好む。
#
# 花子は洋菓子も和菓子も好む。
#
# 花子は洋菓子より和菓子をなお好む。
#
# 花子は洋菓子も和菓子も好む。
#
# ごみを分別回収してのリサイクル活動が盛んだ。
#
# ごみは分別回収される。
#
# 犬が死んで悲しかった。
#
# 飼い犬が死んだ。
#
# 相性が悪いので彼とはグループを別けて欲しい。
#
# 私と彼は相性が悪い。
#
# おでんには大根とちくわが入っている。
#
# おでんにはかぶが入っている。
#
# おでんには大根とちくわが入っている。
#
# おでんには竹が入っている。
#
# この子はできも悪いし、容姿も良くない。
#
# この子は天才だ。
#
# この子はできも悪いし、容姿も良くない。
#
# この子は容姿は悪くない。
#
# インターネットで空席情況の確認と座席の予約ができます。
#
# インターネットで空席状況の操作ができる。
# インターネットで座席の変更ができる。
#
# カエルもイモリも両生類だ。
#
# カエルは爬虫類だ。
#
# カエルもイモリも両生類だ。
#
# ヤモリは両生類だ。
#
# グラタンも食べたいし、スパゲッティも食べたい。
#
# ハンバーグが食べたい。
#
# グラタンも食べたいし、スパゲッティも食べたい。
#
# ラザニアが食べたい。
#
# ジョンは怠慢で、ビルは勤勉だ。
#
# ジョンは勤勉だ。
#
# チューリップとバラが私は好きだ。
#
# 私はサクラが好きだ。
# 私はボタンが好きだ。
#
# ナイキもアディダスもスポーツ用品のメーカーだ。
#
# ナイキはカー用品のメーカーだ。
# アメダスはスポーツ用品のメーカーだ。
#
# ニートが増えて困っている。
#
# ニートは困っている。
#
# ニートが増えて困っている。
#
# ニートは増えた。
#
# レジャーの過ごし方はアウトドア派とインドア派に分かれる。
#
# 海外旅行派がいる。
# 国内旅行派がいる。
#
# 何事にも努力と忍耐が必要だ。
#
# 何事にもやる気が必要だ。
#
# 何事にも努力と忍耐が必要だ。
#
# 何事にも我慢が必要だ。
#
# 会場への入退場に時間がかかる。
#
# 会場への入場は楽だ。
# 会場への退場に時間はかからない。
#
# 改革を進めるとともに、新しい問題にもとり組んでいきたい。
#
# 改革を逆行させる。
# 新しい問題は見て見ぬ振りをする。
#
# 楽譜にト音記号とへ音記号がある。
#
# 楽譜にハ音記号がある。
# 楽譜にタ音記号がある。
#
# 犬は寒さに強く、猫は寒さに弱い。
#
# 熊は寒さに強い。
# 熊猫は寒さに強い。
#
# 災害時のためにラジオと近隣地図を用意しておくといい。
#
# 災害時のためにラジコンを用意しておくといい。
# 災害時のために世界地図を用意しておくといい。
#
# 三十才以上で独身の女性をさがしたが、該当する人はいなかった。
#
# 三十才以下を探した。
# 独身の男性を探した。
#
# 私は犬と猫を飼っている。
#
# 私は豚を飼っている。
#
# 私は犬と猫を飼っている。
#
# 私は馬を飼っている。
#
# 私は食事をご馳走してもらったうえに、タクシー代も出してもらった。
#
# 私は食事代をだした。
# 私はタクシー代を出した。
#
# 事件の鍵は逃走している原田と永田が握っている。
#
# 事件の鍵は原田が握っている。
# 事件の鍵は永田が握っている。
#
# 式典には、横浜、川崎両市長が参加した。
#
# 式典には、都築区長が参加した。
# 式典には川崎さんが参加した。
#
# 昔、話していた言葉と現代の言葉は違う。
#
# 昔、話していた言葉は違う。
# 現代の言葉は違う。
#
# 太郎は穏やかで、花子は激しい。
#
# 太郎は激しい。
#
# 天気といい、風といい、セイリングには最高の日だ。
#
# セイリングにはあいにくの天気だ。
# セイリングにはふさわしくない風だ。
#
# 彼女には優しさや思いやりがない。
#
# 彼女には怖さがない。
# 彼女は投げやりだ。
#
# 娘は東京で就職し、息子はタイに留学した。
#
# 娘はタイに留学した。
#
# この車は燃費といい性能といい抜群だ。
#
# この車は性能が抜群だ。
#
# この車は燃費といい性能といい抜群だ。
#
# この車は燃費が抜群だ。
#
# この図書館は広くて新しい。
#
# この図書館は広い。
#
# この図書館は広くて新しい。
#
# この図書館は新しい。
#
# ジョンは怠慢で、ビルは勤勉だ。
#
# ジョンは怠慢だ。
#
# ジョンは怠慢で、ビルは勤勉だ。
#
# ビルは勤勉だ。
#
# チーズも味噌も発酵食品である。
#
# チーズは発酵食品だ。
#
# チーズも味噌も発酵食品である。
#
# 味噌は発酵食品だ。
#
# ハーブは薬にしたり、料理に使ったりする。
#
# ハーブは薬になる。
# ハーブは料理に使える。
#
# 快適な鉄道と街の実現を目指している。
#
# 快適な交通機関の実現を目指している。
# 快適な街の実現を目指している。
#
# 今度の選挙の焦点は、郵政民営化と年金制度だ。
#
# 選挙の焦点は郵政民営化だ。
# 選挙の焦点は年金制度だ。
#
# 今日は快晴で、運動会日和だ。
#
# 今日は運動会日和だ。
#
# 今日は快晴で、運動会日和だ。
#
# 今日は快晴だ。
#
# 衆議院選挙と同時に裁判官の国民審査もある。
#
# 衆議院選挙がある。
#
# 小学校では皆勤賞だったが、中学校は休みまくりだった。
#
# 小学校では皆勤賞だった。
#
# 小学校では皆勤賞だったが、中学校は休みまくりだった。
#
# 中学校では休みまくりだった。
#
# 掃除機には紙パック式とサイクロン式のものがある。
#
# 紙パック式の掃除機がある。
# サイクロン式の掃除機がある。
#
# 太郎は穏やかで、花子は激しい。
#
# 花子は激しい。
#
# 太郎は穏やかで、花子は激しい。
#
# 太郎は穏やかだ。
#
# 大伴金村は物部尾輿に弾劾され、失脚した。
#
# 大伴金村は失脚した。
#
# 大伴金村は物部尾輿に弾劾され、失脚した。
#
# 大伴金村は物部尾輿に弾劾された。
#
# 地球も木星も太陽系の惑星だ。
#
# 地球は惑星だ。
# 木星は惑星だ。
#
# 茶道にも華道にも作法がある。
#
# 茶道には作法がある。
# 華道にも作法がある。
#
# 日本は製品を輸出入している。
#
# 日本は製品を輸入する。
# 日本は製品を輸出する。
#
# 納税、勤労、ならびに教育は三大義務である。
#
# 教育は三大義務である。
#
# 納税、勤労、ならびに教育は三大義務である。
#
# 納税は三大義務である。
#
# 能や歌舞伎は日本の伝統文化である。
#
# 能は日本の伝統文化である。
# 歌舞伎は日本の伝統文化である。
#
# 彼女は母親似の目の大きな子だった。
#
# 彼女は母親に似ている子である。
#
# 彼女は母親似の目の大きな子だった。
#
# 彼女は目が大きい子である。
#
# 娘は東京で就職し、息子はタイに留学した。
#
# 息子はタイに留学した。
#
# 娘は東京で就職し、息子はタイに留学した。
#
# 娘は東京で就職した。
#
# 私は犬と猫を飼っている。
#
# 私は犬を飼っている。
# 私はカメを飼っている。
#
# 権力と金と女が欲しい。
#
# 権力と金が欲しい。
#
# 太郎は国語と社会が苦手だ。
#
# 太郎は国語が得意だ。
# 太郎は社会が得意だ。
#
# 衆議院選挙と同時に裁判官の国民審査もある。
#
# 最高裁判所裁判官の国民審査もある。
#
# 白石さんに、「本学の知名度、好感度を高めた」と学長から感謝状が贈られた。
#
# 白石さんは、大学の知名度、好感度をあげた。
#
# あの店の定食は、味が良くて安いと評判だ。
#
# 定食は味が良くて高い。
#
# この試験は辞書を持ちこむことが許されている。
#
# ノートを持ちこむことが出来る。
#
# その店員は今、この製品は買い得になっていると言った。
#
# この製品を買うと損をする。
#
# ビルが選ばれると皆が不幸になる。
#
# ビルが選ばれた。
#
# 花子はダイエットに成功して嬉しいと言った。
#
# ダイエットは無駄に終わった。
#
# 花子は犬と話せたらいいのにと思った。
#
# 花子は犬と話せる。
#
# 株で儲けてお金持ちになるなんてはかない夢だ。
#
# お金持ちになった。
#
# 金メダルは５つ取れるだろうと予測している。
#
# 銀メダルは３つとれるだろう。
#
# 銀行は暗証番号を定期的に変えるように呼びかけている。
#
# 暗証番号は変えない方がいい。
#
# 警察は、空き巣被害が増加していることに頭を悩ませている。
#
# 痴漢被害が増加している。
#
# 山口さんはイタリアの生活は楽しかったと話した。
#
# イタリアでの生活は厳しいものだった。
#
# 私は成功するのは地道に頑張った人だと信じている。
#
# 成功するのは、世渡りがうまい人だ。
#
# 私は友人の結婚が決まって嬉しい。
#
# 友人の離婚が決まった。
#
# 資源は無限にあると考えてはいけない。
#
# 資源には限りがある。
#
# 写真撮影をプロのカメラマンに頼んだのは正解だった。
#
# 写真撮影を友人に頼んだ。
#
# 世間は堀江貴文社長が逮捕されたことに驚いた。
#
# 堀江貴文社長が補導された。
#
# 大豆は畑の肉と言われる。
#
# 大豆は豚の肉だ。
#
# 日本は安全だと言われてきた。
#
# 日本は危険だ。
#
# 日本人は愛情を表現するのが下手だと言われてきた。
#
# 日本人は愛情を表現するのが上手だ。
#
# 彼は私が転んだと勘違いした。
#
# 私は転んだ。
#
# 彼は本当は嫌いだったと告げた。
#
# 本当は遊びに行きたかった。
#
# 母は浦島太郎が亀を助けたことを話した。
#
# 母は亀を助けた。
#
# 両親は私が法学部へ進んだことを喜んだ。
#
# 私は工学部へ進んだ。
#
# 臨死体験した彼女は、天国が見えたと語った。
#
# 天国は荒れはてた地だった。
#
# その占い師は、あなたは幸せになれるだろうと予言した。
#
# 私は幸せになれるようだ。
#
# インドゾウとアフリカゾウのどこが違うか教えて下さい。
#
# インドゾウとアフリカゾウは違う。
#
# ウメがなったので、梅酒を作ろう。
#
# ウメがなった。
#
# ビルが選ばれたのは不幸だ。
#
# ビルが選ばれた。
#
# フェンスにからまったツタが素敵だ。
#
# ツタがフェンスにからまっている。
#
# 外来生物のアライグマが増えて、困っている。
#
# アライグマが増えている。
#
# 宮内容疑者は、株売買の操作をしたことを認めた。
#
# 株売買の操作をした。
#
# 語彙に体系があるのかどうか疑わしい。
#
# 語彙には体系があると考えられている。
#
# 今度公開された映画は、いい出来だと評判が高い。
#
# 今度公開された映画はいい出来だ。
#
# 子どもに道草はしないで帰るように注意している。
#
# 道草はしないで帰る。
#
# 商売ではお客様は神様だと思ったほうがいい。
#
# お客様は神様だ。
#
# 新聞社は記者が嘘の記事を書いたことを謝罪した。
#
# 記者は嘘の記事を書いた。
#
# 酢が体にいいともてはやされている。
#
# 酢は体にいい。
#
# 図書館へよく行く田中さんは非常に物知りだ。
#
# 田中さんは図書館へよく行く。
#
# 太郎に貸した本がなくなった。
#
# 太郎に本を貸した。
#
# 太郎は次郎がテストで１００点をとったと聞いて悔しがった。
#
# 次郎がテストで１００点をとった。
#
# 二朗は早くバイクの免許がとりたいと思った。
#
# 二朗はバイクの免許がとりたい。
#
# 白石さんに、「本学の知名度、好感度を高めた」と学長から感謝状が贈られた。
#
# 白石さんは、大学の知名度、好感度をあげた。
#
# 彼に悩みを打ち明けたのは間違いだった。
#
# 彼に悩みを打ち明けた。
#
# 母は浦島太郎が亀を助けたことを話した。
#
# 浦島太郎は亀を助けた。
#
# 陽子は勉強が出来ると皆から認められている。
#
# 陽子は勉強が出来る。
#
# 隆は医者になろうと考えている。
#
# 隆は医者になりたい。
#
# ビルが選ばれると皆が不幸になる。
#
# ビルが選ばれる。
#
# 偉人伝を子どもに読ませることは本当にいいことなのでしょうか。
#
# 偉人伝を子どもに読ませることはいいことだ。
#
# 私は浦島太郎が鶴を助けることを期待した。
#
# 浦島太郎は鶴を助けた。
#
# 男は女性をひき逃げした疑いで逮捕された。
#
# 男は女性をひいて逃げた。
#
# ビルが選ばれると皆が不幸になる。
#
# ビルは選ばれる可能性がある。
#
# お遊戯会でお姫様の役をした。
#
# お楽しみ会があった。
#
# オペラ観賞に陛下がいらっしゃった。
#
# ミュージカルを上演した。
#
# ギャングに襲われた。
#
# 海賊がいる。
#
# プロジェクトでリーダーを任された。
#
# 歌合戦がある。
#
# マンションを買おうとパンフレットを見た。
#
# 折り込み広告がある。
#
# 横浜港で船を見た。
#
# さいたま港がある。
#
# 海の家でラーメンを食べた。
#
# 山小屋があった。
#
# 癌検診でひっかかった。
#
# 歯科検診があった。
#
# 戸棚のお菓子が食べたい。
#
# 本棚にお菓子がある。
#
# 三者面談で進路を話し合った。
#
# 面接試験があった。
#
# 私は面接で失敗した。
#
# お見合いがあった。
#
# 祝勝会でビールを飲んだ。
#
# 壮行会があった。
#
# 千畳敷カールで雪崩が起こった。
#
# 千畳敷カールがいる。
#
# 大雪で家が潰れた。
#
# 大雨が降っている。
#
# 大統領にはボディーガードが付いている。
#
# ガードレールがある。
#
# 日本は予選を通過したら、ワールドカップに参加できる。
#
# コールドカップがある。
#
# 日本チームがマラソンの団体戦で二位になった。
#
# 徒競走があった。
#
# 納品書を見ながら検品した。
#
# 請求書が手元にある。
#
# 売り尽くしセールで、スカートを買った。
#
# 開店セールがあった。
#
# 夫の風邪は悪化している。
#
# 益夫は風邪をひいている。
#
# 壁のカレンダーに予定を書き込んでください。
#
# 机にカレンダーがある。
#
# おたふく風邪の予防接種を受けた。
#
# おたふく風邪の予防接種がある。
#
# グリコ・森永事件は時効を迎えた。
#
# グリコ・森永事件があった。
#
# ミュージシャンが雑誌のインタビューに答えた。
#
# 雑誌のインタビューがあった。
#
# 運動会で一等賞をとった。
#
# 運動会があった。
#
# 運動会の練習をしている。
#
# 運動会がある。
#
# 学会で論文を発表した。
#
# 学会があった。
#
# 教授会で君はクビだと言われた。
#
# 教授会があった。
#
# 結婚式に出席する。
#
# 結婚式がある。
#
# 今度の選挙の焦点は、郵政民営化と年金制度だ。
#
# 選挙がある。
#
# 辞令交付で総務課配属を命じられた。
#
# 辞令交付式があった。
#
# 衆議院選挙を前に、新党が誕生した。
#
# 衆議院選挙がある。
#
# 人身事故で電車が遅れた。
#
# 人身事故があった。
#
# 退職金で海外旅行へ行った。
#
# 退職金をもらった。
#
# 調査結果から事故原因を推論する。
#
# 事故があった。
#
# 東大の赤門は有名だ。
#
# 東大には赤門がある。
#
# 日本チームがマラソンの団体戦で二位になった。
#
# マラソン大会があった。
#
# 発表の出番が近づき、ドキドキしてきた。
#
# 発表がある。
#
# 反日デモで日本人が殴られた。
#
# 反日デモがあった。
#
# 夫の風邪は悪化している。
#
# 夫は風邪をひいている。
#
# アンカラで国際会議があった。
#
# アンカラは場所である。
#
# ウメがなったので、梅酒を作ろう。
#
# ウメの木がある。
#
# 風で帽子がとんだ。
#
# 風が吹いていた。
#
# 地震による死者が日に日に増えていっている。
#
# 災害があった。
#
# 運転免許を持っている人が、車の運転ができるとは限らない。
#
# 運転免許を持っているからといって、車の運転ができるとは限らない。
#
# 日本語を話す人が日本人であるとは限らない。
#
# 日本語を話すからといって日本人であるとは限らない。
#
# 地球博の目玉は冷凍マンモスである。
#
# 地球博の注目展示は冷凍マンモスである。
#
# 夏目漱石の『こころ』を読んだ。
#
# 夏目漱石を読んだ。
#
# 肩たたきにあった。
#
# くびになった。
#
# 甲子園は準決勝を迎えた。
#
# 高校野球大会は準決勝を迎えた。
#
# 中身がスカスカだ。
#
# 中身がない。
#
# いつもぴいぴいしている。
#
# お金がない。
#
# 彼女はピチピチしている。
#
# 彼女は元気だ。
#
# 彼女はピチピチしている。
#
# 彼女は若い。
#
# 花子は太郎を結婚相手に決めた。
#
# 花子は女性である。
#
# 花子は太郎を結婚相手に決めた。
#
# 太郎は男性である。
#
# 香と真樹が結婚した。
#
# 香は女性である。
#
# 香と真樹が結婚した。
#
# 香は男性である。
#
# 香と真樹が結婚した。
#
# 真樹は女性である。
#
# 香と真樹が結婚した。
#
# 真樹は男性である。
#
# ラッシュにぶつかった。
#
# 犬にぶつかった。
#
# ボジョレ・ヌーヴォーが解禁になった。
#
# ボジョレ・ヌーヴォーの販売には解禁日がある。
#
# 彼は英語が堪能である。
#
# 彼の英語はうまい。
#
# 彼は、自分の家が炎上するのを、ただ眺めていた。
#
# 彼は、彼の家が炎上するのを、ただ眺めていた。

# %%
#テキストの取り出し
txt_datas = []
with open('2kyoto_test.txt') as f:
    line = f.readline()
    while line:
        line = line.replace('\n','')
        line = line.replace('\r','')
        txt_datas.append(line)
        line = f.readline()

# %%
#en_parsed のsemから取り出し
tree = ET.parse('sem/kyoto_1016.txt.depccg.sem.xml')
root = tree.getroot()

root = root[0]
root = root[0] #１個目のsentence

c = 0 #辞書のindexを回す
mydict = {}

#子階層のタグと中身
for child in root:
         
    formula = child[2]  #child[2]がsemantics
    check = (child[2].attrib)
    check = check['status']
   
    if(check == 'success'):
        plain = child.text  
        plain = plain+'\n'
        
        formula = child[2][0]
        formula = (formula.attrib)
        formula = formula['sem'] #\nが付与されていると信じている
        
        pair = {'text':plain,'formula':formula}
        mydict.update({str(c):pair})
        
    
    #    print("  ")
    else:
        print('faild parse')
    c = c + 1
    
f = open('ku_input_data.txt', 'w') # 書き込みモードで開く
json.dump(mydict, f,ensure_ascii=False)
f.close()
# Out:
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
# faild parse
