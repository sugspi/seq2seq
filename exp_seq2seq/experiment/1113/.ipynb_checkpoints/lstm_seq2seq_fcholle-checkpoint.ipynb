# %%
# Summary of the algorithm
- We start with input sequences from a domain (e.g. English sentences)
    and correspding target sequences from another domain
    (e.g. French sentences).
- An encoder LSTM turns input sequences to 2 state vectors
    (we keep the last LSTM state and discard the outputs).
- A decoder LSTM is trained to turn the target sequences into
    the same sequence but offset by one timestep in the future,
    a training process called "teacher forcing" in this context.
    Is uses as initial state the state vectors from the encoder.
    Effectively, the decoder learns to generate `targets[t+1...]`
    given `targets[...t]`, conditioned on the input sequence.
- In inference mode, when we want to decode unknown input sequences, we:
    - Encode the input sequence into state vectors
    - Start with a target sequence of size 1
        (just the start-of-sequence character)
    - Feed the state vectors and 1-char target sequence
        to the decoder to produce predictions for the next character
    - Sample the next character using these predictions
        (we simply use argmax).
    - Append the sampled character to the target sequence
    - Repeat until we generate the end-of-sequence character or we
        hit the character limit.
# Out:
#   File "<ipython-input-91-1c8c0c93471c>", line 2
#     - We start with input sequences from a domain (e.g. English sentences)
#              ^
# SyntaxError: invalid syntax

# %%
from __future__ import print_function

from keras.models import Model
from keras.models import load_model
from keras.layers import Input, LSTM, Dense
import numpy as np
import json
# Out:
# Using TensorFlow backend.

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = '/Users/guru/MyResearch/sg/snli/json/snli_inp_1024.json'#'keras-seq2seq/distinct/ku_corpus_char.distinct.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
lines = open(data_path)#.read().split('\n')

#json ver 
jdict = json.load(lines)

for line in jdict:#lines[: min(num_samples, len(lines) - 1)]:
    input_text = (jdict[line])['formula']
    target_text = (jdict[line])['text']
    #input_text, target_text = line.split("___SP___")#line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)
            
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)


input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

#np.zeros 0を要素とする配列(shape, dtype = float, order = ‘C’)　３次元
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')


for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
# Out:
# Number of samples: 19899
# Number of unique input tokens: 74
# Number of unique output tokens: 77
# Max sequence length for inputs: 2428
# Max sequence length for outputs: 267

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=10,#epochs,
          validation_split=0.2)
# Save model
model.save('model/train/s2s_1117_snli_ccg.h5')
# Out:
# Train on 15919 samples, validate on 3980 samples
# Epoch 1/10
#    64/15919 [..............................] - ETA: 55:00 - loss: 0.9084
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8cee2d0b705a> in <module>()
#       9           batch_size=batch_size,
#      10           epochs=10,#epochs,
# ---> 11           validation_split=0.2)
#      12 # Save model
#      13 model.save('model/train/s2s_1117_snli_ccg.h5')
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1629                               initial_epoch=initial_epoch,
#    1630                               steps_per_epoch=steps_per_epoch,
# -> 1631                               validation_steps=validation_steps)
#    1632
#    1633     def evaluate(self, x=None, y=None,
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# choose input data version
model = load_model('model/train/s2s_1117_snli_ccg.h5')
input_texts_inf = []
lines = open('predict.txt').read().split('\n')

for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text_inf = line
    input_texts_inf.append(input_text_inf)
            
print('Number of samples:', len(input_texts_inf))


#np.zeros 0を要素とする配列(shape, dtype = float, order = ‘C’)　３次元
encoder_input_data_inf = np.zeros(
    (len(input_texts_inf), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')


for i, input_text_inf in enumerate(input_texts_inf):
    for t, char in enumerate(input_text_inf):
        encoder_input_data_inf[i, t, input_token_index[char]] = 1.
# Out:
# Number of samples: 1

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models

encoder_model = load_model('model/encoder/s2s_1117_snli_ccg_10.h5')
#encoder_model = Model(encoder_inputs, encoder_states)
#encoder_model.save('model/encoder/s2s_1117_snli_ccg_10.h5')


decoder_model = load_model('model/decoder/s2s_1117_snli_ccg_10.h5')
#decoder_state_input_h = Input(shape=(latent_dim,))
#decoder_state_input_c = Input(shape=(latent_dim,))
#decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
#decoder_outputs, state_h, state_c = decoder_lstm(
#    decoder_inputs, initial_state=decoder_states_inputs)
#decoder_states = [state_h, state_c]
#decoder_outputs = decoder_dense(decoder_outputs)
#decoder_model = Model(
#    [decoder_inputs] + decoder_states_inputs,
#    [decoder_outputs] + decoder_states)
#decoder_model.save('model/decoder/s2s_1117_snli_ccg_10.h5')

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())

reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())
# Out:
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training test)
    # for trying out decoding.
    #input_seq = encoder_input_data[seq_index: seq_index + 1]
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: exists x.(_driver(x) & _car(x) & _race(x) & _two(x) & TrueP & exists e.(_smile(e) & (Subj(e) = x) & exists z9554.(_stage(z9554) & TrueP & _on(e,z9554)) & _next(e) & exists x.(_female(x) & exists z9540.(exists e09548.(_white(e09548) & (Subj(e09548) = z9540) & _dress(z9540)) & TrueP & exists e09549.(_wear(e09549) & (Subj(e09549) = x) & (Acc(e09549) = z9540) & TrueP)) & exists z9541.(exists e09550.(_blue(e09550) & (Subj(e09550) = z9541) & exists e09550.(_white(e09550) & (Subj(e09550) = z9541) & _boot(z9541))) & TrueP & exists e09551.(_wear(e09551) & (Subj(e09551) = x) & (Acc(e09551) = z9541) & TrueP)) & exists z9539.(_model(z9539) & TrueP & exists e09552.(_spoke(e09552) & (Subj(e09552) = x) & (Acc(e09552) = z9539) & TrueP)) & TrueP & (Dat(e) = x)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_dog(x) & _two(x) & exists e1.(_shake(e1) & (Subj(e1) = x) & exists z13104.((z13104 = _themselves) & TrueP & exists e.(_dry(e) & (Subj(e) = z13104) & (AccE(e1) = e))) & exists z13104.(_sand(z13104) & TrueP & _on(e1,z13104) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_person(x) & exists z32884.(exists e.(_yellow(e) & (Subj(e) = z32884) & _ball(z32884)) & TrueP & exists e.(_throw(e) & (Subj(e) = x) & (Acc(e) = z32884) & exists z32886.(_air(z32886) & TrueP & _in(e,z32886) & TrueP))) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z49404.(_motorcycle(z49404) & TrueP & exists e.(_on(e,z49404) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists e.(_return(e) & (Subj(e) = x) & exists z39303.(_trip(z39303) & _business(z39303) & TrueP & _from(e,z39303) & TrueP)) & exists e.(_arrive(e) & (Subj(e) = x) & exists z39305.(_airport(z39305) & TrueP & _at(e,z39305) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(TrueP & exists z29372.(_people(z29372) & exists z29371.(_costume(z29371) & TrueP & exists e.(_in(e,z29371) & (Subj(e) = z29372) & TrueP)) & (x = z29372)) & TrueP & exists z29373.(_arm(z29373) & TrueP & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z29373) & exists x.(_air(x) & TrueP & _in(e,x) & exists x.(_manner(x) & exists z29375.(_finale(z29375) & exists z29374.(exists e029376.(_musical(e029376) & (Subj(e029376) = z29374) & _number(z29374)) & TrueP & (z29375 = z29374)) & TrueP & (x = z29375)) & TrueP & _in(e,x) & TrueP)))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & _two(x) & TrueP & exists z38766.(_fruit(z38766) & TrueP & exists e.(_sell(e) & (Subj(e) = x) & (Acc(e) = z38766) & exists x.(_market(x) & _fruit(x) & TrueP & _at(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_person(x) & exists z25211.(_helmet(z25211) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z25211) & TrueP)) & exists z25212.(_suit(z25212) & _riding(z25212) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z25212) & TrueP)) & TrueP & exists z25215.(_wheeler(z25215) & _four(z25215) & TrueP & exists e.(_ride(e) & (Subj(e) = x) & (Acc(e) = z25215) & exists x.(exists e025217.(_dusty(e025217) & (Subj(e025217) = x) & _plot(x)) & exists z25216.(_land(z25216) & TrueP & (x = z25216)) & TrueP & _on(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z45620.(_hate(z45620) & _baseball(z45620) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z45620) & TrueP)) & TrueP & exists z45623.(_phone(z45623) & TrueP & exists e.(_check(e) & (Subj(e) = x) & (Acc(e) = z45623) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z11616.(_ladder(z11616) & TrueP & exists e.(_float(e) & (Subj(e) = x) & (Acc(e) = z11616) & _up(e) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_kid(x) & TrueP & exists e.(_wait(e) & (Subj(e) = x) & exists x.(_line(x) & TrueP & _in(e,x)) & exists x.(_front(x) & exists z26099.(_truck(z26099) & _cream(z26099) & _ice(z26099) & exists z26098.(_night(z26098) & TrueP & exists e026100.(_at(e026100,z26098) & (Subj(e026100) = z26099) & TrueP)) & (x = z26099)) & TrueP & _in(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & TrueP & exists z53528.(_indoor(z53528) & TrueP & (x = z53528)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_people(x) & _two(x) & TrueP & exists z4968.(_construction(z4968) & TrueP & exists e.(_work(e) & (Subj(e) = x) & (Acc(e) = z4968) & exists x.(_inside(x) & exists z4969.(_house(z4969) & TrueP & (x = z4969)) & TrueP & _on(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_young(e) & (Subj(e) = x) & _snowboarder(x)) & TrueP & exists z13176.(exists e.(_hot(e) & (Subj(e) = z13176) & _chocolate(z13176)) & TrueP & exists e.(_sip(e) & (Subj(e) = x) & (Acc(e) = z13176) & exists x.(_cabin(x) & TrueP & _in(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_golden_dash_colored(e) & (Subj(e) = x) & _dog(x)) & exists z12459.(_eye(z12459) & _alert(z12459) & TrueP & exists e.(_with(e,z12459) & (Subj(e) = x) & TrueP)) & exists z12461.(_brightly(z12461) & exists e.(_color(e) & (Acc(e) = z12461) & _ball(z12461) & _tennis(z12461)) & exists z12460.(_mouth(z12460) & TrueP & exists e.(_in(e,z12460) & (Subj(e) = z12461) & TrueP)) & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z12461) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z56235.(_lecture(z56235) & TrueP & exists e.(_give(e) & (Subj(e) = x) & (Acc(e) = z56235) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & _nine(x) & exists z2862.(exists e.(_white(e) & (Subj(e) = z2862) & _robe(z2862)) & exists z2861.(_hood(z2861) & exists e.(_walk(e) & (Acc(e) = z2861) & exists z2860.(exists e02858.(_plush(e02858) & (Subj(e02858) = z2860) & exists e02858.(_green(e02858) & (Subj(e02858) = z2860) & _grass(z2860))) & TrueP & _on(e,z2860)) & TrueP) & TrueP & exists e.(_with(e,z2861) & (Subj(e) = z2862) & TrueP)) & exists e.(_in(e,z2862) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_kid(x) & TrueP & exists z5845.(_staircase(z5845) & TrueP & exists e.(_fall(e) & (Subj(e) = x) & (Acc(e) = z5845) & _off(e) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_kid(x) & exists z48151.(exists e.(_casual(e) & (Subj(e) = z48151) & _clothing(z48151)) & TrueP & exists e.(_in(e,z48151) & (Subj(e) = x) & TrueP)) & exists e.(_play(e) & (Subj(e) = x) & exists x.(_park(x) & TrueP & _at(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_people(x) & TrueP & exists e.(_listen(e) & (Subj(e) = x) & exists x.(_concert(x) & TrueP & (Dat(e) = x)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_small(e) & (Subj(e) = x) & _child(x)) & exists e.(_outside(e,x) & exists x.(_front(x) & exists z38575.(exists e038576.(_large(e038576) & (Subj(e038576) = z38575) & _pile(z38575) & _dirt(z38575)) & TrueP & (x = z38575)) & TrueP & _in(e,x)) & TrueP) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_worker(x) & TrueP & exists e.(_work(e) & (Subj(e) = x) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(_people(x) & _two(x) & exists e.(_run(e) & (Subj(e) = x) & exists z5978.(_track(z5978) & TrueP & _around(e,z5978) & exists z5978.(_lane(z5978) & _three(z5978) & TrueP & _in(e,z5978) & TrueP))) & TrueP & exists e.((Subj(e) = Subj(e)) & TrueP)) & exists x.(_one(x) & exists z5981.(exists e.(_blue(e) & (Subj(e) = z5981) & _shirt(z5981)) & exists z5980.(exists e.(_green(e) & (Subj(e) = z5980) & _thing(z5980)) & exists z5979.(_eye(z5979) & TrueP & exists e.(_over(e,z5979) & (Subj(e) = z5980) & TrueP)) & exists e.(_with(e,z5980) & (Subj(e) = z5981) & TrueP)) & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z5981) & TrueP)) & TrueP & exists e.(_ahead(e) & (Subj(e) = x) & exists x.(_guy(x) & exists z5984.(_shirt(z5984) & _orange(z5984) & TrueP & exists e05987.(_wear(e05987) & (Subj(e05987) = x) & (Acc(e05987) = z5984) & TrueP)) & TrueP & _of(e,x)) & exists x.(_sunglass(x) & TrueP & _of(e,x)) & _barely(e) & _just(e) & TrueP)))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_child(x) & _two(x) & TrueP & exists z26926.(_arm(z26926) & TrueP & exists e.(_put(e) & (Subj(e) = x) & (Acc(e) = z26926) & _out(e) & TrueP)) & exists e.(_smile(e) & (Subj(e) = x) & TrueP) & exists e.(_stand(e) & (Subj(e) = x) & exists z26925.(_grass(z26925) & TrueP & _among(e,z26925) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_player(x) & exists z26559.(exists e.(_black(e) & (Subj(e) = z26559) & _team(z26559)) & TrueP & exists e.(_from(e,z26559) & (Subj(e) = x) & TrueP)) & exists z26562.(exists z26561.(_player(z26561) & exists z26560.(exists e.(_red(e) & (Subj(e) = z26560) & _team(z26560)) & TrueP & (z26561 = z26560)) & TrueP & exists e.(_to(e,z26561) & (Subj(e) = z26562) & TrueP)) & exists e.(_tell(e) & (Subj(e) = x) & (Acc(e) = z26562) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists e.(_while(e) & exists x.(_the(x) & exists e03771.(_listen(e03771) & (Subj(e03771) = x) & exists z3768.(exists e03766.(_classical(e03766) & (Subj(e03766) = z3768) & _music(z3768)) & TrueP & (Dat(e03771) = z3768)) & exists z3768.(_headphone(z3768) & TrueP & _through(e03771,z3768) & exists z3770.(_computer(z3770) & _she(z3770) & TrueP & _on(e03771,z3770) & (Subj(e03771) = Subj(e))))) & _work(x) & _girl(x)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & TrueP & exists e1.(_wind(e1) & (Subj(e1) = x) & AccI(e1,exists x.(_yarn(x) & TrueP & exists z11042.(_rent(z11042) & TrueP & exists e.(_pay(e) & (Subj(e) = x) & (Acc(e) = z11042) & _help(e) & TrueP)))) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(exists e.(_black(e) & (Subj(e) = x) & _dog(x)) & TrueP & TrueP) & exists x.(_swim(x) & _goose(x) & exists z34711.(_water(z34711) & TrueP & exists e.(_in(e,z34711) & (Subj(e) = x) & TrueP)) & TrueP))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_man(x) & TrueP & exists e.(_away(e) & (Subj(e) = x) & _stare(e) & TrueP) & exists e.(_sit(e) & (Subj(e) = x) & exists z32180.(_stall(z32180) & TrueP & _in(e,z32180) & exists z32180.(_stand(z32180) & TrueP & _while(e,z32180) & exists z32180.(_front(z32180) & exists z32176.((z32176 = _it) & TrueP & (z32180 = z32176)) & TrueP & _in(e,z32180) & TrueP)))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_asian(e) & (Subj(e) = x) & _teen(x)) & TrueP & exists z12388.(_game(z12388) & TrueP & exists e.(_play(e) & (Subj(e) = x) & (Acc(e) = z12388) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & exists z11815.(_sunglass(z11815) & TrueP & exists e.(_in(e,z11815) & (Subj(e) = x) & exists z11816.(_face(z11816) & _pout(z11816) & TrueP & exists e.(_make(e) & (Subj(e) = x) & (Acc(e) = z11816) & TrueP)) & exists z11817.(_seafood(z11817) & TrueP & exists e.(_eat(e) & (Subj(e) = x) & (Acc(e) = z11817) & TrueP)) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(_bride(x) & TrueP & exists z5839.(_aisle(z5839) & _church(z5839) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & (Acc(e) = z5839) & _down(e) & TrueP))) & exists x.(_father(x) & TrueP & exists z5839.(_aisle(z5839) & _church(z5839) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & (Acc(e) = z5839) & _down(e) & TrueP))))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_girl(x) & TrueP & exists e.(_hang(e) & (Subj(e) = x) & exists x.(exists e025172.(_gymnastic(e025172) & (Subj(e025172) = x) & _rope(x)) & TrueP & (Subj(e) = x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_cop(x) & TrueP & exists z13175.(TrueP & exists e.(_handcuff(e) & (Subj(e) = x) & (Acc(e) = z13175) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z40686.(_microphone(z40686) & TrueP & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z40686) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_fireman(x) & TrueP & (exists e.(_stand(e) & (Subj(e) = x) & TrueP) | (exists e.(_sit(e) & (Subj(e) = x) & exists z57913.(exists e057909.(_gray(e057909) & (Subj(e057909) = z57913) & _roof(z57913)) & TrueP & _on(e,z57913) & TrueP)) & exists e.(_work(e) & (Subj(e) = x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_child(x) & TrueP & exists z20924.(_adult(z20924) & exists z20923.(_red(z20923) & TrueP & exists e.(_in(e,z20923) & (Subj(e) = z20924) & TrueP)) & exists e.(_guide(e) & (Subj(e) = x) & (Acc(e) = z20924) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(TrueP & exists z47078.(_people(z47078) & exists z47077.(_office(z47077) & TrueP & exists e.(_in(e,z47077) & (Subj(e) = z47078) & TrueP)) & (x = z47078)) & TrueP & exists e.(_prepare(e) & (Subj(e) = x) & exists x.(_snowstorm(x) & TrueP & _for(e,x)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & exists z9357.(_castle(z9357) & _sand(z9357) & TrueP & exists e.(_build(e) & (Subj(e) = x) & (Acc(e) = z9357) & _herself(e) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(_woman(x) & exists z4791.(exists e.(_gray(e) & (Subj(e) = z4791) & _pants(z4791)) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z4791) & TrueP)) & TrueP & exists e.(_jump(e) & (Subj(e) = x) & exists x.(_hand(x) & TrueP & _with(e,x) & exists x.(_air(x) & TrueP & _in(e,x) & TrueP)))) & exists x.(exists e.(_white(e) & (Subj(e) = x) & _blouse(x)) & TrueP & exists e.(_jump(e) & (Subj(e) = x) & exists x.(_hand(x) & TrueP & _with(e,x) & exists x.(_air(x) & TrueP & _in(e,x) & TrueP)))) & exists x.(exists e.(_black(e) & (Subj(e) = x) & _vest(x)) & TrueP & exists e.(_jump(e) & (Subj(e) = x) & exists x.(_hand(x) & TrueP & _with(e,x) & exists x.(_air(x) & TrueP & _in(e,x) & TrueP)))) & exists x.((x = _she) & TrueP & exists e.(_go(e) & (Subj(e) = x) & exists x.(exists e04794.(_indoor(e04794) & (Subj(e04794) = x) & _stadium(x)) & TrueP & _through(e,x) & TrueP))))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z43225.(_motorcycle(z43225) & TrueP & exists e.(_ride(e) & (Subj(e) = x) & (Acc(e) = z43225) & _next(e) & exists x.(_boy(x) & TrueP & (Dat(e) = x)) & exists x.(_bicycle(x) & TrueP & _on(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & TrueP & exists e.(_bride(e) & (Subj(e) = x) & exists x.(_dress(x) & TrueP & _into(e,x)) & _help(e) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & exists x.(_sidewalk(x) & TrueP & _on(e,x) & exists x.(_hand(x) & TrueP & _with(e,x) & exists x.(_pocket(x) & TrueP & _in(e,x) & TrueP)))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_walker(x) & _power(x) & _two(x) & exists e.(_walk(e) & (Subj(e) = x) & exists z13973.(_one(z13973) & _another(z13973) & TrueP & _beside(e,z13973) & exists z13973.(_race(z13973) & TrueP & _in(e,z13973) & TrueP))) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z54081.(exists e.(_black(e) & (Subj(e) = z54081) & _shirt(z54081)) & TrueP & exists e.(_in(e,z54081) & (Subj(e) = x) & TrueP)) & exists z54082.(_baby(z54082) & _smile(z54082) & TrueP & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z54082) & exists x.(_person(x) & exists z54083.(exists e054085.(_blue(e054085) & (Subj(e054085) = z54083) & _stand(z54083) & _shirt(z54083)) & TrueP & exists e054086.(_in(e054086,z54083) & (Subj(e054086) = x) & exists z54084.(_foreground(z54084) & TrueP & exists e054086.(_in(e054086,z54084) & (Subj(e054086) = x) & TrueP)))) & _while(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & TrueP & exists z28547.(_drink(z28547) & TrueP & exists e.(_have(e) & (Subj(e) = x) & (Acc(e) = z28547) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z12978.(_bottle(z12978) & exists z12977.(_wine(z12977) & TrueP & (z12978 = z12977)) & TrueP & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z12978) & exists z12982.(_box(z12982) & exists z12979.(_head(z12979) & TrueP & exists e012980.(_on(e012980,z12979) & (Subj(e012980) = z12982) & TrueP)) & _with(e,z12982) & TrueP))) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_jet(x) & TrueP & exists e.(_low(e) & (Subj(e) = x) & _fly(e) & exists x.(_field(x) & TrueP & _over(e,x) & exists x.(_woman(x) & exists z29976.(_field(z29976) & TrueP & exists e029977.(_in(e029977,z29976) & (Subj(e029977) = x) & TrueP)) & _with(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists e.(_swim(e) & (Subj(e) = x) & exists x.(_middle(x) & exists z52387.(_ocean(z52387) & TrueP & (x = z52387)) & TrueP & _in(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z2971.(_cat(z2971) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & (Acc(e) = z2971) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & TrueP & exists z44622.(_flag(z44622) & TrueP & exists e.(_carry(e) & (Subj(e) = x) & (Acc(e) = z44622) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(_man(x) & TrueP & exists e.(_sit(e) & (Subj(e) = x) & TrueP)) & exists x.(_man(x) & exists z48913.((z48913 = _he) & TrueP & exists e.(_behind(e,z48913) & (Subj(e) = x) & TrueP)) & exists z48914.(_bus(z48914) & TrueP & exists e.(_wash(e) & (Subj(e) = x) & (Acc(e) = z48914) & TrueP))))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_boy(x) & exists z2129.(_bubble(z2129) & _blow(z2129) & _overalls(z2129) & TrueP & exists e.(_in(e,z2129) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: -exists x.(_animal(x) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_child(x) & TrueP & exists e.(_scare(e) & (Subj(e) = x) & AccI(e,exists e.(_jump(e) & (Subj(e) = x) & exists z5990.(_water(z5990) & TrueP & _in(e,z5990) & TrueP))) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_child(x) & TrueP & exists z51300.(_baseball(z51300) & TrueP & exists e.(_play(e) & (Subj(e) = x) & (Acc(e) = z51300) & exists x.(_home(x) & TrueP & _at(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists e.(_wander(e) & (Subj(e) = x) & exists z1287.(_desert(z1287) & TrueP & _in(e,z1287) & exists z1287.(_roll(z1287) & _cloud(z1287) & TrueP & _as(e,z1287) & _in(e) & TrueP))) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: (exists x.(_dog(x) & TrueP & exists e.(_stand(e) & (Subj(e) = x) & exists x.(_water(x) & TrueP & _in(e,x) & TrueP))) & exists x.(_kid(x) & _wear(x) & _diaper(x) & TrueP & exists e.(_sit(e) & (Subj(e) = x) & exists x.(_rock(x) & TrueP & _on(e,x) & TrueP))))
# Decoded sentence: A man ina black shirt and blue jeans anda white shirt and blue jeans is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitting ona beach witha woman ina blue shirt is sitt
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z25805.(exists e.(_national(e) & (Subj(e) = z25805) & _anthem(z25805)) & TrueP & exists e.(_sing(e) & (Subj(e) = x) & (Acc(e) = z25805) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_white(e) & (Subj(e) = x) & _dog(x)) & TrueP & exists e.(_sit(e) & (Subj(e) = x) & exists x.(_tree(x) & TrueP & _under(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z101.(_donut(z101) & TrueP & exists e.(_sell(e) & (Subj(e) = x) & (Acc(e) = z101) & exists z103.(_customer(z103) & TrueP & (Dat(e) = z103)) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_player(x) & _football(x) & exists e.(_jump(e) & (Subj(e) = x) & AccI(e,exists z20516.(_ball(z20516) & TrueP & exists e.(_catch(e) & (Subj(e) = x) & (Acc(e) = z20516) & exists z20521.(exists e020518.(_empty(e020518) & (Subj(e020518) = z20521) & _stand(z20521)) & exists z20517.((z20517 = _he) & TrueP & exists e020519.(_behind(e020519,z20517) & (Subj(e020519) = z20521) & TrueP)) & _with(e,z20521) & TrueP)))) & TrueP) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_cooking(x) & _boy(x) & exists z10970.(_grill(z10970) & TrueP & exists e.(_on(e,z10970) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & exists e.(_walk(e) & (Subj(e) = x) & exists z29967.(_front(z29967) & exists z29965.(_a(z29965) & TrueP & (z29967 = z29965)) & TrueP & _in(e,z29967) & TrueP)) & TrueP & exists z29968.(_building(z29968) & TrueP & exists e.(_establish(e) & (Subj(e) = x) & (Acc(e) = z29968) & _newly(e) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists e.(_perform(e) & (Subj(e) = x) & exists x.(_concert(x) & TrueP & _in(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_dog(x) & TrueP & exists e.(_run(e) & (Subj(e) = x) & _outside(e) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z24157.(_wood(z24157) & TrueP & exists e.(_chop(e) & (Subj(e) = x) & (Acc(e) = z24157) & TrueP)) & exists e.(_about(e) & (Subj(e) = x) & AccI(e,exists e.(_push(e) & (Acc(e) = x) & _over(e) & exists z24159.(_person(z24159) & TrueP & (Subj(e) = z24159) & TrueP))) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z15636.(_child(z15636) & TrueP & exists e.(_carry(e) & (Subj(e) = x) & (Acc(e) = z15636) & TrueP)) & exists z15637.(exists e.(_blue(e) & (Subj(e) = z15637) & exists e.(_red(e) & (Subj(e) = z15637) & _umbrella(z15637))) & TrueP & exists e.(_hold(e) & (Subj(e) = x) & (Acc(e) = z15637) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z21152.(_hat(z21152) & TrueP & exists e.(_in(e,z21152) & (Subj(e) = x) & TrueP)) & exists e.(_sit(e) & (Subj(e) = x) & _down(e) & exists x.(exists e021153.(_local(e021153) & (Subj(e021153) = x) & _dmv(x)) & TrueP & _at(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_band(x) & exists e.(_perform(e) & (Subj(e) = x) & exists z22558.(_singing(z22558) & _girl(z22558) & TrueP & _with(e,z22558) & _well(e) & TrueP) & exists z22558.(_guy(z22558) & exists e022556.(_next(e022556,z22558) & exists z22558.(_singing(z22558) & TrueP & (Dat(e022556) = z22558)) & TrueP) & _with(e,z22558) & _well(e) & TrueP)) & _as(x) & exists z22559.(_guitar(z22559) & TrueP & exists e.(_play(e) & (Subj(e) = x) & (Acc(e) = z22559) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_small(e) & (Subj(e) = x) & exists e.(_blond(e) & (Subj(e) = x) & _child(x))) & TrueP & exists e.(_play(e) & (Subj(e) = x) & exists x.(exists e026053.(_puzzle(e026053) & (Subj(e026053) = x) & _piece(x)) & exists z26049.(_color(z26049) & TrueP & exists e026054.(_vary(e026054) & (Subj(e026054) = x) & (Acc(e026054) = z26049) & exists z26052.(_leg(z26052) & exists z26050.(_else(z26050) & TrueP & (z26052 = z26050)) & TrueP & _on(e026054,z26052)) & TrueP)) & TrueP & _with(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_child(x) & TrueP & exists e.(_play(e) & (Subj(e) = x) & exists x.(_mortar(x) & TrueP & _with(e,x) & TrueP) & exists x.(_pistil(x) & TrueP & _with(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_wrestler(x) & _two(x) & TrueP & exists e.(_tag(e) & (Acc(e) = x) & _just(e) & _in(e) & exists x.(_match(x) & _team(x) & _tag(x) & TrueP & _on(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z31527.(_trick(z31527) & _jump(z31527) & TrueP & exists e.(_do(e) & (Subj(e) = x) & (Acc(e) = z31527) & exists x.(_bike(x) & TrueP & _on(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_young(e) & (Subj(e) = x) & _girl(x)) & exists z18001.(exists e.(_pink(e) & (Subj(e) = z18001) & _coat(z18001)) & exists z17998.(_word(z17998) & TrueP & exists e.(_erase(e) & (Subj(e) = z18001) & (Acc(e) = z17998) & exists z18000.(_sign(z18000) & _chalkboard(z18000) & TrueP & _on(e,z18000)) & TrueP)) & TrueP & exists e.(_in(e,z18001) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_fife(x) & _barney(x) & exists z2030.(_bullet(z2030) & TrueP & exists e.(_with(e,z2030) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z29191.(_biceps(z29191) & TrueP & exists e.(_flex(e) & (Subj(e) = x) & (Acc(e) = z29191) & TrueP)) & exists e.(_stand(e) & (Subj(e) = x) & exists z29194.(_rooftop(z29194) & TrueP & _on(e,z29194) & exists z29194.(exists e029192.(_multiple(e029192) & (Subj(e029192) = z29194) & _chimney(z29194)) & TrueP & _with(e,z29194) & exists z29194.(_background(z29194) & TrueP & _in(e,z29194) & TrueP)))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_boy(x) & exists z40274.(_field(z40274) & TrueP & exists e.(_on(e,z40274) & (Subj(e) = x) & exists z40275.(_football(z40275) & _flag(z40275) & TrueP & exists e.(_play(e) & (Subj(e) = x) & (Acc(e) = z40275) & exists z40296.(_boy(z40296) & exists z40287.(exists e040290.(_red(e040290) & (Subj(e040290) = z40287) & _flag(z40287)) & exists z40276.(_football(z40276) & TrueP & exists e040291.(_clutch(e040291) & (Subj(e040291) = z40287) & (Acc(e040291) = z40276) & exists z40284.(_boy(z40284) & exists z40277.(exists e040278.(_yellow(e040278) & (Subj(e040278) = z40277) & _dive(z40277) & _flag(z40277)) & TrueP & exists e040279.(_with(e040279,z40277) & (Subj(e040279) = z40284) & TrueP)) & _while(e040291,z40284) & TrueP))) & exists z40280.(exists e040292.(_red(e040292) & (Subj(e040292) = z40280) & _flag(z40280)) & TrueP & exists e040293.(_get(e040293) & (Subj(e040293) = z40287) & (Acc(e040293) = z40280) & TrueP)) & TrueP & exists e040294.(_wear(e040294) & (Subj(e040294) = z40296) & (Acc(e040294) = z40287) & TrueP)) & TrueP & _with(e,z40296) & TrueP))) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: -exists x.(_woman(x) & _two(x) & TrueP & all z23525.(_noise(z23525) -> (TrueP -> exists e.(_make(e) & (Subj(e) = x) & (Acc(e) = z23525) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(TrueP & exists z51922.(_people(z51922) & TrueP & (x = z51922)) & TrueP & exists e.(_sleep(e) & (Subj(e) = x) & exists x.(_couch(x) & TrueP & _on(e,x)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & exists z45298.(_jeans(z45298) & TrueP & exists e.(_in(e,z45298) & (Subj(e) = x) & TrueP)) & exists e.(_sit(e) & (Subj(e) = x) & exists x.(_river(x) & TrueP & (Subj(e) = x) & exists x.(exists e045299.(_large(e045299) & (Subj(e045299) = x) & _fish(x)) & TrueP & _with(e,x) & TrueP))))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_people(x) & _two(x) & exists e.(_sleep(e) & (Subj(e) = x) & exists z25222.(_vehicle(z25222) & TrueP & _in(e,z25222) & TrueP)) & TrueP & exists e.((Subj(e) = Subj(e)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_woman(x) & _two(x) & TrueP & exists z53907.(_scarf(z53907) & TrueP & exists e.(_have(e) & (Subj(e) = x) & (Acc(e) = z53907) & _on(e) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_old(e) & (Subj(e) = x) & _man(x)) & TrueP & exists e.(_have(e) & (Subj(e) = x) & AccI(e,(exists e.(_lye(e) & (Subj(e) = x) & _down(e) & exists z49595.(_bed(z49595) & TrueP & _in(e,z49595) & TrueP)) & -exists z49596.((z49596 = _he) & TrueP & exists e.(_well(e) & (Subj(e) = z49596) & _feel(e) & TrueP)))) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_young(e) & (Subj(e) = x) & _girl(x)) & exists z26783.(_dance(z26783) & _uniform(z26783) & _school(z26783) & exists z26782.(_sculpture(z26782) & _water(z26782) & exists z26781.(_middle(z26781) & exists z26780.(exists e.(_crowded(e) & (Subj(e) = z26780) & exists e.(_public(e) & (Subj(e) = z26780) & _square(z26780))) & TrueP & (z26781 = z26780)) & TrueP & exists e.(_in(e,z26781) & (Subj(e) = z26782) & TrueP)) & exists e.(_in(e,z26782) & (Subj(e) = z26783) & TrueP)) & exists e.(_in(e,z26783) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_man(x) & TrueP & exists z8393.(exists e.(_green(e) & (Subj(e) = z8393) & _mask(z8393)) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z8393) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_crowd(x) & exists z52621.(_people(z52621) & TrueP & (x = z52621)) & TrueP & exists e.(_asian(e) & (Subj(e) = x) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_dog(x) & exists e.(_sleep(e) & (Subj(e) = x) & TrueP) & TrueP & exists e.((Subj(e) = Subj(e)) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_boy(x) & exists z20622.(_pass(z20622) & _costume(z20622) & _monkey(z20622) & TrueP & exists e.(_wear(e) & (Subj(e) = x) & (Acc(e) = z20622) & exists z20624.(_puppeteer(z20624) & TrueP & (Subj(e) = z20624) & TrueP))) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_young(e) & (Subj(e) = x) & _boy(x)) & exists z10409.(_tongue(z10409) & exists z10408.(_hula(z10408) & exists e.(_hoop(e) & (Subj(e) = z10408) & exists z10407.(_hoop(z10407) & _hula(z10407) & _two(z10407) & exists z10400.(exists e010402.(_crowded(e010402) & (Subj(e010402) = z10400) & _area(z10400)) & TrueP & exists e010403.(_in(e010403,z10400) & (Subj(e010403) = z10407) & TrueP)) & _with(e,z10407)) & exists z10407.(_man(z10407) & exists z10401.(exists e010404.(_blue(e010404) & (Subj(e010404) = z10401) & _shirt(z10401)) & TrueP & exists e010405.(_in(e010405,z10401) & (Subj(e010405) = z10407) & TrueP)) & _with(e,z10407)) & TrueP) & TrueP & exists e.(_out(e,z10408) & (Subj(e) = z10409) & TrueP)) & exists e.(_with(e,z10409) & (Subj(e) = x) & TrueP)) & exists e.(_stand(e) & (Subj(e) = x) & exists x.((x = _he) & TrueP & _behind(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_couple(x) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & exists x.(_park(x) & TrueP & _in(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_performer(x) & _street(x) & exists z40112.(_clause(z40112) & _santa(z40112) & exists z40107.(_middle(z40107) & TrueP & exists e.(_in(e,z40107) & (Subj(e) = z40112) & TrueP)) & exists e.(_with(e,z40112) & (Subj(e) = x) & TrueP)) & exists z40113.(_lady(z40113) & exists z40111.(_side(z40111) & exists z40108.(_hand(z40108) & TrueP & exists e.(_join(e) & (Subj(e) = z40111) & (Acc(e) = z40108) & TrueP)) & TrueP & exists e.(_on(e,z40111) & (Subj(e) = z40113) & TrueP)) & exists e.(_with(e,z40113) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(TrueP & exists z5505.(exists e.(_young(e) & (Subj(e) = z5505) & _player(z5505) & _baseball(z5505)) & TrueP & (x = z5505)) & exists z5506.(_game(z5506) & _championship(z5506) & TrueP & exists e.(_have(e) & (Subj(e) = x) & (Acc(e) = z5506) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.((x = _it) & TrueP & exists z8614.(_evening(z8614) & TrueP & (x = z8614)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: -exists x.(_cat(x) & TrueP & exists z23882.(_treat(z23882) & TrueP & exists e.(_catch(e) & (Subj(e) = x) & (Acc(e) = z23882) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_orange(x) & TrueP & exists e.(_peel(e) & (Acc(e) = x) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_baby(x) & exists z32289.(exists e.(_indoor(e) & (Subj(e) = z32289) & _pool(z32289)) & exists z32286.(exists e.(_inflatable(e) & (Subj(e) = z32286) & _tube(z32286)) & exists z32285.((z32285 = _it) & TrueP & exists e.(_on(e,z32285) & (Subj(e) = z32286) & TrueP)) & exists e.(_use(e) & (Subj(e) = z32289) & (Acc(e) = z32286) & TrueP)) & TrueP & exists e.(_in(e,z32289) & (Subj(e) = x) & TrueP)) & exists e.(_on(e) & (Subj(e) = x) & _'s(e) & TrueP))
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_person(x) & exists z43248.(exists e.(_brown(e) & (Subj(e) = z43248) & _horse(z43248)) & exists z43247.(_prairie(z43247) & exists z43246.(_front(z43246) & exists z43245.(exists e.(_tall(e) & (Subj(e) = z43245) & _mountain(z43245)) & TrueP & (z43246 = z43245)) & TrueP & exists e.(_in(e,z43246) & (Subj(e) = z43247) & TrueP)) & exists e.(_in(e,z43247) & (Subj(e) = z43248) & TrueP)) & exists e.(_on(e,z43248) & (Subj(e) = x) & TrueP)) & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(exists e.(_many(e) & (Subj(e) = x) & _woman(x)) & exists e.(_sit(e) & (Subj(e) = x) & exists z41181.(_room(z41181) & TrueP & _in(e,z41181) & TrueP)) & TrueP & TrueP)
# Decoded sentence:  The man is sitting in the background.
#
# -
# Input sentence: exists x.(_people(x) & _two(x) & TrueP & exists e.(_walk(e) & (Subj(e) = x) & exists x.(exists e037263.(_wooded(e037263) & (Subj(e037263) = x) & _building(x)) & TrueP & _towards(e,x) & TrueP)))
# Decoded sentence:  The man is sitting in the background.
