# %%
from __future__ import print_function

from keras.models import Model
from keras.models import load_model
from keras.layers import Input, LSTM, Dense
import keras
from keras.utils.vis_utils import plot_model


from sklearn.model_selection import train_test_split

import numpy as np
import json
# Out:
# Using TensorFlow backend.
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
batch_size = 64  # Batch size for training.
epochs = 20  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = '/Users/guru/MyResearch/sg/snli/json/snli_inp_1024.json'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
lines = open(data_path)

#json ver 
jdict = json.load(lines)

for line in jdict:
    input_text = (jdict[line])['formula']
    target_text = (jdict[line])['text']
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)
            
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)


input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

#np.zeros 0を要素とする配列(shape, dtype = float, order = ‘C’)　３次元
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')


for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
# Out:
# Number of samples: 19899
# Number of unique input tokens: 74
# Number of unique output tokens: 77
# Max sequence length for inputs: 2428
# Max sequence length for outputs: 267

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
#callback function and parameter search
k
earlystop =keras.callbacks.EarlyStopping(monitor='val_loss', patience=0, verbose=0, mode='auto')
            #keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=10, verbose=0, mode='auto')
tensorboard = keras.callbacks.TensorBoard(log_dir='logs',write_images=True,write_graph=True,)

#トレーニングデータ，テストデータ分割
#data_train, data_test, label_train, label_test = train_test_split(bow, labels_list, test_size=0.5)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
#plot_model(model, to_file='model.png')
# Run training
#model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[tensorboard])

# Save model
model.save('s2s.h5')
# Out:
# Train on 15919 samples, validate on 3980 samples
# Epoch 1/1
# 15919/15919 [==============================] - 9710s 610ms/step - loss: 0.5440 - val_loss: 0.4509
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_4 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_3/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_3/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
model.save('new_pre_s2s.h5')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[tensorboard])
model.save('s2s.h5')
# Out:
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_4 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_3/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_3/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '
# Train on 15919 samples, validate on 3980 samples
# Epoch 1/20
# 15919/15919 [==============================] - 13026s 818ms/step - loss: 0.1583 - val_loss: 0.1899
# Epoch 2/20
# 15919/15919 [==============================] - 2881s 181ms/step - loss: 0.1549 - val_loss: 0.1885
# Epoch 3/20
# 15919/15919 [==============================] - 2847s 179ms/step - loss: 0.1518 - val_loss: 0.1883
# Epoch 4/20
# 15919/15919 [==============================] - 2838s 178ms/step - loss: 0.1492 - val_loss: 0.1862
# Epoch 5/20
# 15919/15919 [==============================] - 2839s 178ms/step - loss: 0.1464 - val_loss: 0.1840
# Epoch 6/20
# 15919/15919 [==============================] - 2839s 178ms/step - loss: 0.1436 - val_loss: 0.1821
# Epoch 7/20
# 15919/15919 [==============================] - 2841s 178ms/step - loss: 0.1408 - val_loss: 0.1815
# Epoch 8/20
# 15919/15919 [==============================] - 2841s 178ms/step - loss: 0.1385 - val_loss: 0.1800
# Epoch 9/20
# 15919/15919 [==============================] - 2841s 178ms/step - loss: 0.1372 - val_loss: 0.1792
# Epoch 10/20
# 15919/15919 [==============================] - 2841s 178ms/step - loss: 0.1344 - val_loss: 0.1775
# Epoch 11/20
# 15919/15919 [==============================] - 2880s 181ms/step - loss: 0.1324 - val_loss: 0.1775
# Epoch 12/20
# 15919/15919 [==============================] - 2977s 187ms/step - loss: 0.1329 - val_loss: 0.1831
# Epoch 13/20
# 15919/15919 [==============================] - 2850s 179ms/step - loss: 0.1370 - val_loss: 0.1841
# Epoch 14/20
# 15919/15919 [==============================] - 3030s 190ms/step - loss: 0.1327 - val_loss: 0.1766
# Epoch 15/20
# 15919/15919 [==============================] - 4131s 259ms/step - loss: 0.1274 - val_loss: 0.1747
# Epoch 16/20
# 15919/15919 [==============================] - 2985s 188ms/step - loss: 0.1253 - val_loss: 0.1720
# Epoch 17/20
# 15919/15919 [==============================] - 2942s 185ms/step - loss: 0.1236 - val_loss: 0.1728
# Epoch 18/20
# 15919/15919 [==============================] - 2947s 185ms/step - loss: 0.1221 - val_loss: 0.1719
# Epoch 19/20
# 15919/15919 [==============================] - 3485s 219ms/step - loss: 0.1246 - val_loss: 0.1766
# Epoch 20/20
# 15919/15919 [==============================] - 3833s 241ms/step - loss: 0.1251 - val_loss: 0.1767

# %%
# choose input data version
#input_texts_inf = []
#lines = open('predict.txt').read().split('\n')

#for line in lines[: min(num_samples, len(lines) - 1)]:
#    input_text_inf = line
#    input_texts_inf.append(input_text_inf)
            
#print('Number of samples:', len(input_texts_inf))


#np.zeros 0を要素とする配列(shape, dtype = float, order = ‘C’)　３次元
#encoder_input_data_inf = np.zeros(
#    (len(input_texts_inf), max_encoder_seq_length, num_encoder_tokens),
#    dtype='float32')


#for i, input_text_inf in enumerate(input_texts_inf):
#    for t, char in enumerate(input_text_inf):
#        encoder_input_data_inf[i, t, input_token_index[char]] = 1.
# Out:
# Number of samples: 1

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

#model = load_model('s2s.h5')
# Define sampling models
#model.save('s2s.h5')

#encoder_model = load_model('encoder.h5')
encoder_model = Model(encoder_inputs, encoder_states)
encoder_model.save('encoder.h5')


#decoder_model = load_model('decoder.h5')
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)
decoder_model.save('decoder.h5')

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())

reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())
# Out:
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_4 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'input_9:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'input_10:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training test)
    # for trying out decoding.
    #input_seq = encoder_input_data[seq_index: seq_index + 1]
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    #print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
    print('Answer sentence:', target_texts[seq_index])
# Out:
# -
# Decoded sentence:  The boy is sleeping on the bench of the beach.
#
# Answer sentence: 	 Four men ride ina fast boat.
#
#
# -
# Decoded sentence: A group of people wearing hats and laughs the one head asa fence vehicle drinking basketball.
#
# Answer sentence: 	 Female ina pink tutu and pink boxing gloves performing ina chained off area.
#
#
# -
# Decoded sentence: A brown dog witha blue hood is looking out the window.
#
# Answer sentence: 	A large elderly woman ina green stripy dress is carrying shopping bags alonga cobbled street.
#
#
# -
# Decoded sentence:  The two men are playing basketball.
#
# Answer sentence: 	A young man is blindfolded.
#
#
# -
# Decoded sentence:  Two people are walking downa cobble toy and shares sitting ona crowded city street.
#
# Answer sentence: 	A middle-aged man works under the engine ofa train on rail tracks.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench of the beach.
#
# Answer sentence: 	A little boy is shootinga basketball.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the street.
#
# Answer sentence: 	A man ina photo booth.
#
#
# -
# Decoded sentence:  Two people are walking downa cobble outdoors.
#
# Answer sentence: 	 two pedestrians walk ona cobblestone road pasta cafe
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	 The catcher is right-handed.
#
#
# -
# Decoded sentence: A man is sitting ina chair.
#
# Answer sentence: 	A man is insidea Target.
#
#
# -
# Decoded sentence:  The girl is wearing jeans.
#
# Answer sentence: 	A guy is in the laundromat
#
#
# -
# Decoded sentence:  The people are outside stards.
#
# Answer sentence: 	 The couple just started dating.
#
#
# -
# Decoded sentence: A woman ina blue shirt and blue jeans is walking down the street.
#
# Answer sentence: 	A woman, ina green shirt, preparing to run ona treadmill.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancers are standing outside on the side of the street on the boat with his hands in the background.
#
# Answer sentence: 	A person wearing orange pants in playing in the mud.
#
#
# -
# Decoded sentence:  The girl is wearing jeans.
#
# Answer sentence: 	 Dogs are playing on snow.
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	a player walks around
#
#
# -
# Decoded sentence: A man and woman are sitting ata table while her friends drim.
#
# Answer sentence: 	A man and woman are talking ina party atmosphere witha crowd and purple and blue lights behind them.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	A female ina chained off area.
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	A teenage is ona surfboard.
#
#
# -
# Decoded sentence:  Two people are walking downa cobble outdoors.
#
# Answer sentence: 	 Some young boys ride bikes in the street.
#
#
# -
# Decoded sentence: A young boy is sitting ona bench with his family in the background.
#
# Answer sentence: 	A youngster straddlesa small makeshift bench while his companion plays in the doorway nearby.
#
#
# -
# Decoded sentence: A woman is ridinga bike in the background.
#
# Answer sentence: 	a woman nibbles food from her hand
#
#
# -
# Decoded sentence:  Two men are sitting in the rear tarking ona cellphone ina parade.
#
# Answer sentence: 	 Two young men in unusual clothing are jumping ina gym.
#
#
# -
# Decoded sentence:  The people are outside stards.
#
# Answer sentence: 	 There are children by an adult.
#
#
# -
# Decoded sentence: A man ina black shirt is standing in front of the counter with complete in the background.
#
# Answer sentence: 	A man napping on the ground witha shirt over his eyes witha person standing beside him.
#
#
# -
# Decoded sentence:  Two men are sitting in the rear tarking ona cellphone ina parade.
#
# Answer sentence: 	 Two men are ona cherry picker proceeding to perform work ata construction site.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench.
#
# Answer sentence: 	 There are multiple people present.
#
#
# -
# Decoded sentence: A woman is ridinga bike.
#
# Answer sentence: 	 The woman is on top of the horse.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancers are standing outside on the side of the street on the boat with his hands in the background.
#
# Answer sentence: 	 The dog is coming out of the ocean witha stick in its mouth.
#
#
# -
# Decoded sentence: A brown dog witha blue hood is looking out the window.
#
# Answer sentence: 	A snowboarder in green pants boards downa snowy mountain.
#
#
# -
# Decoded sentence: A woman ina blue shirt and blue jeans.
#
# Answer sentence: 	A man and woman are having drinks ina bar.
#
#
# -
# Decoded sentence: A man wearinga blue shirt and blue jeans is sitting ona bench ina park.
#
# Answer sentence: 	A man witha tattoo is wearing sunglasses while holdinga small boy.
#
#
# -
# Decoded sentence:  Two people are sitting ina rock.
#
# Answer sentence: 	 Two men were outsidea building.
#
#
# -
# Decoded sentence:  Three children play with the ball in the water by the ball.
#
# Answer sentence: 	A little boy learning to swim ina pool with his arm floaties.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench of the beach.
#
# Answer sentence: 	A lone man sitting ina large decorated area.
#
#
# -
# Decoded sentence:  Two men are sitting in the rear takesa photographer.
#
# Answer sentence: 	 Two women talking overa glass of wine.
#
#
# -
# Decoded sentence:  Two people are sitting ina rock walking down the street.
#
# Answer sentence: 	 Two friends are walking together to there house
#
#
# -
# Decoded sentence:  The woman is walking to the ball.
#
# Answer sentence: 	A woman is sick in bed.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench of the beach.
#
# Answer sentence: 	A street vendor is selling delicious food to people.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	 Musicians are performing on stage.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt and white uniform holds her each other.
#
# Answer sentence: 	A guy pushesa machine through the grass.
#
#
# -
# Decoded sentence: A woman is ridinga bike.
#
# Answer sentence: 	 The woman is hunting for elk.
#
#
# -
# Decoded sentence: A group of people walking down the street witha woman ina purple shirt and jeans sports of food.
#
# Answer sentence: 	A lady is carryinga big bag of flowers.
#
#
# -
# Decoded sentence: A young boy ina black shirt is standing in front ofa brick wall.
#
# Answer sentence: 	A middle-aged man 's shaving his beard ina room with white walls which does n't look likea bathroom.
#
#
# -
# Decoded sentence: A brown dog witha blue hood is looking out the window.
#
# Answer sentence: 	 Black dog with orange ball approaches camera across dead leaves.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench.
#
# Answer sentence: 	A snowboarder is performing tricks.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	 This isa heated hockey match at the goal line.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the snow.
#
# Answer sentence: 	 The man is alone in his bathroom.
#
#
# -
# Decoded sentence: A group of people are sitting ina rock walls.
#
# Answer sentence: 	A cyclist just wiped out and is trying to get up
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	 People talking outside.
#
#
# -
# Decoded sentence:  The people are outside stards.
#
# Answer sentence: 	 The boy is wearing red trunks.
#
#
# -
# Decoded sentence: A woman ina blue shirt and black shorts playsa green holse while sitting ona rocky class behind her.
#
# Answer sentence: 	A woman with dark hair wearinga dark shirt, jeans, and glasses is talking intoa microphone.
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	 The people sit together.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancing together on the sun side are looking in the snow.
#
# Answer sentence: 	A group of kids listening to their band instructor, and reading music off their papers.
#
#
# -
# Decoded sentence: A man and woman are sitting ata table while her friends between the stairs ofa cliff ona child the desplayer is working on the room.
#
# Answer sentence: 	 Elderly woman with green sweater picking out produce in outdoor market.
#
#
# -
# Decoded sentence: A young boy is sitting ona bench with his family hands.
#
# Answer sentence: 	A young boy wearinga red coat eatsa chocolate bar.
# -
# Decoded sentence:  Two men are sitting in the rear tarking ona cellphone ina parade on the street.
#
# Answer sentence: 	 Two people ona date stop by the side of the road to look ina store front window.
#
#
# -
# Decoded sentence: A man ina black shirt is standing in front of the counter with complete in the background.
#
# Answer sentence: 	 Man wearing dark clothes walks downa street witha wall of graffiti to his left.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the street.
#
# Answer sentence: 	A male is placing an order ina deli.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	 The people are sitting and eating their food.
#
#
# -
# Decoded sentence: A woman is ridinga bike in the background.
#
# Answer sentence: 	A woman is window shopping for purses.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	A crowd watchinga soccer match.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt and white uniform hold hangs for her man ata restaurant.
#
# Answer sentence: 	 Girl in blue chewing on paper.
#
#
# -
# Decoded sentence: A group of people wearing hats and laughs the one head asa fence vehicle drinking basketball in the background.
#
# Answer sentence: 	A girl ina striped black and white sweater holds on to her friend who is bent over wearinga hooded black sweater and torn blue jeans.
#
#
# -
# Decoded sentence:  Three people are walking down the street witha woman ina purple shirt and black plasticter in the background looking out the water.
#
# Answer sentence: 	 Three glass elevators with people inside of them.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancers are standing outside on the side of the street on the boat with his hands in the background.
#
# Answer sentence: 	A lady ina red sweatshirt openinga present.
#
#
# -
# Decoded sentence:  Two people are sitting ina rock walking down the street.
#
# Answer sentence: 	 Two people looking at New York.
#
#
# -
# Decoded sentence:  The girl is wearing jeans.
#
# Answer sentence: 	A person is happily playinga drum.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large chality building in the background.
#
# Answer sentence: 	A boy in dark blue clothes is kneeling while holdinga toy.
#
#
# -
# Decoded sentence:  Three people are walking down the street witha woman ina purple shirt and black plasticter in the background looking out the water.
#
# Answer sentence: 	 There is an older man doing work on the railroad tracks.
#
#
# -
# Decoded sentence: A group of people wearing hats and laughs the one head asa fence vehicle drinking basketball in the background.
#
# Answer sentence: 	A group of onlookers glance ata person doinga strange trick on her head.
#
#
# -
# Decoded sentence: A brown dog witha blue hood is looking out the window.
#
# Answer sentence: 	 Female runners from Japan, Germany and China are running side by side.
#
#
# -
# Decoded sentence: A woman ina blue shirt and blue jeans.
#
# Answer sentence: 	A woman cutting fabric flowers ina market.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt and white uniform holds her each other.
#
# Answer sentence: 	A gentleman ina striped shirt not gesturing
#
#
# -
# Decoded sentence:  Three people are sitting on the beach whoce phone are walking down the street.
#
# Answer sentence: 	A toddler ina denim hats plays ina tire.
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	 people take pictures
#
#
# -
# Decoded sentence: A woman is ridinga bike in the background.
#
# Answer sentence: 	 Women are trying to drive home.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the snow.
#
# Answer sentence: 	A man is sitting down ona bench.
#
#
# -
# Decoded sentence:  The people are outside.
#
# Answer sentence: 	 The child isa toddler.
#
#
# -
# Decoded sentence:  Three children play with two black close up behind her.
#
# Answer sentence: 	 Three people in t-shirt, yellow helmets and harnesses begin to climb ladder.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench.
#
# Answer sentence: 	 There isa soda bottle flying.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the street.
#
# Answer sentence: 	A man is playing on an electric guitar.
#
#
# -
# Decoded sentence:  Three people are sitting on the beach whoce phones.
#
# Answer sentence: 	a white dog is tugging ona black rope
#
#
# -
# Decoded sentence: A group of people wearing hats and laughs the one head asa fence vehicle drinking basketball in the background.
#
# Answer sentence: 	A chef speaks intoa microphone abouta mixed salad contained ina bowl witha decorative lid.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancers are standing outside on the side of the street on the boat with his hands in the background.
#
# Answer sentence: 	A person is climbinga cliff wall that overlooks water.
#
#
# -
# Decoded sentence:  The people are sitting down.
#
# Answer sentence: 	 There is not an image here.
#
#
# -
# Decoded sentence: A woman ina blue shirt and blue jeans is walking down the street.
#
# Answer sentence: 	A woman wading througha pool in front ofa waterfall.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancer in the background.
#
# Answer sentence: 	A group of people wearing blue shirts, standing in the grass.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large kid who is moning as he passess while dancers are standing outside on the side of the street on the boat with his hands in the background.
#
# Answer sentence: 	 Dog running down paved walkway neara Japanese maple tree.
#
#
# -
# Decoded sentence: A group of people walking down the street witha large chality building in the background.
#
# Answer sentence: 	 People are standing around the new fountain in the city hall.
#
#
# -
# Decoded sentence:  The girl is wearinga blue shirt.
#
# Answer sentence: 	A girl has all white.
#
#
# -
# Decoded sentence: A man is sitting ina chair blowing babby shipping man in the background of the street.
#
# Answer sentence: 	A man drives his car to the fair.
#
#
# -
# Decoded sentence: A black and white dog with long hair sell outside in the air and trees in the background.
#
# Answer sentence: 	A dune buggy with one male passenger gets some air as it drives overa sand dune.
#
#
# -
# Decoded sentence:  The boy is sleeping on the bench of the beach.
#
# Answer sentence: 	A shirtless man is walking toa gas station.
#
#
# -
# Decoded sentence:  The people are outside staring for his family.
#
# Answer sentence: 	A pale dog runs downa path.
#
#
# -
# Decoded sentence:  Two people are sitting ina rock walking down the street.
#
# Answer sentence: 	 Two people drive arounda track.
#
#
# -
# Decoded sentence:  The woman is sitting on the bench.
#
# Answer sentence: 	A woman is on the phone.
#
#
# -
# Decoded sentence: A man ina blue shirt and blue jeans is walking down the street witha large field with their arms streth large basses on the back ofa played of the snow.
#
# Answer sentence: 	A man ina blue shirt is ina lab looking intoa microscope.
#
#
# -
# Decoded sentence:  Two men are sitting in the rear takesa child of another waid ina black shirt.
#
# Answer sentence: 	 The two girls are in deep water.
#
#
# -
# Decoded sentence: A group of people wearing hats and laughs the one head asa fence vehicle drinking basketball in the background.
#
# Answer sentence: 	A child in green winter clothes is holding his or her hand up while two other children look at him or her.
