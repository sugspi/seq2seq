# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'keras-seq2seq/distinct/ku_corpus_char.distinct.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
lines = open(data_path).read().split('\n')

for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split("___SP___")#line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)
            
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)


input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

#np.zeros 0を要素とする配列(shape, dtype = float, order = ‘C’)　３次元
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')


for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
# Out:
# Number of samples: 4942
# Number of unique input tokens: 93
# Number of unique output tokens: 95
# Max sequence length for inputs: 14
# Max sequence length for outputs: 16

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s_1107.h5')
# Out:
# Train on 3953 samples, validate on 989 samples
# Epoch 1/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.9227 - val_loss: 0.8584
# Epoch 2/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.8233 - val_loss: 0.7827
# Epoch 3/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.7392 - val_loss: 0.7115
# Epoch 4/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.6738 - val_loss: 0.6443
# Epoch 5/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.5854 - val_loss: 0.5728
# Epoch 6/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.5071 - val_loss: 0.5211
# Epoch 7/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.4537 - val_loss: 0.4573
# Epoch 8/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.4105 - val_loss: 0.4307
# Epoch 9/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.3718 - val_loss: 0.3927
# Epoch 10/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.3365 - val_loss: 0.3604
# Epoch 11/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.3039 - val_loss: 0.3384
# Epoch 12/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.2734 - val_loss: 0.3202
# Epoch 13/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.2456 - val_loss: 0.3049
# Epoch 14/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.2214 - val_loss: 0.2678
# Epoch 15/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1981 - val_loss: 0.2537
# Epoch 16/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1775 - val_loss: 0.2417
# Epoch 17/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1574 - val_loss: 0.2233
# Epoch 18/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1407 - val_loss: 0.2239
# Epoch 19/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1261 - val_loss: 0.2104
# Epoch 20/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.1114 - val_loss: 0.2174
# Epoch 21/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.0997 - val_loss: 0.2112
# Epoch 22/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.0892 - val_loss: 0.1809
# Epoch 23/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.0817 - val_loss: 0.1784
# Epoch 24/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.0707 - val_loss: 0.1760
# Epoch 25/100
# 3953/3953 [==============================] - 10s 3ms/step - loss: 0.0636 - val_loss: 0.1813
# Epoch 26/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0560 - val_loss: 0.1665
# Epoch 27/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0503 - val_loss: 0.1668
# Epoch 28/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0453 - val_loss: 0.1708
# Epoch 29/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0405 - val_loss: 0.1574
# Epoch 30/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0367 - val_loss: 0.1749
# Epoch 31/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0335 - val_loss: 0.1574
# Epoch 32/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0291 - val_loss: 0.1558
# Epoch 33/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0268 - val_loss: 0.1521
# Epoch 34/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0256 - val_loss: 0.1559
# Epoch 35/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0231 - val_loss: 0.1577
# Epoch 36/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0210 - val_loss: 0.1775
# Epoch 37/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0185 - val_loss: 0.1558
# Epoch 38/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0181 - val_loss: 0.1584
# Epoch 39/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0174 - val_loss: 0.1624
# Epoch 40/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0149 - val_loss: 0.1523
# Epoch 41/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0153 - val_loss: 0.1715
# Epoch 42/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0125 - val_loss: 0.1564
# Epoch 43/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0145 - val_loss: 0.1638
# Epoch 44/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0118 - val_loss: 0.1633
# Epoch 45/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0146 - val_loss: 0.1601
# Epoch 46/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0118 - val_loss: 0.1514
# Epoch 47/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0103 - val_loss: 0.1807
# Epoch 48/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0109 - val_loss: 0.1558
# Epoch 49/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0110 - val_loss: 0.1589
# Epoch 50/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0107 - val_loss: 0.1646
# Epoch 51/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0091 - val_loss: 0.1620
# Epoch 52/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0097 - val_loss: 0.1558
# Epoch 53/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.0076 - val_loss: 0.1580
# Epoch 54/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0093 - val_loss: 0.1666
# Epoch 55/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0088 - val_loss: 0.1618
# Epoch 56/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0079 - val_loss: 0.1624
# Epoch 57/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0078 - val_loss: 0.1617
# Epoch 58/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0081 - val_loss: 0.1583
# Epoch 59/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0084 - val_loss: 0.1580
# Epoch 60/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0072 - val_loss: 0.1555
# Epoch 61/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0064 - val_loss: 0.1618
# Epoch 62/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0066 - val_loss: 0.1672
# Epoch 63/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0067 - val_loss: 0.1603
# Epoch 64/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0061 - val_loss: 0.1683
# Epoch 65/100
# 3953/3953 [==============================] - 13s 3ms/step - loss: 0.0076 - val_loss: 0.1643
# Epoch 66/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.0068 - val_loss: 0.1598
# Epoch 67/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0055 - val_loss: 0.1630
# Epoch 68/100
# 3953/3953 [==============================] - 13s 3ms/step - loss: 0.0061 - val_loss: 0.1563
# Epoch 69/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0073 - val_loss: 0.1668
# Epoch 70/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0064 - val_loss: 0.1847
# Epoch 71/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.0065 - val_loss: 0.1657
# Epoch 72/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0059 - val_loss: 0.1658
# Epoch 73/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0049 - val_loss: 0.1628
# Epoch 74/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0057 - val_loss: 0.1615
# Epoch 75/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.0055 - val_loss: 0.1665
# Epoch 76/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0055 - val_loss: 0.1635
# Epoch 77/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0061 - val_loss: 0.1605
# Epoch 78/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0050 - val_loss: 0.1606
# Epoch 79/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0047 - val_loss: 0.1596
# Epoch 80/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0053 - val_loss: 0.1608
# Epoch 81/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0039 - val_loss: 0.1597
# Epoch 82/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0049 - val_loss: 0.1692
# Epoch 83/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0047 - val_loss: 0.1690
# Epoch 84/100
# 3953/3953 [==============================] - 12s 3ms/step - loss: 0.0049 - val_loss: 0.1854
# Epoch 85/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0050 - val_loss: 0.1662
# Epoch 86/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0037 - val_loss: 0.1679
# Epoch 87/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0038 - val_loss: 0.1786
# Epoch 88/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0037 - val_loss: 0.1784
# Epoch 89/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0035 - val_loss: 0.1771
# Epoch 90/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0044 - val_loss: 0.1626
# Epoch 91/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0050 - val_loss: 0.1696
# Epoch 92/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0049 - val_loss: 0.1649
# Epoch 93/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0047 - val_loss: 0.1681
# Epoch 94/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0033 - val_loss: 0.1659
# Epoch 95/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0049 - val_loss: 0.1687
# Epoch 96/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0039 - val_loss: 0.1624
# Epoch 97/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0045 - val_loss: 0.1602
# Epoch 98/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0048 - val_loss: 0.1628
# Epoch 99/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0036 - val_loss: 0.1645
# Epoch 100/100
# 3953/3953 [==============================] - 11s 3ms/step - loss: 0.0037 - val_loss: 0.1655
# /Users/guru/.pyenv/versions/3.5.1/lib/python3.5/site-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training test)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: ベンキョウ
# Decoded sentence: ベンキョウ
#
# -
# Input sentence: カノジョ
# Decoded sentence: カノジョ
#
# -
# Input sentence: シュッケ
# Decoded sentence: シュッケ
#
# -
# Input sentence: セイヨウ
# Decoded sentence: セイヨウ
#
# -
# Input sentence: センソウ
# Decoded sentence: センソウ
#
# -
# Input sentence: オイシカッ
# Decoded sentence: オイシカッ
#
# -
# Input sentence: トウダイ
# Decoded sentence: トウダイ
#
# -
# Input sentence: トチ
# Decoded sentence: トチ
#
# -
# Input sentence: レイ
# Decoded sentence: レイコ
#
# -
# Input sentence: カイコ
# Decoded sentence: カイコ
#
# -
# Input sentence: タイフウ
# Decoded sentence: タイフウ
#
# -
# Input sentence: カノウ
# Decoded sentence: カノウ
#
# -
# Input sentence: カイガ
# Decoded sentence: カイガ
#
# -
# Input sentence: タロウ
# Decoded sentence: タロウ
#
# -
# Input sentence: コオリ
# Decoded sentence: コオリ
#
# -
# Input sentence: ジョウミャク
# Decoded sentence: ジョウミャク
#
# -
# Input sentence: スイヨウビ
# Decoded sentence: スイヨウビ
#
# -
# Input sentence: ノグチ
# Decoded sentence: ノグチ
#
# -
# Input sentence: メルマガ
# Decoded sentence: メルマガ
#
# -
# Input sentence: カレ
# Decoded sentence: カレ
#
# -
# Input sentence: オカネ
# Decoded sentence: オカネ
#
# -
# Input sentence: コノ
# Decoded sentence: コノ
#
# -
# Input sentence: ピョンピョン
# Decoded sentence: ピョンピョン
#
# -
# Input sentence: サイコウ
# Decoded sentence: サイコウ
#
# -
# Input sentence: ハナコ
# Decoded sentence: ハナコ
#
# -
# Input sentence: カミ
# Decoded sentence: カミ
#
# -
# Input sentence: マンチョウ
# Decoded sentence: マンチョウ
#
# -
# Input sentence: キョウ
# Decoded sentence: キョウ
#
# -
# Input sentence: ヘイネン
# Decoded sentence: ヘイネン
#
# -
# Input sentence: ギャクタイ
# Decoded sentence: ギャクタイ
#
# -
# Input sentence: ツマ
# Decoded sentence: ツマ
#
# -
# Input sentence: シタウチ
# Decoded sentence: シタウチ
#
# -
# Input sentence: メキャベツ
# Decoded sentence: メキャベツ
#
# -
# Input sentence: チョウキ
# Decoded sentence: チョウキ
#
# -
# Input sentence: ヒガイ
# Decoded sentence: ヒガイ
#
# -
# Input sentence: イマ
# Decoded sentence: イマ
#
# -
# Input sentence: ワタシ
# Decoded sentence: ワタシ
#
# -
# Input sentence: ビタミン
# Decoded sentence: ビタミン
#
# -
# Input sentence: カンヨウ
# Decoded sentence: カンヨウ
#
# -
# Input sentence: エダマメ
# Decoded sentence: エダマメ
#
# -
# Input sentence: キョウ
# Decoded sentence: キョウ
#
# -
# Input sentence: ニッポン
# Decoded sentence: ニッポン
#
# -
# Input sentence: タイジュウ
# Decoded sentence: タイジュウ
#
# -
# Input sentence: オウダン
# Decoded sentence: オウダン
#
# -
# Input sentence: カノジョ
# Decoded sentence: カノジョ
#
# -
# Input sentence: カクチ
# Decoded sentence: カクチ
#
# -
# Input sentence: ソウブセン
# Decoded sentence: ソウブセン
#
# -
# Input sentence: カタ
# Decoded sentence: カタ
#
# -
# Input sentence: チャーハン
# Decoded sentence: チャーハン
#
# -
# Input sentence: カミ
# Decoded sentence: カミ
#
# -
# Input sentence: カイシャ
# Decoded sentence: カイシャ
#
# -
# Input sentence: カショウ
# Decoded sentence: カショウ
#
# -
# Input sentence: カレ
# Decoded sentence: カレ
#
# -
# Input sentence: クサツ
# Decoded sentence: クサツ
#
# -
# Input sentence: カセイ
# Decoded sentence: カセイ
#
# -
# Input sentence: オンナ
# Decoded sentence: オンナ
#
# -
# Input sentence: シキテン
# Decoded sentence: シキテン
#
# -
# Input sentence: シュジン
# Decoded sentence: シュジン
#
# -
# Input sentence: テチョウ
# Decoded sentence: テチョウ
#
# -
# Input sentence: オシエ
# Decoded sentence: オシエ
#
# -
# Input sentence: ホッカイドウ
# Decoded sentence: ホッカイドウ
#
# -
# Input sentence: フトン
# Decoded sentence: フトン
#
# -
# Input sentence: ジドウ
# Decoded sentence: ジドウ
#
# -
# Input sentence: リス
# Decoded sentence: リス
#
# -
# Input sentence: ウサギ
# Decoded sentence: ウサギ
#
# -
# Input sentence: サムク
# Decoded sentence: サムク
#
# -
# Input sentence: ワタシ
# Decoded sentence: ワタシ
#
# -
# Input sentence: タロウ
# Decoded sentence: タロウ
#
# -
# Input sentence: キョウジュ
# Decoded sentence: キョウジュ
#
# -
# Input sentence: ニッポン
# Decoded sentence: ニッポン
#
# -
# Input sentence: ボタン
# Decoded sentence: ボタン
#
# -
# Input sentence: ツユ
# Decoded sentence: ツユ
#
# -
# Input sentence: ト
# Decoded sentence: ト
#
# -
# Input sentence: ツウキン
# Decoded sentence: ツウキン
#
# -
# Input sentence: カレ
# Decoded sentence: カレ
#
# -
# Input sentence: サクラ
# Decoded sentence: サクラ
#
# -
# Input sentence: サケ
# Decoded sentence: サケ
#
# -
# Input sentence: ハーブ
# Decoded sentence: ハーブ
#
# -
# Input sentence: ドコ
# Decoded sentence: ドコ
#
# -
# Input sentence: カレ
# Decoded sentence: カレ
#
# -
# Input sentence: ソウジ
# Decoded sentence: ソウジ
#
# -
# Input sentence: ゴライコウ
# Decoded sentence: ゴライコウ
#
# -
# Input sentence: ショクモツ
# Decoded sentence: ショクモツ
#
# -
# Input sentence: キンシ
# Decoded sentence: キンシ
#
# -
# Input sentence: ヒャッカテン
# Decoded sentence: ヒャッカテン
#
# -
# Input sentence: リョウリ
# Decoded sentence: リョウリ
#
# -
# Input sentence: テイボウ
# Decoded sentence: テイボウ
#
# -
# Input sentence: ケンキュウ
# Decoded sentence: ケンキュウ
#
# -
# Input sentence: ム
# Decoded sentence: ム
#
# -
# Input sentence: ハンシャ
# Decoded sentence: ハンシャ
#
# -
# Input sentence: ツボミ
# Decoded sentence: ツボミ
#
# -
# Input sentence: トシシタ
# Decoded sentence: トシシタ
#
# -
# Input sentence: カノジョ
# Decoded sentence: カノジョ
#
# -
# Input sentence: ジョ
# Decoded sentence: ジョ
#
# -
# Input sentence: カゾク
# Decoded sentence: カゾク
#
# -
# Input sentence: チチ
# Decoded sentence: チチ
#
# -
# Input sentence: ツユ
# Decoded sentence: ツユ
#
# -
# Input sentence: キョネン
# Decoded sentence: キョネン
#
# -
# Input sentence: オデン
# Decoded sentence: オデン
#
# -
# Input sentence: マツタケ
# Decoded sentence: マツタケ
