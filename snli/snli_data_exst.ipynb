# %%
import numpy as np
import json
import pandas as pd
import os
import re
import ast
import xml.etree.ElementTree as ET
import ast

# %%
# input

lines = []
with open('snli_1.0_dev.jsonl') as f:
    line = f.readline()
    while line:
        lines.append(line)
        line = f.readline()
txt = open('snli_dev_100.txt', 'w') # 書き込みモードで開く

count= 0;
for i in lines:
    count +=1
    dic  = json.loads(i)
    txt.write(dic['sentence1']+ "\n") 
    txt.write(dic['sentence2']+ "\n") 
    if(100<count):
        break
    
txt.close()
# Out:
# 10000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-86406ca2351c> in <module>()
#       9 txt = open('snli_dev_100.txt', 'w') # 書き込みモードで開く
#      10 print(len(lines))
# ---> 11 raise
#      12
#      13 count= 0;
#
# RuntimeError: No active exception to reraise

# %%
#テキストの取り出し
txt_data = []
with open('snli_dev.txt') as f:
    line = f.readline()
    while line:
        line = line.replace('\n','')
        line = line.replace('\r','')
#        print(line)
        txt_data.append(line)
        line = f.readline()
print(len(txt_data))
# Out:
# 20000

# %%
#en_parsed のsemから取り出し
tree = ET.parse('sem/snli_dev_100.txt.candc.sem.xml')
root = tree.getroot()

root = root[0]
root = root[0] #１個目のsentence

mydict = {}
c = 0 #辞書のindexを回す
print(len(root))

#子階層のタグと中身
for child in root:
    
    formula = child[2]  #child[2]がsemantics
    check = (child[2].attrib)
    check = check['status']
   
    if(check == 'success'):
        plain = ""
        toridashi = child[0]
        #print(child[0])
        
        for i in toridashi :
            p = i.attrib
            p = p['surf']
            if(len(p) == 1):
                plain = plain + p
            else :
                plain = plain + " " + p
        plain = plain+'\n'
        
        print(plain)
        
        formula = child[2][0]
        formula = (formula.attrib)
        formula = formula['sem'] #\nが付与されていると信じている
        
        pair = {'text':plain,'formula':formula}
        mydict.update({str(c):pair})
        
    else:
      print('faild parse')
    c = c + 1
print(len(formulas))
    
f = open('snli_input_data.txt', 'w') # 書き込みモードで開く
json.dump(mydict, f,ensure_ascii=False)
f.close()
# Out:
# 199
#  Two women are embracing while holding to go packages.
#
#  The sisters are hugging goodbye while holding to go packages after just eating lunch.
#
#  Two women are embracing while holding to go packages.
#
#  Two woman are holding packages.
#
#  Two women are embracing while holding to go packages.
#
#  The men are fighting outsidea deli.
#
#  Two young children in blue jerseys, one with the number9 and one with the number2 are standing on wooden steps ina bathroom and washing their hands ina sink.
#
#  Two kids in numbered jerseys wash their hands.
#
#  Two young children in blue jerseys, one with the number9 and one with the number2 are standing on wooden steps ina bathroom and washing their hands ina sink.
#
#  Two kids ata ballgame wash their hands.
#
#  Two young children in blue jerseys, one with the number9 and one with the number2 are standing on wooden steps ina bathroom and washing their hands ina sink.
#
#  Two kids in jackets walk to school.
#
# A man selling donuts toa customer duringa world exhibition event held in the city of Angeles
#
# A woman drinks her coffee ina small cafe.
#
# A man selling donuts toa customer duringa world exhibition event held in the city of Angeles
#
# faild parse
# A man selling donuts toa customer duringa world exhibition event held in the city of Angeles
#
# A man selling donuts toa customer.
#
#  Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.
#
#  boys play football
#
#  Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.
#
#  dog eats out of bowl
#
#  Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.
#
#  boys scoringa touchdown
#
# A man ina blue shirt standing in front ofa garage-like structure painted with geometric designs.
#
# A man is repaintinga garage
#
# A man ina blue shirt standing in front ofa garage-like structure painted with geometric designs.
#
# A man is wearinga blue shirt
#
# A man ina blue shirt standing in front ofa garage-like structure painted with geometric designs.
#
# A man is wearinga black shirt
#
#  Undera blue sky with white clouds,a child reaches up to touch the propeller ofa plane standing parked ona field of grass.
#
# A child is reaching to touch the propeller ofa plane.
#
#  Undera blue sky with white clouds,a child reaches up to touch the propeller ofa plane standing parked ona field of grass.
#
# A child is reaching to touch the propeller out of curiosity.
#
#  Undera blue sky with white clouds,a child reaches up to touch the propeller ofa plane standing parked ona field of grass.
#
# A child is playing witha ball.
#
# A woman is doinga cartwheel while wearinga bikini in the sand next to the beach.
#
# A woman is doinga cartwheel.
#
# A woman is doinga cartwheel while wearinga bikini in the sand next to the beach.
#
# A woman is fixing her home.
#
# A woman is doinga cartwheel while wearinga bikini in the sand next to the beach.
#
# A woman is doinga cartwheel and falls on her head.
#
#  Two men on bicycles competing ina race.
#
#  People are riding bikes.
#
#  Two men on bicycles competing ina race.
#
#  Men are riding bicycles on the street.
#
#  Two men on bicycles competing ina race.
#
# A few people are catching fish.
#
# A young boy ina field of flowers carryinga ball
#
#  boy leaving baseball game
#
# A young boy ina field of flowers carryinga ball
#
#  boy in field
#
# A young boy ina field of flowers carryinga ball
#
#  dog in pool
#
#  Families waiting in line at an amusement park for their turn to ride.
#
#  The restaurant is very bad.
#
#  Families waiting in line at an amusement park for their turn to ride.
#
#  People are waiting in line ata restaurant.
#
#  Families waiting in line at an amusement park for their turn to ride.
#
#  People are waiting to seea movie.
#
# faild parse
# A man is waiting in line for the bus.
#
# A man is looking to ordera grilled cheese sandwich.
#
#  Man ina black suit, white shirt and black bowtie playing an instrument with the rest of his symphony surrounding him.
#
# A person ina suit
#
#  Man ina black suit, white shirt and black bowtie playing an instrument with the rest of his symphony surrounding him.
#
#  Nobody hasa suit
#
#  Man ina black suit, white shirt and black bowtie playing an instrument with the rest of his symphony surrounding him.
#
# A tall person ina suit
#
#  Two women having drinks and smoking cigarettes at the bar.
#
#  Two women are ata bar.
#
#  Two women having drinks and smoking cigarettes at the bar.
#
#  Three women are ata bar.
#
#  Two women having drinks and smoking cigarettes at the bar.
#
#  Women are celebrating ata bar.
#
#  At an outdoor event in an Asian-themed area,a crowd congregates as one person ina yellow Chinese dragon costume confronts the camera.
#
# A single man is next toa camera
#
#  At an outdoor event in an Asian-themed area,a crowd congregates as one person ina yellow Chinese dragon costume confronts the camera.
#
# A crowd is dancing
#
#  At an outdoor event in an Asian-themed area,a crowd congregates as one person ina yellow Chinese dragon costume confronts the camera.
#
# A crowd is in front ofa camera
#
#  Two doctors perform surgery on patient.
#
#  Two surgeons are having lunch.
#
#  Two doctors perform surgery on patient.
#
#  Doctors are performing surgery.
#
#  Two doctors perform surgery on patient.
#
#  Two doctors are performing surgery ona man.
#
# A white dog with long hair jumps to catcha red and green toy.
#
# A white dog with long hair is swimming underwater.
#
# A white dog with long hair jumps to catcha red and green toy.
#
#  An animal is jumping to catch an object.
#
# A white dog with long hair jumps to catcha red and green toy.
#
# A white chihuahua mix with long curly hair is jumping to catcha red and green toy bone.
#
#  Kids are ona amusement ride.
#
#  Kids ride their favorite amusement ride.
#
#  Kids are ona amusement ride.
#
# A car is broke down on the side of the road.
#
#  Kids are ona amusement ride.
#
#  Kids ride an amusement ride.
#
# A man ina black shirt is playing golf outside.
#
# A man plays ona golf course to relax.
#
# A man ina black shirt is playing golf outside.
#
#  The man in the black shirt trades Pokemon cards with his girlfriend.
#
# A man ina black shirt is playing golf outside.
#
#  The man wearing the black shirt playsa game of golf.
#
# A older gentleman finds it humorous that he is getting his picture taken while doing his laundry.
#
# a blond man laughs while doing laundry
#
# A older gentleman finds it humorous that he is getting his picture taken while doing his laundry.
#
# a guy laughs while doing laundry
#
# A older gentleman finds it humorous that he is getting his picture taken while doing his laundry.
#
#  two ladies pin clothes to dry
#
#  An Indian woman is washing and cleaning dirty laundry ata lake and in the background isa kid who appears to have jumped into the lake.
#
#  An Indian woman is doing her laundry ina lake.
#
#  An Indian woman is washing and cleaning dirty laundry ata lake and in the background isa kid who appears to have jumped into the lake.
#
#  An Indian woman is putting her laundry into the machine.
#
#  An Indian woman is washing and cleaning dirty laundry ata lake and in the background isa kid who appears to have jumped into the lake.
#
#  An Indian woman is doing laundry for her son in the lake.
#
# A man ina green jersey and rollerskates stumbles asa man ina black jersey appears to collide with him.
#
#  They are driving cars.
#
# A man ina green jersey and rollerskates stumbles asa man ina black jersey appears to collide with him.
#
#  They both fall to the ground.
#
# A man ina green jersey and rollerskates stumbles asa man ina black jersey appears to collide with him.
#
#  The man stumbles stumbles in rollerskates.
#
# A group of onlookers glance ata person doinga strange trick on her head.
#
# A boy doesa card trick.
#
# A group of onlookers glance ata person doinga strange trick on her head.
#
#  Onlookers are impressed by the trick.
#
# A group of onlookers glance ata person doinga strange trick on her head.
#
#  People watch another person doa trick.
#
#  The middle eastern woman wearing the pink headscarf is walking besidea woman ina purple headscarf.
#
#  Two women are walking together.
#
#  The middle eastern woman wearing the pink headscarf is walking besidea woman ina purple headscarf.
#
#  Only one woman is wearinga head scarf.
#
#  The middle eastern woman wearing the pink headscarf is walking besidea woman ina purple headscarf.
#
#  These two women are friends.
#
# A taxi SUV drives past an urban construction site, asa man walks down the street in the other direction.
#
# A man is chasing an SUV that is going in the same direction as him.
#
# A taxi SUV drives past an urban construction site, asa man walks down the street in the other direction.
#
#  An SUV anda man are going in opposite directions.
#
# A taxi SUV drives past an urban construction site, asa man walks down the street in the other direction.
#
# faild parse
#  People wearing red shirts are standing ina large pool of water as it splashes over and around them.
#
#  Nobody hasa shirt on
#
#  People wearing red shirts are standing ina large pool of water as it splashes over and around them.
#
# A person ina shirt
#
#  People wearing red shirts are standing ina large pool of water as it splashes over and around them.
#
# A tall person ina shirt
#
# A man ina white t-shirt takesa picture in the middle of the street with two public buses in the background.
#
# A man is wearinga black shirt
#
# A man ina white t-shirt takesa picture in the middle of the street with two public buses in the background.
#
# A man is wearinga white shirt
#
# A man ina white t-shirt takesa picture in the middle of the street with two public buses in the background.
#
# A man is taking photos while on tour in nyc
#
# A shirtless man is singing intoa microphone whilea woman next to him plays an accordion.
#
#  He is Polish.
#
# A shirtless man is singing intoa microphone whilea woman next to him plays an accordion.
#
#  He is playinga saxophone.
#
# A shirtless man is singing intoa microphone whilea woman next to him plays an accordion.
#
# A man is singing intoa microphone.
#
#  Women and children sitting outside in the shade whilea group of younger children sitting inside in the shade.
#
#  It is very sunny outside.
#
#  Women and children sitting outside in the shade whilea group of younger children sitting inside in the shade.
#
#  The woman and kids and sitting down.
#
#  Women and children sitting outside in the shade whilea group of younger children sitting inside in the shade.
#
#  The woman is running.
#
# A pregnant lady singing on stage while holdinga flag behind her.
#
# A woman is sick in bed.
#
# A pregnant lady singing on stage while holdinga flag behind her.
#
# A woman is making music.
#
# A pregnant lady singing on stage while holdinga flag behind her.
#
# A lady is participating ina talent show.
#
#  The two farmers are working ona piece of John Deere equipment.
#
#  Men are working on John Deere equipment
#
#  The two farmers are working ona piece of John Deere equipment.
#
#  John Deere equipment is being worked on by two farmers
#
#  The two farmers are working ona piece of John Deere equipment.
#
# 2 Men are makinga pool together
#
# A little boy ina blue shirt holdinga toy.
#
#  Boy dressed in blue carrying toy toa toybox.
#
# A little boy ina blue shirt holdinga toy.
#
#  Boy dressed in red lighting things on fire.
#
# A little boy ina blue shirt holdinga toy.
#
#  Boy dressed in blue holdsa toy.
#
# A woman is writing something ona post-it note which is hanging ona bulletin board witha lot of other post-it notes.
#
#  The woman is writinga grocery list.
#
# A woman is writing something ona post-it note which is hanging ona bulletin board witha lot of other post-it notes.
#
#  The woman is talking on the phone.
#
# A woman is writing something ona post-it note which is hanging ona bulletin board witha lot of other post-it notes.
#
#  The woman is writinga note.
#
# A baby at the end ofa slip and slide ata party
#
#  The baby is wet.
#
# A baby at the end ofa slip and slide ata party
#
#  The man is at the end of the slip and slide
#
# A baby at the end ofa slip and slide ata party
#
#  There isa party
#
# A girl swings high in the air.
#
# A girl is gaining momentum to flip off the swing
#
# A girl swings high in the air.
#
# A girl is laying in the pool
#
# 0
