# %%
# coding: utf-8
#ifrom __future__ import print_function

from keras.models import Model
from keras.models import load_model
from keras.layers import Input, LSTM,Embedding, Dense
import keras

#from sklearn.model_selection import train_test_split

import numpy as np
import json
import re
#import pydot

import nltk
from nltk.tree import Tree
from nltk.translate.bleu_score import sentence_bleu

####

import logging

from nltk.sem.logic import LogicParser
from nltk.sem.logic import LogicalExpressionException
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
#bleu evaluation
len_inp = 1500#len(test_input_data)
sum_score = 0
complete = 0
comp_texts = []
for seq_index in range(len_inp-1):
    fname = 'char/c2l/result'+str(seq_index)+'.txt'
    f = open(fname)
    lines = f.readlines()
    f.close()

    orign_text = lines[0].rstrip()
    if(orign_text[-1]!='.'):
        orign_text = orign_text + '.'
    decoded_sentence = lines[1].rstrip()
    score = sentence_bleu([orign_text],decoded_sentence)
    sum_score += score
    
    if(orign_text == decoded_sentence):
        complete += 1
        comp_texts.append(orign_text)
    
    print(orign_text)
    print(decoded_sentence)
    print(score,"\n")
    
    #f.write(output_texts[seq_index])
    #f.write(decoded_sentence.strip()+'\n')
    #f.close()
    #print('Input sentence:', input_texts[seq_index])
    #if (seq_index%100) == 0 :
    #    print('Decoded sentence:', decoded_sentence)
    #    print('Answer sentence:', output_texts[seq_index])
print('bleu score: ',(sum_score/len_inp))
print('complete: ',complete)
print(comp_texts)
# Out:
# Two women are embracing while holding to go packages.
# Two women are wearing a black shirt and wearing black.
# 0.41874849645289924
#
# The sisters are hugging goodbye while holding to go packages after just eating lunch.
# A person is congurting a concert to her husband in the snow.
# 0.1735098813625114
#
# Two woman are holding packages.
# Two women are watching the paper.
# 0.4401633695329419
#
# The men are fighting outside a deli.
# A man is standing in the rain.
# 0.13621924714543918
#
# Two young children in blue jerseys, one with the number 9 and one with the number 2 are standing on wooden steps in a bathroom and washing their hands in a sink.
# A young girl in a blue shirt and a black tan dog recled shirt walks down the street with a woman in a blue shirt, while a group of people walking down a street with a white tree pass by the street with a boy wearing his hands on the floor with a ball in the water with a
# 0.2958101910185145
#
# Two kids in numbered jerseys wash their hands.
# Two tentlasts are dancing on the street in front of a building.
# 0.15580315880549894
#
# Two kids at a ballgame wash their hands.
# Two kids in white and white shirt
# 0.303399091878655
#
# Two kids in jackets walk to school.
# Two girls in striped shirt and red striped shirt.
# 0.15263496054469328
#
# A man selling donuts to a customer during a world exhibition event held in the city of Angeles.
# A man sitting on the beach with a woman in a crowd of people walking down a street.
# 0.34790191433508133
#
# A woman drinks her coffee in a small cafe.
# A child wearing a red shirt playing on the sand.
# 0.301541846704942
#
# A man selling donuts to a customer during a world exhibition event while people wait in line behind him.
# A man sitting on the beach with a woman in a crowd of people walking down a street with a ball.
# 0.38022890618531
#
# A man selling donuts to a customer.
# A man playing with her dogs on the street.
# 0.2614084216938996
#
# Two young boys of opposing teams play football, while wearing full protection uniforms and helmets.
# A young woman in a blue shirt and blue shirt and blue jeans is standing in front of a building.
# 0.22430900211276522
#
# boys play football.
# The boy is wearing a blue shirt.
# 0.20040201207853411
#
# dog eats out of bowl.
# A dog sleeps on a cliff.
# 0.169398499987232
#
# boys scoring a touchdown.
# A boy wearing a black shirt
# 0.30096870722978436
#
# A man in a blue shirt standing in front of a garage-like structure painted with geometric designs.
# A man in a blue shirt and a black shirt and blue jeans is walking through a pool with his daughter.
# 0.39322051894479876
#
# A man is repainting a garage.
# A man is wearing a blue shirt.
# 0.46920486289166446
#
# A man is wearing a blue shirt.
# A man is wearing a blue shirt.
# 1.0
#
# A man is wearing a black shirt.
# A man is wearing a blue shirt.
# 0.8456771197939585
#
# Under a blue sky with white clouds, a child reaches up to touch the propeller of a plane standing parked on a field of grass.
# A child is playing with a box on the sidewalk with the ball to a woman in a blue shirt.
# 0.3046047854682374
#
# A child is reaching to touch the propeller of a plane.
# A child is walking towards the mach to a car.
# 0.45114404233403393
#
# A child is reaching to touch the propeller out of curiosity.
# A child is playing with a box on the street with the ball.
# 0.3627999292233507
#
# A child is playing with a ball.
# A child is walking towards the ground.
# 0.38273892989940506
#
# A woman is doing a cartwheel while wearing a bikini in the sand next to the beach.
# A woman is holding a baby with a boy with a bowl of water with a ball.
# 0.27400371837791854
#
# A woman is doing a cartwheel.
# A woman is wearing a blue shirt.
# 0.5202137721228448
#
# A woman is fixing her home.
# A woman is wearing a blue shirt.
# 0.4255911375936231
#
# A woman is doing a cartwheel and falls on her head.
# A woman is sitting on the ground walking on the street with the dog.
# 0.29961247186719675
#
# Two men on bicycles competing in a race.
# Two men in shorts walking on the street.
# 0.39209271064912804
#
# People are riding bikes.
# People are watching the ball.
# 0.45738892911373086
#
# Men are riding bicycles on the street.
# A man is standing on the sidewalk.
# 0.3749005392833194
#
# A few people are catching fish.
# People are watching the ball.
# 0.5356296951673281
#
# A young boy in a field of flowers carrying a ball.
# A young girl with blond-hair is standing on the sidewalk.
# 0.2391462668825332
#
# boy leaving baseball game.
# The boy is wearing a blue shirt.
# 0.19114167548796013
#
# boy in field.
# A boy in a bikini
# 0.360056585428503
#
# dog in pool.
# A dog running in the street.
# 0.195647514979229
#
# Families waiting in line at an amusement park for their turn to ride.
# A family standing on a train at the beach while the other people are waiting.
# 0.29750922405619434
#
# The restaurant is very bad.
# The street vendor is on the beach.
# 0.22068603375419538
#
# People are waiting in line at a restaurant.
# People sit in a car and steps.
# 0.25996069706423036
#
# People are waiting to see a movie.
# People are walking down a stage.
# 0.5068768379275972
#
# A person waits to be served his food.
# A person is leaning on his cellphone together.
# 0.3271827080465137
#
# A man is waiting in line for the bus.
# A man is standing in the road wearing a black contor.
# 0.3720391790025799
#
# A man is looking to order a grilled cheese sandwich.
# A man is standing on the sidewalk with the ball.
# 0.31562684619784487
#
# Man in a black suit, white shirt and black bowtie playing an instrument with the rest of his symphony surrounding him.
# A man in a blue shirt and another with a black shirt and blue shirt and red shirt and blue shirts.
# 0.36776536864491177
#
# A person in a suit.
# A person in a crowd
# 0.7128736748247595
#
# Nobody has a suit.
# Nobody has a basketball.
# 0.5364487221855199
#
# A tall person in a suit.
# A tall person in shorts
# 0.7196529892507432
#
# Two women having drinks and smoking cigarettes at the bar.
# Two women walking on a beach with a boat.
# 0.2662601764212851
#
# Two women are at a bar.
# Two women are watching television.
# 0.41578372496714516
#
# Three women are at a bar.
# The two women are walking outside.
# 0.3624091673774342
#
# Women are celebrating at a bar.
# A woman is sitting on the grass.
# 0.17787737198601233
#
# At an outdoor event in an Asian-themed area, a crowd congregates as one person in a yellow Chinese dragon costume confronts the camera.
# A couple is wearing a black shirt and stands in the street with a boy wearing black suits.
# 0.12448051392971815
#
# A single man is next to a camera.
# The old man is sitting on a bench.
# 0.3482990918507536
#
# A crowd is dancing.
# The couple are standing.
# 0.15306882399696514
#
# A crowd is in front of a camera.
# The couple are on a busy city.
# 0.25429664109729583
#
# Two doctors perform surgery on patient.
# Two children are walking together on a beach.
# 0.15529951508970113
#
# Two surgeons are having lunch.
# Two children are playing basketball.
# 0.2631191750351757
#
# Doctors are performing surgery.
# A doctor is performing around.
# 0.5396889433478473
#
# Two doctors are performing surgery on a man.
# Two children are walking together on a beach.
# 0.3310819443085382
#
# A white dog with long hair jumps to catch a red and green toy.
# A tall person in a blue shirt with her cat and staring at the camera.
# 0.25608607945750234
#
# A white dog with long hair is swimming underwater.
# A small child is eating a cafe in front of a building.
# 0.15105790133168984
#
# An animal is jumping to catch an object.
# The boys are watching television.
# 0.19692233880789708
#
# A white chihuahua mix with long curly hair is jumping to catch a red and green toy bone.
# A small group of people walking down a street with a woman in a blue shirt.
# 0.19166722076915035
#
# Kids are on a amusement ride.
# A kid is in a bathroom.
# 0.1295591427798445
#
# Kids ride their favorite amusement ride.
# The kid is playing with her hair.
# 0.5168197664717988
#
# Kids ride an amusement ride.
# The kid is playing with her day.
# 0.483026015152751
#
# A man in a black shirt is playing golf outside.
# A man in a blue shirt is standing on the street.
# 0.5195247201953358
#
# A man plays on a golf course to relax.
# A man is standing in the road wearing a black shirt.
# 0.1702602472176709
#
# The man in the black shirt trades Pokemon cards with his girlfriend.
# A man in a blue shirt and blue shirt and red shirt and blue shirt.
# 0.27671169359613795
#
# The man wearing the black shirt plays a game of golf.
# A man in a blue shirt and jeans is near a bus.
# 0.27535420240372155
#
# A older gentleman finds it humorous that he is getting his picture taken while doing his laundry.
# An older man wearing a blue shirt is standing next to a boy on the sidewalk.
# 0.23378015614137712
#
# a guy laughs while doing laundry.
# A guy is wearing a blue shirt.
# 0.26380279814210006
#
# two ladies pin clothes to dry.
# Two women are walking down a street.
# 0.22250253290431032
#
# An Indian woman is washing and cleaning dirty laundry at a lake and in the background is a kid who appears to have jumped into the lake.
# A blond woman wearing a blue shirt and blue shirt and blue shirt is standing on the sidewalk.
# 0.2624869749846381
#
# An Indian woman is doing her laundry in a lake.
# A white dog is taking pictures of a baseball game.
# 0.17853792370223795
#
# An Indian woman is putting her laundry into the machine.
# A blond woman is congurting a conversation.
# 0.2690047162751575
#
# An Indian woman is doing laundry for her son in the lake.
# An Asian man is congrating for a picture while standing in the street.
# 0.3630278629930645
#
# A man in a green jersey and rollerskates stumbles as a man in a black jersey appears to collide with him.
# A man wearing a blue shirt and blue shirt is standing on the sidewalk with the ball to a woman in a blue shirt.
# 0.3421845085022934
#
# They are driving cars.
# They are playing a game.
# 0.44932528670420063
#
# They both fall to the ground.
# The child is walking towards the ball.
# 0.20346348329886924
#
# The man stumbles stumbles in rollerskates.
# A man is wearing a blue shirt is standing behind him.
# 0.16842373878804118
#
# A group of onlookers glance at a person doing a strange trick on her head.
# A group of people wearing black dresses and pants is walking through a pool.
# 0.3135457170725125
#
# A boy does a card trick.
# The boy is wearing a blue shirt.
# 0.19406071325325308
#
# Onlookers are impressed by the trick.
# A tennis players in a cafe.
# 0.10798868095712362
#
# People watch another person do a trick.
# People are playing a game of cass.
# 0.23390787567967444
#
# The middle eastern woman wearing the pink headscarf is walking beside a woman in a purple headscarf.
# An older man wearing a blue shirt is standing on the sidewalk with the ball to a woman.
# 0.3821741464369769
#
# Two women are walking together.
# Two women are walking.
# 0.639142030693106
#
# Only one woman is wearing a head scarf.
# The woman and women are walking in the street.
# 0.28795734142758295
#
# These two women are friends.
# The two women are walking.
# 0.6145473219150656
#
# A taxi SUV drives past an urban construction site, as a man walks down the street in the other direction.
# Two children are sleeping on a couch with a little boy while shirt in a store with a boy in the background.
# 0.2012539004786283
#
# A man is chasing an SUV that is going in the same direction as him.
# A man is wearing a blue shirt is standing on the sidewalk.
# 0.39978042733814245
#
# An SUV and a man are going in opposite directions.
# A child is playing with a box on the street with a ball of people.
# 0.10036327540648152
#
# People wearing red shirts are standing in a large pool of water as it splashes over and around them.
# A dog climber in a blue jean hair shorts is standing in front of a large crowd of people on the sidewalk.
# 0.426321045429913
#
# Nobody has a shirt on.
# Nobody has a picture.
# 0.5994544305714528
#
# A person in a shirt.
# A person in a crowd
# 0.6880908437029064
#
# A tall person in a shirt.
# A tall person in shorts
# 0.7382280437851888
#
# A man in a white t-shirt takes a picture in the middle of the street with two public buses in the background.
# A man in a blue shirt and blue jeans is walking through a street carroon at the beach while the other people are waiting.
# 0.3983721453050341
#
# A man is wearing a white shirt.
# A man is wearing a blue shirt.
# 0.8115699931635378
#
# A man is taking photos while on tour in nyc.
# A man is standing in the road wearing a white jacket.
# 0.33938740234995907
#
# A shirtless man is singing into a microphone while a woman next to him plays an accordion.
# A shirtless man is walking in the street with a woman in a crowded area.
# 0.4222108781204198
#
# He is Polish.
# They are outside.
# 0.41412387656655203
#
# He is playing a saxophone.
# They are playing a game.
# 0.4507172665700191
#
# A man is singing into a microphone.
# A man is standing in the rain.
# 0.4413329890942321
#
# Women and children sitting outside in the shade while a group of younger children sitting inside in the shade.
# A woman walks to her son an empty road with the streets are while the other people are waiting.
# 0.2697481940655308
#
# It is very sunny outside.
# They are going outside.
# 0.37652017880472516
#
# The woman and kids and sitting down.
# A woman stands on a beach.
# 0.26664842850684417
#
# The woman is running.
# A woman is sitting.
# 0.5549270001127401
#
# A pregnant lady singing on stage while holding a flag behind her.
# A large group of people standing in front of an empty crowd.
# 0.20971025669098745
#
# A woman is sick in bed.
# A woman is sitting on the grass.
# 0.4291023068026641
#
# A woman is making music.
# A woman is holding a baby.
# 0.49692833205572384
#
# A lady is participating in a talent show.
# A lady is looking at the camera.
# 0.3407524177812351
#
# The two farmers are working on a piece of John Deere equipment.
# Two boys in the street are wearing a white shirt.
# 0.2097925480336738
#
# Men are working on John Deere equipment.
# A man is standing in the road wearing a black contor.
# 0.0997579374955373
#
# John Deere equipment is being worked on by two farmers.
# A toplettoo blown dogs are running through water.
# 0.11404850823597569
#
# 2 Men are making a pool together.
# Two men are playing basketball.
# 0.31180943299936736
#
# A little boy in a blue shirt holding a toy.
# A little girl in a pink shirt and stands in the street.
# 0.38118942250824384
#
# Boy dressed in blue carrying toy to a toybox.
# A boy is playing with her hands on the sidewalk.
# 0.16015036862961354
#
# Boy dressed in red lighting things on fire.
# A boy is playing with her hands on the sidewalk.
# 0.20542403711160412
#
# Boy dressed in blue holds a toy.
# A boy is playing with her hands on the beach.
# 0.28350274018970023
#
# A woman is writing something on a post-it note which is hanging on a bulletin board with a lot of other post-it notes.
# A woman is holding a baby with a boy with a book of water in the water near a parking lot of people.
# 0.3801328892394888
#
# The woman is writing a grocery list.
# A woman is wearing a blue shirt.
# 0.4744026453320173
#
# The woman is talking on the phone.
# A woman is sitting on the street.
# 0.5749251298563759
#
# The woman is writing a note.
# A woman is wearing a blue shirt.
# 0.5099074050019046
#
# A baby at the end of a slip and slide at a party.
# A baby wearing a blue shirt with his hands in the snow.
# 0.27138561691496704
#
# The baby is wet.
# The baby is sleeping
# 0.5767908748024404
#
# The man is at the end of the slip and slide.
# A man is in a baseball car in his bed.
# 0.2137915473279982
#
# There is a party.
# There is a person.
# 0.659109604993135
#
# A girl swings high in the air.
# The girl is standing on the street.
# 0.3526722960272411
#
# A girl is gaining momentum to flip off the swing.
# A girl is taking a picture of a bench over him.
# 0.3276915503970715
#
# A girl is laying in the pool.
# The girl is standing on the street.
# 0.43683636444615426
#
# A girl is on a swing.
# The girl is in the air.
# 0.4249456196134439
#
# A view of the back of a woman having a beverage.
# A child wearing a red shirt playing a game.
# 0.17720398385345842
#
# woman drinks a beer.
# A man and woman dressed.
# 0.3502979072560522
#
# woman dumps the drink on a man.
# A woman is holding a baby with a book.
# 0.2077492757912418
#
# woman has a drink.
# A woman is wearing a blue shirt.
# 0.24034793256416837
#
# A lady sitting on a bench that is against a building and under a poster of a man in a uniform waving.
# A lady wearing a blue shirt with a conversation is looking at the camera in front of a building.
# 0.4291343450884396
#
# A person sitting.
# A person smiling
# 0.6449131835432435
#
# A tall person sitting.
# A tall human standing
# 0.3875448571474537
#
# Nobody is sitting.
# Nobody is singing
# 0.7189085812023328
#
# A man with a shopping cart is studying the shelves in a supermarket aisle.
# A man in a blue shirt is sitting on a bench in front of a building.
# 0.3359021578469794
#
# The man is trying to pick out what cereal to choose.
# A man is walking down the street with a boy.
# 0.2793191007299837
#
# A man is watching a movie in a theater.
# A man is standing on the sidewalk.
# 0.3767739529210461
#
# There is a man inside a supermarket.
# There is a man with a bathtub.
# 0.4533359043554146
#
# A man wearing sunglasses is sitting on the steps outside, reading a magazine.
# A man in a blue shirt and jeans is near a busy street.
# 0.1941812515784131
#
# The man is sitting.
# A man is standing.
# 0.5703017172567459
#
# The man is reading tips on how to be a better boy friend.
# The man is a child are watching ten in the water.
# 0.3409427492295908
#
# The man is reading a spoon with the words `` HELP ME '' on it.
# A man is standing in the road wearing a white jacket.
# 0.3360567973733421
#
# A woman sitting outside weaving a long piece of red, white, and blue cloth.
# A woman standing on the sidewalk with a boat with a boy with her cellphone.
# 0.30459627874928386
#
# He is jumping over a house.
# He is riding a bike.
# 0.31461626389034086
#
# She is working with cloth.
# They are going on a path.
# 0.1724369836513602
#
# She is weaving an american flag.
# They are playing a game of bus.
# 0.21512219070265007
#
# A person powerwashing stairs leading down to a pool.
# A person doing a trick on a sidewalk near a building.
# 0.3437014858178136
#
# a person washes stairs.
# The person is wearing a blue shirt.
# 0.28593485712827327
#
# a worker cleans near the pool.
# A cowboy clown is watching the paper.
# 0.21599414421199176
#
# a dog chases a cat.
# The dog is catching a beach.
# 0.287686670403962
#
# A person rides his bicycle in the sand beside the ocean.
# A person is conducting a conventing tore with the ball.
# 0.3064309554926383
#
# A person is falling off his bike.
# A person is riding a bike.
# 0.5477955480116765
#
# A person is on a boat.
# The person is in the air.
# 0.46899177269829906
#
# A person is on a beach.
# The person is in the air.
# 0.4757415904104826
#
# Two black little boys hanging over an upside down bicycle, one examining the pedal.
# A black dog running on the sidewalk with the ball to a woman with a bowl of water with a ball.
# 0.2862521666727227
#
# Children were looking at a bike.
# A child is looking at the camera.
# 0.46541609816330265
#
# the children are outside.
# The children are outside.
# 0.9573479717381596
#
# Someone is riding a bike.
# Someone is playing with her day.
# 0.4255911375936231
#
# A brown a dog and a black dog in the edge of the ocean with a wave under them boats are on the water in the background.
# Two boys in white rest up on a stage while a man in a white t-shirt and blue shirt, white and blue shirt.
# 0.2273964711598718
#
# The dogs are out to catch fish.
# The dog is climbing a concert.
# 0.27341704031445485
#
# The pets are sleeping on the grass.
# People are standing on a beach.
# 0.3493053137572869
#
# The dogs are swimming among the boats.
# A dog is sleeping on a bench.
# 0.1848699344522547
#
# A group of people prepare hot air balloons for takeoff.
# A group of people are watching a man with a ball in the water.
# 0.4165153914692078
#
# A group of people are outside.
# A group of people are walking.
# 0.7345870556080605
#
# A group of people prepare cars for racing.
# A group of people are standing on a beach with his dog.
# 0.4215161430342694
#
# There are hot air balloons on the ground and air.
# There is a dog on the street after and skirt.
# 0.38823072693178134
#
# Men stand on steps leading out of a body of water.
# A man is standing on the sidewalk with a boat with a boy.
# 0.3243692997058749
#
# Men are standing on some steps near some water.
# A man is standing in the road wearing a black shirt.
# 0.2795666572712775
#
# Men are sitting outside near a golf course.
# A man is standing in the road wearing a black contor.
# 0.1314770573188977
#
# Men are standing by a docked boat.
# A man is walking down the street.
# 0.22576206373887323
#
# A group of young people with instruments are on stage.
# A group of people stand on stage while others watch.
# 0.5338707385651228
#
# People are performing as a band for a crowd.
# People are standing on a beach with his dogs.
# 0.398790133042794
#
# Young people are playing water polo.
# A young man is sitting on the beach.
# 0.20298407172594946
#
# People are playing music.
# People are watching the ball.
# 0.45510305582622584
#
# A long-beaked bird in mid-flight.
# A brown dog walks through the wall.
# 0.5091969063347359
#
# A bird flying.
# A brown dog running.
# 0.18951629567590741
#
# A rat running on a wheel.
# A police officer running through water.
# 0.27682256344108913
#
# A bird chasing an insect.
# A baby wearing yellow.
# 0.1592869824391964
#
# A young boy with black hair is holding onto a gun which is secured to a vehicle which is being driven by a young man who is wearing a bright pink shirt.
# A young man wearing a blue shirt and blue shirt and blue shirt and blue shirt, while a group of people walking down the street with a boy.
# 0.3749427889329883
#
# The boy is outside and running from cops.
# A boy wearing a blue shirt is standing behind them.
# 0.23726830697320317
#
# The young boy is completing a heist.
# A young man is sitting outside.
# 0.3509586226359661
#
# The bank has just been robbed.
# The baby is playing.
# 0.181675124071465
#
# A man in the middle east with a corn-on-the-cob cart selling corn.
# A man in a blue shirt and another woman walks through a pool.
# 0.2636523462674825
#
# An old middle eastern man is selling corn-on-the-cob from his brother 's cart.
# An old man wearing a blue shirt is standing on the sidewalk with a boy on the street.
# 0.28429411746633587
#
# In the middle east, a man sells corn-on-the-cob from a cart.
# A man is standing on the sidewalk with the ball to a woman.
# 0.2442162036619489
#
# A middle east man is throwing corn at strangers.
# An older man is walking through a street carroon.
# 0.3818486033683033
#
# A man in a black shirt is playing a guitar.
# A man in a blue shirt is standing on the street.
# 0.5083456094153593
#
# He is playing a song.
# They are playing a game.
# 0.464578221240361
#
# The man is wearing a blue shirt.
# A man is wearing a blue shirt.
# 0.9026306113066667
#
# The man is wearing black.
# A man is sitting down.
# 0.38593480840054595
#
# Colorfully dressed people walk down the center of the road, with onlookers behind a barricade.
# A child in a blue shirt and blue shirt and blue jeans is standing in front of a building.
# 0.11542013660882079
#
# A group of people in a motorcade driving past an audience.
# A group of people walking down a street carrying offed.
# 0.4554083502422704
#
# A group of people walking down a road.
# A group of people walking down the street.
# 0.7451601370072265
#
# A group of people walking past a group of civilian spectators.
# A group of people walking down a street in the air.
# 0.4874103867273424
#
# A woman is talking on the phone while standing next to a dog.
# A woman is standing on the sidewalk with the ball.
# 0.4974023212031755
#
# A woman is sleeping.
# A woman is sitting.
# 0.6955862031711643
#
# A woman is walking her dog.
# A woman is wearing a blue shirt.
# 0.45999334469787295
#
# A woman is on the phone.
# A woman is in the air.
# 0.6252982897216868
#
# Three young boys one is holding a camera and another is holding a green toy all are wearing t-shirt and smiling.
# A woman is holding a baby with a boy with a book of water in the water near a parking lot of people.
# 0.29602689664656306
#
# The boys are all wearing yellow.
# The boy is holding his back.
# 0.2956681571641412
#
# The boy is crouching down to take a picture.
# A boy is playing with her hands.
# 0.25181314664834265
#
# The young boy has a camera.
# A young man is sitting outside.
# 0.23337388721354077
#
# 5 women sitting around a table doing some crafts.
# A man sitting down to the side of the water.
# 0.28996831357250985
#
# Five men stand on chairs.
# A band person in a hole.
# 0.18820540136657773
#
# Five women sit at a table.
# A family stands on the sidewalk.
# 0.25508469658542515
#
# Five friends sit at a table.
# A female and woman is in the park.
# 0.6016322655879698
#
# Street performer with bowler hat and high boots performs outside.
# A street vendor is standing in front of a large crowd.
# 0.1514934150556602
#
# The man is performing a magic act.
# A man is wearing a blue shirt.
# 0.3934967258943436
#
# The person is performing.
# The person is being climb.
# 0.5880323438417842
#
# The child is dancing inside.
# The children are playing.
# 0.3642819527668392
#
# A young boy playing in the grass.
# A young girl putting on a stage.
# 0.3656000289938815
#
# The boy is playing make believe.
# A boy in a blue shirt.
# 0.1999276949290299
#
# There is a child in the grass.
# The cheerleaders stands on the street.
# 0.23971764365258025
#
# The boy is in the sand.
# The boy is in front of the street.
# 0.5251807780739226
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Two men playing baseball with the one in the black and red jersey running toward base.
# Two men sitting on a beach with a woman in a purple shirt and blue shirt.
# 0.3123440515039422
#
# The man in black and red is about to score the winning run.
# A man in a blue shirt is standing on the sidewalk with their arms in the background.
# 0.2917844402972348
#
# There is a baseball game going on.
# There is a base of a train.
# 0.48801720129428794
#
# The man in black and red is sitting in the bleachers.
# A man in a blue shirt is standing on the street.
# 0.41204978560079714
#
# A man and a woman are looking at produce on display.
# A man is standing on the sidewalk with a boat with a cat on the sidewalk.
# 0.21590249462364078
#
# A man and women are staring at heads of lettuce.
# A man and a woman are standing on the sidewalk.
# 0.5021679853401341
#
# Two men throw produce at each other for fun.
# Two men are sitting on a bench with a boat of people.
# 0.2376058648441647
#
# A man and woman are looking at produce.
# A man and woman are walking on the street.
# 0.5794476842125932
#
# People are throwing tomatoes at each other.
# People are standing on a beach with his dogs.
# 0.420502518576466
#
# The people are sitting and eating their food.
# People are playing a game of bus.
# 0.31634436861250015
#
# The men are covered in tomatoes.
# A man is standing in the rain.
# 0.1997828925956146
#
# The people are having a food fight.
# People are watching a boat.
# 0.40697807461930235
#
# People standing in line of a beer and curry line.
# People standing in a large park of a tree.
# 0.5265462291579779
#
# People standing in line.
# People walking towards the painted.
# 0.2765471039836258
#
# People happily standing in line.
# People walking towards the ball
# 0.2996843505577541
#
# People not standing in line.
# People walking towards the ball
# 0.3059304585676471
#
# A man and a woman are talking in a park.
# A man and a woman are standing on the sidewalk.
# 0.5836670503066977
#
# A man and woman are talking in the aquarium.
# A man and woman are walking on the street.
# 0.68120772511364
#
# The couple discuss their financial future in the park.
# A couple is waiting for his car to work on a rock.
# 0.2336366169713267
#
# A pair of people are talking outdoors.
# A pair of people are walking on the sidewalk.
# 0.6208536231748663
#
# A small ice cream stand with two people standing near it.
# A small child in a purple shirt and blue shirt.
# 0.2911778548851426
#
# Two people selling ice cream from a car.
# Two people are sitting on a bench with his daughter.
# 0.32764727316826103
#
# Two people standing outside an ice cream stand.
# Two people standing in front of an empty car engerine.
# 0.4666753242533752
#
# Two people in line to buy icecream.
# Two people in blue baseball cap.
# 0.44105857411876775
#
# Number 916 is hoping that he is going to win the race.
# Three boys in sunglasses is standing on a beach.
# 0.15768397803664955
#
# A person is is playing baseball.
# A person in a blue jacket is running.
# 0.37599623542143973
#
# A person is betting that he will win the race.
# A person is riding a bike in a large park.
# 0.38139940920126736
#
# A person is competing in a race.
# A person is looking at the camera.
# 0.4759605058537325
#
# Girl plays with colorful letters on the floor.
# A girl is sitting on the ground walking on the street.
# 0.24038535338362632
#
# The girl is playing a video game in the bath.
# A girl is standing on the sidewalk with their backs.
# 0.37024910294005836
#
# The girl is spelling out her favorite words with colored letters.
# A girl is standing on the sidewalk with the ball to a building.
# 0.3362724384686378
#
# The girl is having fun learning her letters.
# The girl is wearing a blue shirt with his bike.
# 0.3666357918437556
#
# Two men are cooking food together on the corner of the street.
# Two men are sitting on a bench with a boat.
# 0.285665330456357
#
# The men are making something to eat.
# A man is wearing a blue shirt.
# 0.15559751744557948
#
# The two men are cooking food for the block party.
# Two men are watching the water with her son.
# 0.37034531065733567
#
# The two men are running in a race.
# Two men are sitting on the beach.
# 0.46646369770358076
#
# A man wandering in the desert as the clouds roll in.
# A man standing on the sidewalk with the ball.
# 0.36090100677310744
#
# A man fights dead mummy 's who magically came alive in the desert.
# A man is wearing a blue shirt is standing on the sidewalk.
# 0.23432123601599836
#
# A man wonders in the desert.
# A man is standing in the rain.
# 0.4348596052870303
#
# A man and a camel wonder in the desert.
# A man and women are walking outside.
# 0.35722810851910414
#
# A lady with bright orange hair walking in a crowd.
# A well dressed woman wearing a blue shirt is standing behind him.
# 0.11082288083126803
#
# The woman is asleep.
# A woman is sitting.
# 0.47906736710514164
#
# A woman is near a group of people.
# A woman is on the beach with a boy.
# 0.3783848545653754
#
# The street performer is entertaining the tourists.
# The truck is cherry ride in the snow.
# 0.24953138978184455
#
# A white-haired man with a mustache and glasses in a business suit stands outside at a podium marked with the seal of the US House of Representatives, surrounded by many people, with a columned building behind him.
# A blond woman wearing a blue shirt and blue shirt and blue shirt and blue shirt, while a group of people walking down a street with a blue balloon trailing in the background watch to her hand with a bowl of water.
# 0.35284581194199716
#
# There are people outside.
# There are people outside.
# 1.0
#
# The man is getting ready to speak.
# A man is looking at the camera.
# 0.35443045927736694
#
# The man is sitting in a chair inside.
# A man is standing in the rain.
# 0.44488506963409763
#
# A man running a marathon talks to his friend.
# A man wearing a blue shirt is standing behind them.
# 0.2839477063265359
#
# There are people canoeing down a river.
# There are people in the street.
# 0.4594859247429188
#
# There is a man running.
# There is a man outside.
# 0.6558149806895979
#
# A man and his friend are running a marathon together.
# A man is wearing a blue shirt is standing on the street.
# 0.32266554016501237
#
# A lot of people walking outside a row of shops with an older man with his hands in his pocket is closer to the camera.
# A dog with the ball is wearing a blue shirt and another man in blue and red shirt and blue shirts.
# 0.2729552066331744
#
# A lot of dogs barking outside a row of shops with a cat teasing them.
# People walking down a street with a little girl with blond-hair.
# 0.25673480162244805
#
# A lot of people walking outside a row of shops with a man with hands in his pockets.
# People walking down a stage while a man in a white t-shirt and blue shirt and stands in the street.
# 0.35839567742396566
#
# People are looking through the shops for stuff to buy.
# People are watching the ball to a woman in a blue shirt.
# 0.40727571852309247
#
# A barefooted adolescent boy in a yellow shirt reaching the top of a small skateboarding ramp.
# A bunch of people walking down a street with a woman in a crowded park.
# 0.20441368421639608
#
# the boy is flying a helicopter.
# The boy is wearing a black coat.
# 0.4679962294723193
#
# the boy is five.
# The boys are friends.
# 0.2952818889864951
#
# a boy is barefooted.
# The boy is sleeping.
# 0.3754280685962881
#
# A man waterskies with a life jacket.
# A man is standing in the road
# 0.19380746034674162
#
# Hitler rides a jetski in this Kawasaki advertisement.
# A horse is trying to streat to work on some people.
# 0.2154578973107421
#
# A lifeguard races across the water.
# A female dancer with two his kearsed.
# 0.6771165854343336
#
# The man is enjoying the ocean.
# A man is wearing a blue shirt.
# 0.35915652346944754
#
# A group of children enjoy their time on the beach.
# A group of people are watching a man with their car.
# 0.4063329113334116
#
# A group of adults are swimming at the beach.
# A group of people are standing outside a building.
# 0.400749626953802
#
# Children are swimming at the beach.
# A child is looking at the street.
# 0.4266592352455754
#
# Children are at the beach.
# The children are at a party.
# 0.5979796889571918
#
# A group of people sit on benches at a park outside a building.
# A group of people are standing on a beach with a boy on the street.
# 0.47577137899012406
#
# The people sit together.
# People are sitting.
# 0.36489144317533406
#
# The people wait for the bus to come.
# People are standing on a beach.
# 0.18928589382512512
#
# A women sits on a bench by herself.
# A woman is standing on the sidewalk.
# 0.248603700820539
#
# A small baby, possibly a newborn is being bathed by a person in blue scrubs wearing protective gloves.
# A pair of people walking down a street with a woman in a crowded park.
# 0.13489657701293134
#
# Someone is helping bathe the small baby.
# Someone is holding his back of water.
# 0.4098847057936353
#
# The person bathing the small baby is the mother.
# The person wearing a white hat is smiling.
# 0.38350615501937463
#
# The small baby is in it 's crib sound asleep.
# A small child is eating a cafe in the water.
# 0.31165179239353874
#
# An asian woman sitting outside an outdoor market stall.
# Asian woman playing with a box on the street.
# 0.31340475017542097
#
# A woman sits outdoors.
# A woman is wearing a blue shirt.
# 0.26598871140611724
#
# A woman is selling stuff in a flea market.
# A woman is standing on the sidewalk street.
# 0.4149143884649672
#
# A woman sitting in an indoor market.
# A woman standing on the sidewalk.
# 0.37637453553725675
#
# An older gentleman enjoys a scenic stroll through the countryside.
# An older man is sitting on the ground walking on the sidewalk.
# 0.33752193014352433
#
# A pirate boards the spaceship.
# A duner wearing oranges.
# 0.4544505188404086
#
# An old man searches for a good place to die.
# An old man riding a bike in a large building.
# 0.3219119301263731
#
# A man walks the countryside.
# A man is wearing a blue shirt.
# 0.23804727615014665
#
# A middle-aged man is sitting indian style outside holding a folded paper in his hands.
# A middle-aged woman wearing a blue shirt is standing next to the beach while the other people are walking.
# 0.34880083814010154
#
# A middle aged man is outdoors.
# The older man is a man wearing a blue shirt.
# 0.22204588318592486
#
# A middle aged man is showing off his origami creation.
# A shirtless man is eating an armen standing behind him.
# 0.3138944883176695
#
# A middle aged man is sitting on a stool in a bar.
# An older man is sitting on the ground walking on the street.
# 0.4009303368612343
#
# Number 13 kicks a soccer ball towards the goal during children 's soccer game.
# A man standing in front of a large crowd of people on the sidewalk.
# 0.1462241911415978
#
# A player passing the ball in a soccer game.
# A person wearing a blue shirt is standing behind him.
# 0.13147705731889764
#
# A player trying to score in a soccer game.
# A person wearing a blue shirt and stands in the street.
# 0.17178411709186117
#
# A player fighting in a soccer game.
# A person carrying a baseball game.
# 0.3189714047264471
#
# A nun uses her camera to take a photo of an interesting site.
# A person is crossing the street while sitting on the ground and held one walking down the street.
# 0.14388344159183583
#
# A nun using her camera to take pictures of various things outdoors.
# A person wearing a blue shirt is walking through a picture of a building.
# 0.27185913225635955
#
# A nun taking photos of a interesting site outside.
# A person wearing a blue shirt is standing on the street.
# 0.1872458334277124
#
# A nun on her knees praying by a statue.
# A person with a cap at a building.
# 0.33940581407497517
#
# A man sits in a chair on the sidewalk in front of a huge display of brightly colored artwork.
# A man is standing on the sidewalk with a boat with a cat on the sidewalk.
# 0.3523354999284345
#
# The man was watching tv.
# A man is wearing a black shirt.
# 0.25941601404401565
#
# A man sits in a chair on the sidewalk in front of a huge display of brightly colored artwork.
# A man is standing on the sidewalk with a boat with a cat on the sidewalk.
# 0.3523354999284345
#
# The man was selling the artwork.
# A man is wearing a blue shirt.
# 0.2767861830095972
#
# A young child is jumping into the arms of a woman wearing a black swimming suit while in a pool.
# A young man is standing on the sidewalk with the ball to a woman in a blue shirt.
# 0.37846385153485607
#
# Mother catching her son in a pool.
# A mother takes pictures of a baseball.
# 0.20460980179777127
#
# Mother and daughter shopping for shoes.
# A kid is playing with her holder.
# 0.17346230216859593
#
# Child leaping into arms of a woman wearing swimsuit in a pool.
# A child wearing a red shirt and blue shirt and red striped shirt.
# 0.25639821565313525
#
# A guy waxing a wooden floor with wax.
# A guy who is watching television pole because he is sitting.
# 0.18780788241658158
#
# the guy is dead.
# The guy is blown.
# 0.5581600587827487
#
# a guy is waxing.
# The guy is blown.
# 0.4484416535458776
#
# the guy is paid.
# The guy is blown.
# 0.5581600587827487
#
# This is the image of two Asian men squatting near a mop-pad.
# This is girl of a baseball while the other people are waiting for the bus.
# 0.290253631153199
#
# This picture is of two Asian men.
# A restaur watches a live to the park.
# 0.5896311414767996
#
# Two young asian men are squatting.
# The young man is sitting on the grass.
# 0.35516249584264625
#
# Two italian girls are squatting.
# A white dog is conducting a can.
# 0.14466558206442298
#
# A man uses a projector to give a presentation.
# A man is standing on the sidewalk with their arms in the background.
# 0.13282720967749945
#
# A man is giving a presentation in front of a large crowd.
# A man is wearing a blue shirt is standing on the sidewalk.
# 0.3201115513313811
#
# A man is using a projector to watch television.
# A man is standing on the sidewalk with their arms in the background.
# 0.2356486987700694
#
# A man is giving a presentation.
# A man is wearing a blue shirt.
# 0.4454919399364311
#
# An older gentleman speaking at a podium.
# An older man is walking to a car.
# 0.3981973877518862
#
# A little girl in a spelling bee.
# A little girl in a pink shirt.
# 0.6308433068206093
#
# A man giving a speech.
# A man standing outside.
# 0.35138749399652214
#
# The college dean giving the graduation speech.
# A person with a cap as the park.
# 0.13120953170622374
#
# A young barefoot girl in a pink dress is jumping outside.
# A young man is standing on the sidewalk with their arms in the background.
# 0.30620193155963765
#
# The child sits in a dark room watching television.
# A child is playing with a box on the street with the ball.
# 0.24814844551289567
#
# A little girl is playing jump rope.
# A little girl is playing outside.
# 0.7358080527404821
#
# A child is playing.
# The children are outside.
# 0.2251376916177524
#
# Four guys with guns and army gear.
# A cowboy street in front of a building.
# 0.41509845622052555
#
# The four guys are in the army.
# The conductor is on the street.
# 0.2955261230535602
#
# The guys have guns.
# A guy is wearing a black shirt.
# 0.11035569779632985
#
# The four guys are playing hopscotch.
# Five people are standing outside.
# 0.24082472596216184
#
# A man is a safety suit walking outside while another man in a dark suit walks into a building.
# A man is crowded by a path of the street with the ball to a woman in a blue shirt.
# 0.324460431158535
#
# There are two men walking outside.
# There are two men on the beach.
# 0.5582358148594986
#
# Men are walking in different directions.
# A man is standing in the road wearing a black coat.
# 0.18916724136294233
#
# Men are sitting in the park.
# A man is standing in the street.
# 0.41238552613852936
#
# A man poses for a photo in front of a Chinese building by jumping.
# A man is wearing a blue shirt with his hands with her hand.
# 0.18584578742746538
#
# The man has experience in taking photos.
# A man is wearing a blue shirt is standing behind him.
# 0.17303353843686656
#
# The man is dancing around the building.
# A man is standing in the rain.
# 0.39374622184569025
#
# The man is prepared for his photo.
# A man is standing in the rain.
# 0.27379085904726047
#
# A couple bows their head as a man in a decorative robe reads from a scroll in Asia with a black late model station wagon in the background.
# A couple is watching television past a car with the ball to a woman in a blue shirt.
# 0.2666734721863171
#
# A black late model station wagon is in the background.
# A black dog is running through a football face.
# 0.2785221892444044
#
# A white late model station wagon is in the background.
# A white dog is conducting a can empoys the other team.
# 0.3213711135298508
#
# A light black late model station wagon is in the background.
# A white dog is wearing a blue shirt is standing on the street.
# 0.2552934135934592
#
# A boy looks surly as his father looks at the camera.
# A boy jumps into the water with a ball of the wall.
# 0.25650115399000334
#
# a girl looks at her father.
# A girl is playing with his son.
# 0.215610692354456
#
# a boy looks at his farther.
# A boy is playing with his dog.
# 0.2846824368437765
#
# a younger boy looks at his father.
# The resture works on the street.
# 0.25749908111093356
#
# A boy in red slides down an inflatable ride.
# A boy in a blue shirt with his hands in the street.
# 0.2744348133674281
#
# A boy rolls around an inflatable ride.
# A boy is playing with a box on the beach.
# 0.19811207515897553
#
# A boy is playing on an inflatable ride.
# A boy is playing with a bow in the water.
# 0.504698665560137
#
# A boy pierces a knife through an inflatable ride.
# A boy is playing with her hands on the beach.
# 0.20875229379248617
#
# A man is reading a newspaper in a car dealership.
# A man is standing on the sidewalk with their arms.
# 0.31972787498500166
#
# A man is at a car dealership.
# A man is in a baseball car.
# 0.446628492912555
#
# The man is waiting for his car to be serviced.
# A man is standing on the sidewalk street.
# 0.2920534677773307
#
# A man is reading a magazine at the hospital.
# A man is standing on the sidewalk street.
# 0.39774256061740376
#
# Two male police officers on patrol, wearing the normal gear and bright green reflective shirts.
# A male dog is standing in front of a large crowd of people on the sidewalk with a boy on the street.
# 0.24448314661278947
#
# The two officers have gotten a call about a fight.
# Two hiker is wearing a blue shirt is standing behind them.
# 0.2557458389365888
#
# The two male police officers are looking for trouble.
# A male car is watching television and is crossing the stage.
# 0.19971854403258568
#
# The officers have shot an unarmed black man and will not go to prison for it.
# The tractor is checking their while they are walking on the sidewalk.
# 0.14117370164254256
#
# A carefully balanced male stands on one foot near a clean ocean beach area.
# A child wearing a red shirt and blue shirt and red striped shirt.
# 0.3298412498169335
#
# A man stands on one foot with his wife near the beach.
# A man is standing on the sidewalk with the ball to a building.
# 0.38330060709555835
#
# A man is ouside near the beach.
# The man is a man in a bike.
# 0.30960822968521046
#
# A man is sitting on his couch.
# The man is sitting on the grass.
# 0.6074428598213805
#
# A man wearing a white shirt is playing the drums.
# A man in a blue shirt is standing on the street.
# 0.47544074873108194
#
# A man is playing a musical instrument.
# A man is wearing a blue shirt.
# 0.36694729100964985
#
# A man is playing the trumpet with his hands tied behind his back.
# A man is standing on the sidewalk with a boat on it.
# 0.33604024193029514
#
# A man in a band is playing the drums.
# A man in a blue shirt is sitting.
# 0.4438222841301936
#
# Three women in dress suits walk by a building.
# Three women dressed in blue and white shirt.
# 0.47895360539001436
#
# Three women are traveling by foot.
# There are two women walk to the store.
# 0.3405015716890832
#
# The suits are gray.
# The vehicle is blue.
# 0.17537670874647399
#
# The woman are wearing bikinis.
# A woman is holding a baby.
# 0.33111059566820394
#
# two people are waiting for a train at a station.
# Two people are standing on a beach with a boy.
# 0.47968967670606594
#
# They expect a train to arrive eventually.
# They are going to a window to the day.
# 0.26771843243182913
#
# They are both waiting for a bus.
# The girls are walking to the store.
# 0.2741455993358603
#
# They will both get onto the same train together.
# They are going on a sunny day.
# 0.1292604536765341
#
# A man in a black shirt is smiling at a woman in a black shirt what a tattoo and a eye brow ring.
# A man in a blue shirt and a black shirt and blue jeans is walking through a pool with his daughter.
# 0.4966113660618406
#
# A man is smiling at a woman.
# A man is standing in the rain.
# 0.4399465474379019
#
# A man is smiling at his wife.
# The man is sitting on the grass.
# 0.3645702681338323
#
# A man is reading a book alone.
# A man is wearing a blue shirt.
# 0.5008870727467083
#
# A person wearing white is running towards a ball that was kicked from another person.
# A person wearing a blue shirt is standing on the sidewalk.
# 0.33172884624047816
#
# The goalie is running out to catch the ball before it passes him into the goal.
# A gentleman smiles while sitting on the ground walking on the sidewalk.
# 0.23399857347237266
#
# The goalie is sleeping at home.
# A lady is looking at the camera.
# 0.33258928107506885
# Two men sitting on a subway are reading, with coats and scarves on, but have seemed to have lost their pants.
# Two men and a woman with red shirt and blue shirt and stands in the street.
# 0.2578877505885937
#
# There are women on the subway.
# There is a woman dressed.
# 0.29732001253923884
#
# There are people on the subway.
# There are people on the beach.
# 0.7860436238303993
#
# The men are wearing pants.
# A man is wearing a blue shirt.
# 0.3633646899304787
#
# kids drawing something on paper.
# A gentlemen sitting on a bench.
# 0.2470405529377274
#
# The kids are drawing pictures of animals.
# The kid is playing with her holder.
# 0.2665872862693695
#
# There are kids drawing.
# There is a girl in the snow.
# 0.25079292295301137
#
# The kids are cutting ribbons.
# The kid is wearing a black coat.
# 0.3380440123324412
#
# A young woman is singing into a microphone.
# The young woman is in the air outdoors.
# 0.4407914305588879
#
# The woman playing the trumpet.
# A woman standing on the sidewalk.
# 0.36896156718464784
#
# The woman is in a band.
# The woman is in the air.
# 0.6824816510321863
#
# The woman is singing.
# A woman is sitting.
# 0.6599231368411863
#
# Three elephants, each carrying a group of people, walking through the water.
# Three girls and one man are sitting on a bench in front of a building.
# 0.2125236076700712
#
# The elephants are part of a jungle tour.
# The girl is a song on the beach.
# 0.14368738741670592
#
# The elephants are performing in a circus tent.
# A goalie is sitting on the ground.
# 0.11540236711049551
#
# Three elephants carry people through the water.
# Three girls are sitting on a bench with his daughter.
# 0.22037640091893979
#
# ...
# 0.4766350750209365
#
# A man standing in front of a brick building.
# A man standing in front of a large crowd.
# 0.6827296327903086
#
# A man is outside.
# A man is standing.
# 0.5030760719034105
#
# A man is outside with a woman.
# A man is standing in the street.
# 0.33310773826997886
#
# The man pushes a women on the ground.
# A man is standing on the sidewalk.
# 0.33375482451073785
#
# An adult ballerina shows you children how to dance.
# Two basketball players are playing in the snow.
# 0.12677140427871422
#
# The ballerina is sitting down judging the children 's dancing.
# The batter watches the ball to a man showing off the sidewalk.
# 0.28982469415338574
#
# A ballerina is teaching kids ballet.
# The batter watches the ball
# 0.19262770582905125
#
# The ballerina is the children 's dance instructor.
# The backstruck is in front of a building.
# 0.290032670304139
#
# People in orange robes line up behind a man wearing sunglasses.
# A dog carrying a baseball in the snow is holding a baby street.
# 0.1553666920852403
#
# Cult members queue up behind their leader.
# The conductor and one child running through the water.
# 0.11287347342254485
#
# People are playing basketball.
# People are watching a basketball.
# 0.7066916904405172
#
# People line up behind a one other person.
# People are standing on a beach.
# 0.2596862217367919
#
# Two Children playing baseball at the park.
# Two children run in front of a building.
# 0.29485877236491287
#
# Children playing baseball.
# A child wearing swim clothes.
# 0.19158743349944554
#
# Two children lighting matches in their room.
# Two children are playing in a country.
# 0.4166917448174333
#
# Two children practicing for a ball game in the park.
# Two children playing outdoors with an umbrella.
# 0.37822156095533827
#
# Two people are sitting next to a wood-stacked campfire at night.
# Two people are walking down a street with a blue ball.
# 0.3549557468023839
#
# People are sitting outside at night.
# People are standing on a beach.
# 0.4508687140486472
#
# The sun is shining brightly on the people.
# A person is looking at the street.
# 0.3111262614864619
#
# The people are camping in the woods.
# People are standing on a beach.
# 0.37020683292741074
#
# A young girl in a white summer dress walks the outer edges of a large park fountain.
# A young woman in a blue shirt and blue jeans is walking through a pool with his daughter.
# 0.30801882301498684
#
# The girl is sitting by the fountain.
# A girl is standing on the sidewalk.
# 0.46879173099524163
#
# The girl is wearing a white dress.
# The girl is wearing a blue shirt.
# 0.697366396180624
#
# The girl is walking the edges on a sunny day.
# A girl is standing on the sidewalk with their arms.
# 0.4086153655750691
#
# An older man sitting on a stool on the sidewalk playing a violin.
# An older man wearing a blue shirt is standing on the sidewalk.
# 0.5840893313738539
#
# A woman performs a comedy routine in a club.
# A woman is standing on the sidewalk street.
# 0.23805913678393031
#
# An old man plays his violin for tips on the sidewalk.
# An old man is sitting on the ground walking on the sidewalk.
# 0.5128508705535385
#
# An old man plays the violin on the sidewalk.
# An old man is sitting on the ground walking.
# 0.5048721178211859
#
# 2 woman walking down the street next to graffiti.
# A woman standing on the sidewalk with a bottle.
# 0.39694633828537224
#
# The grafitti is a picture of a mouse.
# The truck is a son while wearing
# 0.24056486386122503
#
# The woman are by grafitti.
# The woman is in the air.
# 0.4258406422181277
#
# The 2 woman are running.
# The two women are walking.
# 0.45924571537645986
#
# An older man is standing outside in front of a truck.
# An older man is walking through a street carroon.
# 0.447330776026838
#
# A man is on his feet.
# A man is in a bus.
# 0.44620063502064367
#
# A disabled man is in a wheelchair.
# The blond girl is standing outside.
# 0.139800134566647
#
# An elderly man is blocking traffic.
# The elderly dree dogs a sandwich.
# 0.3001985358331127
#
# A guy singing on stage with a cool black shirt, while turning his microphone to the audience so they can sing along.
# A guy who is wearing a blue shirt with a conversation with a white dress is standing in front of a building.
# 0.3600233408387332
#
# A guy is telling a joke on stage.
# A guy is watching television and crowd.
# 0.38652970254450975
#
# A guy is singing a classic rock song on stage along with the audience.
# A guy is standing on top of a ball to the park.
# 0.30982069730883055
#
# A guy is singing on stage along with the audience.
# A guy is sleeping on a sidewalk with their backs.
# 0.5173298700359364
#
# A hot-air balloon getting filled.
# A blond woman stands by her.
# 0.5212465312759786
#
# A hot-air balloon is being operated on.
# A blond woman is standing outside.
# 0.2522255151131222
#
# A hot-air balloon is flying over a mountain range.
# A blond woman is looking at the street.
# 0.1906804671537825
#
# A hot-air balloon is being prepared for take off.
# A blond woman is looking at the street.
# 0.20383602441467122
#
# An Indian man standing on the bank of a river.
# An Asian people walking down a stage while others watch.
# 0.2124424326796599
#
# He is fishing.
# It is Halloween.
# 0.18207052811092134
#
# There is a black man fishing.
# There is an eventical man standing
# 0.4323201039781683
#
# There is a man by the river.
# There is a man walking outside.
# 0.49041180180807975
#
# This photo includes a statue of a man and a woman walking with a blue shirt walking behind it.
# People are watching the sun while throwing of a ball to a woman in a blue shirt.
# 0.4232416497081096
#
# A man and woman walking down a busy street.
# A man and woman drinking water in the pool.
# 0.5241530614279214
#
# There is a statue of two people.
# There is a person on a beach.
# 0.403611660159182
#
# A statue is outdoors in a park.
# The street is playing.
# 0.1413524393918024
#
# This crib contains a baby, stuffed animals, a box of matches, a cordless drill, a paperback novel, and a blanket.
# A couple is watching television past a car and some trees and water at the beach while the other people are waiting for their motorcycle.
# 0.14963096080326627
#
# The baby 's older sibling is very mischevious.
# The baby is playing with a book of water.
# 0.3186870444882079
#
# The boy is napping in the highchair.
# A boy is playing with his dog.
# 0.3240761558245353
#
# The baby is in the crib.
# The baby is at the beach.
# 0.6131106798760368
#
# Two guys and a woman standing and talking in a playground.
# Two guys is married to work on a stage with a boy.
# 0.3074274643223424
#
# Three adults are standing and thinking about space.
# Two hikers are walking to the street are team.
# 0.2897445808775236
#
# Three adults are talking in the playground.
# The street performer is reading a meal.
# 0.15683283582627475
#
# A couple of guys in the playground are talking with the woman about kids.
# A child in a blue shirt and blue jeans is walking through a pool.
# 0.24875296021851354
# A man in a yellow shirt does East Asian calligraphy.
# A man in a blue shirt is sitting on a bench.
# 0.3613184537303543
#
# A man does graffiti.
# A man is wearing a blue shirt.
# 0.2045751403232798
#
# A man does calligraphy.
# A man is wearing a blue shirt.
# 0.2076993284885205
#
# A man does Japanese calligraphy.
# A man is wearing a blue shirt.
# 0.21289301754818854
#
# Two girls talk at an ice skating rink.
# Two girls in a bike race together.
# 0.3569182114418833
#
# Two women compete in a speed skating race.
# Two women are walking on a beach.
# 0.36414723004037025
#
# Two girls are near the ice.
# Two girls are standing outside.
# 0.4761245453424493
#
# A group of people standing in front of a club.
# A group of people walking down a street corner.
# 0.5296809666009631
#
# A group of people are waiting to enter the club.
# A group of people are watching a man on the street.
# 0.6145296756383275
#
# A group of people in front of a club.
# A group of people walking down a stage.
# 0.5296040055585964
#
# There are seven people leaving the club.
# There are people walking down the street.
# 0.5648989765320949
#
# A sleeping toddler has toppled out of his crib.
# The two dogs are running through water.
# 0.13038483918868046
#
# A baby.
# A woman selling.
# 0.35930411196308426
#
# a baby in crib.
# A baby in a blue skir
# 0.444670097512721
#
# A toddler slept.
# Persons.
# 0.20109487958223407
#
# Balding man in gray sweater plays with his dog.
# A band woman walks in front of a building with the ball.
# 0.2918309030737595
#
# A man puts the sweater he knitted on a dog.
# A man is standing on the sidewalk with a boat.
# 0.3359646343678108
#
# An older man is throwing a stick for his dog.
# An older man is walking through a street carroon.
# 0.5301027210290284
#
# A man is with an animal.
# A man is in a baseball.
# 0.44997815071520203
#
# The small girl is sitting in a harness, strapped to a tether, while others watch.
# A small child is eating a camera in front of a building.
# 0.23411149171320933
#
# There is a girl in a harness.
# There is a girl in a pink.
# 0.7250567067060762
#
# A little girl is riding a bicycle on a tightrope.
# A little girl is playing with her hands.
# 0.42403854177938094
#
# The girl in the harness is being rescued from a buring building.
# A girl in a blue jacket is riding a bike.
# 0.2666784783432626
#
# A black dog runs with a deflated ball and a tiny tire.
# A black dog is running through a street carroon.
# 0.3522805705675502
#
# A dog with a ball.
# People watching them.
# 0.5294392838566988
#
# A cat eats tuna.
# The cat is wearing a black coat.
# 0.1585953426182852
#
# A dog with his two favorite toys.
# A dog running in the snow covered mountain.
# 0.17038083674521656
#
# People are walking along the street.
# People are standing on a beach.
# 0.4469759580113421
#
# The people are walking in a parade.
# People are standing on a beach.
# 0.4186815486990483
#
# People are skipping down a street.
# People are standing on a beach.
# 0.5083184483563488
#
# Humans beings are ambling down a road.
# A boy and girl are walking on the street.
# 0.2088033590602766
#
# A man is sitting in a chair and looking at something that he is holding.
# A man is looking at something on a couch with a ball of the wall.
# 0.5227154129611521
#
# A man is sitting in a chair pondering life.
# A man is standing on the sidewalk with their arms.
# 0.3385103580900612
#
# A man is sitting down looking at something.
# A man is looking at the camera while resting.
# 0.5384396849329113
#
# An old women in a purple skirt is gardening with a old tool.
# An old man wearing a blue shirt is standing on the sidewalk.
# 0.3538396136854465
#
# A woman is planting tulips.
# A woman is wearing a blue shirt.
# 0.4255911375936231
#
# A woman is cooking in the kitchen.
# A woman is sitting on the street.
# 0.532172842288342
#
# There is a woman wearing purple outside.
# There is a woman with a conversation.
# 0.48609313962833633
#
# Two girls are on a street sidewalk and one is sitting.
# Two girls are watching the wall with a band play.
# 0.38962513185915737
#
# the street is empty.
# The street is wooden.
# 0.6093228271290612
#
# girls are on the sidewalk.
# The girl is in the air.
# 0.3394079806411346
#
# girls are watching boys.
# The girl is wearing a blue shirt.
# 0.21715830432529226
#
# Women are standing outside.
# A woman is sitting outside.
# 0.5031747626530138
#
# The women are seated in a bistro eating lunch.
# A woman is sitting on the ground watching.
# 0.23620796543357755
#
# There are muliple women outdoors.
# There is a large couple.
# 0.23464976072939484
#
# A motocross rider is slightly airborne on a competition circuit jump.
# Two children in white uniforms are watching television.
# 0.18550544402673266
#
# The motorcross rider is standing in quicksand.
# A construction worker is eating a sand castle.
# 0.2725150980979239
#
# The motorcross rider is holding on to bike in order not to fall.
# Two children in white uniforms are watching television together.
# 0.20382664651530857
#
# The motorcross rider is performing in front of an audience.
# A construction worker is eating a sand castle on the beach.
# 0.20805738232313717
#
# A guy with long brown curly hair wearing a white t-shirt is looking into the camera with something in his mouth. a.
# A guy with a blue shirt and blue jeans is walking through a pile of leaves and red striped shirt.
# 0.2691913781943858
#
# A person looks at something.
# A person is looking at the street.
# 0.48946145158440807
#
# There is a person standing outside.
# There is a person outside.
# 0.6841783195019325
#
# A person with long hair looks at the camera.
# A person in a blue jacket is riding a bicycle together.
# 0.2574590020983642
#
# The man in black has a condom on his head.
# A man with a blue shirt is sitting on a bench.
# 0.23838701459730122
#
# The man is wearing the condom on his foot.
# A man is wearing a blue shirt is standing behind him.
# 0.38127254931653054
#
# The man is wearing a prophylactic on his head.
# A man is wearing a blue shirt is standing behind him.
# 0.41765471442301993
#
# The man is using a condom as a mask.
# A man is wearing a blue shirt is standing.
# 0.33442241824244306
#
# A woman is holding one young children with another standing next to her while a man is sitting by a small campfire.
# A woman is holding a baby with a boy with a bowl of water with a woman in a crowd.
# 0.3212310300111458
#
# A woman is holding one young children with another standing happily next to her.
# A woman is holding a baby with a boy with a book of water.
# 0.34269162084111154
#
# A woman is holding one young children with another standing next to her.
# A woman is standing on the sidewalk with the ball.
# 0.3808422357965043
#
# A woman is holding one young chimp with another standing next to her.
# A woman is standing on the sidewalk with the ball.
# 0.3988959699543036
#
# A distant person is climbing up a very sheer mountain.
# A group of people are watching a man with their car.
# 0.1446213290230735
#
# There are many people climbing.
# There are three couchs in bed.
# 0.37661811297569525
#
# The mountain is unclimbable for humans.
# The water is playing with a boy.
# 0.1650395971234387
#
# People are outside climbing.
# People are watching the ball.
# 0.4424252176035718
#
# Four female children gather around a brown table to paint.
# A female belly dancer is performing in front of an empty crowd.
# 0.22646110919988569
#
# Kids are working on art.
# A kid is playing with his son.
# 0.14260408421074205
#
# Girls are playing outside.
# The girl is wearing a blue shirt.
# 0.15500976149303866
#
# Girls are at school.
# The girl is in the air.
# 0.33257789882723987
#
# Two girls and a guy are involved in a pie eating contest.
# Two girls are sitting on a bench with a boat on the street in front of a building.
# 0.3259673520657404
#
# Three people are drinking beer on a boat.
# Three people are standing on a beach.
# 0.6259341258043069
#
# A group is at the county fair.
# The group is working on the street.
# 0.3917634141548745
#
# Three people are stuffing their faces.
# Three people are watching the paper.
# 0.6106655171958235
#
# A couple in bathing suits walk on a beach.
# A child in shorts is standing on the sidewalk.
# 0.29222453847009816
#
# the couple are sitting inside.
# The couple is asleep.
# 0.3433746649580804
#
# The couple are together.
# The couple are outside.
# 0.6364572502650327
#
# there is a couple.
# There is a man.
# 0.5251228733626776
#
# A basset hound is tied to a doorway in an alley in front of a man and woman.
# A baseball player is in the air on the beach with a boy with a book.
# 0.20680983395011215
#
# The dog is outside.
# The dogs are sleeping.
# 0.32505557934821355
#
# The dog is on the moon.
# A dog is in the air.
# 0.5105875195044327
#
# It is their dog.
# It is Hallowed mentle over.
# 0.20744432576282615
#
# A man in a plaid shirt and brown pants walking around town with one hand in his pocket.
# A man in a blue shirt and another woman wearing a blue shirt is standing next to the side.
# 0.3909035027923958
#
# The man has walking shoes on.
# A man is wearing a blue shirt is standing.
# 0.2198787120479627
#
# The man is going for a walk.
# A man is standing in the rain.
# 0.3746631570740834
#
# The man has a white dress shirt on.
# A man is crying alone at the beach.
# 0.20656716309120185
#
# A young man plays a racing video game.
# A young man is sitting on the beach.
# 0.4139500377072306
#
# a young man is good at games.
# A young girl is playing with his hands.
# 0.2615651536220919
#
# bleu score:  0.3493567918654209
# complete:  2
# ['A man is wearing a blue shirt.', 'There are people outside.']
